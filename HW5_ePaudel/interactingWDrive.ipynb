# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/DSPS/blob/master/HW5/interactingWDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Review the operations below to interact with your drive and complete the final task

# %% [markdown]
# ### Integrating Colaboratory with Google Drive

# %% [markdown]
# If we are going to be grabbing data from the internet for use with colaboratory, we'll need to use our google drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### The unix terminal
#
# Unix is one of the oldest and most barebones Operating Systems (OS), but it serves as the platform for more advanced OSs like Mac OS and some modes of Windows.
#
# Unix and unix-based OSs like Mac OS, have a powerful utility called the "Terminal", that allows for a "command line interface" for interacting with your computer (Windows has something similar, but the syntax is different).
#
# Jupyter allows us to run some of these commands **as if we were in a terminal**:

# %% [markdown]
# ```ls``` lists the content of the directory you are in

# %%
ls
# Out:
# drive/  sample_data/

# %% [markdown]
# ```pwd```  stants for present working directory and telss you which dir. you are in

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ```ls``` with an argument lists the content of the directory path indicated by the argument

# %%
ls "drive/My Drive"
# Out:
#  00101.mov
#  00102.mov
#  00103.mov
#  00104.mov
#  11bov.pdf
# '11fe summary.gdoc'
#  11img-179017.png
# '1 2017 Proposal Award Information Form & Guidelines.pdf'
#  2003VS2.png
#  2013Jul15_obslog_0327.log
#  2018-07-17_SC.pdf
# '2018 Capstone assignments FINAL.XLSX'
# '2018 Capstone assignments - worksheets.xlsx'
# '2018 Capstone assignments - worksheets.xlsx.gsheet'
# '2 2017 Final Report and Financial Attestation Forms.pdf'
# '3 2017 Financial Report Template.xlsx'
# '4 Form W-9.pdf'
#  5.25.pdf
#  A1DBA84B-27E0-4B23-A409-135AA52FB3FD.png
# 'AAS12948 referee report.gdoc'
# 'aas 2011 austin costs.gsheet'
# 'AAS check list.gsheet'
# 'AAS - EDU cheatsheet.pdf'
# 'aas membership.gsheet'
# 'AAS Poster Quaoar.jpg'
# 'Abundance_Maryam_29_Aug13 (1).pro.gdoc'
#  Abundance_Maryam_29_Aug13.pro
#  Abundance_Maryam_29_Aug13.pro.gdoc
# 'A  Cadence  to  Reduce  Aliasing  in  LSST Bell.gdoc'
# 'Accelnet2019 reviews.gdoc'
# 'AC NSF ID -000747680 -Bianco Federica.docx'
#  Acquaviva.gdoc
# 'added coauthors.gsheet'
# 'A Diversity and Inclusion Committee of the Department of Physics and Astronomy at the University of Delaware.gdoc'
#  AGNlogo.gdraw
# 'A  Higher  Cadence  Subsurvey  Located  in  the Galactic  Plane Lund.gdoc'
#  alienmovies.gsheet
#  alienmovies.tsv
# 'amazing women.gdoc'
# 'An Extreme Rolling Cadence (for TDEs) Gezari.gdoc'
#  apiks/
#  APIreadingJson.ipynb
#  __appdata__/
# 'application season 2015.gsheet'
# 'application season 2015.xlsx'
# 'Are we alone? Searching for Intelligent Life with LSST.gdoc'
# 'ARPAe docs'/
#  AS4_TDA_20160211.docx
#  AS4_TDA_Nov2015_20160119notes_ecb.docx.gdoc
# 'Assessment of the impact of an LSST ODF from the Science Collaborations (1).pdf'
# 'Assessment of the impact of an LSST ODF from the Science Collaborations.pdf'
# 'astro 101 2013 grades.gsheet'
#  Astro2020SCsF1.gdraw
#  Atimeexchangemodel-thoughtsandscribblings.docx
#  August/
#  BaurJulienFBB.gdoc
#  behavpp.gslides
#  berlusconi_eng.doc.gdoc
# 'BEST HACK (1).pdf'
# 'bg 2.png'
#  bg.jpg
# 'BIA02-01 Modified Provisional Application - with GA_s changes-c SEK.docx'
# 'BIA02-01 Modified Provisional Application - with GA_s changes-c SEK.gdoc'
#  Bianco--1-26-2015.doc
# 'bianco+2014 answers.gdoc'
# 'BiancoAAS233TownHallPPT 3 (1).key'
# 'BiancoAAS233TownHallPPT 3.key'
#  Bianco_Federica-2018-03.jpg
#  Bianco.pdf
#  bianco_S1_EWASS2019_LSST.pdf
# 'Bianco_SC_F2F2018 (1).pdf'
#  Bianco_SC_F2F2018.pdf
# 'Bianco UDel Phsyica&Astronomy   DSI  postdoc PDR.gdoc'
# 'Blazars  (and  FRBs)  with  LSST Raiteri.gdoc'
#  bookmarks_11_26_17.html
#  bootplot4.py
# 'Boxing Answers .gdoc'
#  box_whisker_pca.png
# 'briefing on ODF - Steve Kahn - SC chairs.gdoc'
#  Budget_justification_NSF_UWM_Bianco.docx
# 'Budget  - NSF 19-501 - Bianco.xlsx'
#  building-comprehensive-complete.zip
# 'CAA_LSSTSCs (1).key'
#  CAA_LSSTSCs.gslides
#  CAA_LSSTSCs.key
#  CAA_LSSTSCs.pdf
# 'Camping graucery list.gdoc'
#  carousel_image_fb084d49f0320057c720_DSC_0777.JPG
# 'Carreer Grant Proposal 01 03 2019.gdoc'
# 'census tracts geoid hint.gdoc'
#  CfA.SNIbc.BIGINFO.list.gsheet
#  CfA.SNIbc.BIGINFO.list.txt
#  CfA.SNIbc.BIGINFO_notused.gsheet
# 'Changes to PASP-100746 .gdoc'
# 'Chotard+ 2011.gslides'
#  citibikes/
# 'class quiz'/
#  co_fed.gdoc
# 'Colab Notebooks'/
# 'Committees guidelines from Executive Board Handbook_Final_R2_21Mar2018.pdf'
#  comp_Fe_old_new.csv
#  comp_Fe_old_new.gsheet
# 'Continuous  Cadence  Acquisition  of  the  LSSTDeep  Drilling  Fields Bell.gdoc'
# 'Copy of 6. Aggregation task.gdoc'
# 'Copy of all_music_gear.gsheet'
# 'Copy of BaurJulienFBB.gdoc'
# 'Copy of BIA02-01 Modified Provisional Application - with GA_s changes-c SEK - sek.gdoc'
# 'Copy of Carreer Grant Proposal 01 03 2019.gdoc'
# 'Copy of CfA.SNIbc.BIGINFO.list.gsheet'
# 'Copy of Federica Bianco II 2019 Talk prep .gdoc'
# 'Copy of LSST2019: LSST SCIENCE.gslides'
# 'Copy of Occultation Key Project .gdoc'
# 'Copy of Vision for a Data Science curriculum for Public Service.gdoc'
#  CSIAgenda4.12.17.pdf
#  CUSP/
#  CUSPstudents_netIDGithub.gsheet
#  d11_dom.gsheet
#  dads/
# 'DarkUniverseNoSN (1).mp4'
#  DarkUniverseNoSN.mp4
#  DarkUniverseNoSN_slow.mov
#  DDT_HD187091.gdoc
# 'Dear Editors of Astronomy&Computing,.gdoc'
# 'December 10 LSST SC chairs call.gdoc'
# 'December 6 LSST SC chairs call.gdoc'
# 'December 7th CUSP HackDay.gdoc'
# 'DE legislative reform'/
#  descsticker.gdraw
# 'Done for house.gsheet'
#  draft.gdoc
#  DSC_0089.AVI
# 'DSPP curriculum logic model (1).jpg'
# 'DSPP curriculum logic model (1).png'
# 'DSPP curriculum logic model (2).jpg'
# 'DSPP curriculum logic model (2).png'
# 'DSPP curriculum logic model (3).jpg'
# 'DSPP curriculum logic model.drawio'
# 'DSPP curriculum logic model_final2.png'
# 'DSPP curriculum logic model_final.png'
# 'DSPP curriculum logic model.jpg'
# 'DSPP curriculum logic model.png'
# 'DSPP curriculum logic model.svg'
#  dsps/
#  dsps2019/
# 'DSPS 2019 quiz 6 - Google Docs-1.pdf'
# 'DTU17 classification data challenge.gdoc'
# 'Ejecta mass Phot Analysis paper outline 2015-16.gdoc'
# 'Electromagnetic Follow Up of MMA triggers.gdoc'
# 'Endorsement of LSST Corporation Activities by the LSST Science Collaborations.gdoc'
#  ESB_119.75_camera4_50ms_1999_1706.GIF
#  eta07_eta09.gsheet
# 'eta car echoes meeting 04 23.gdoc'
# ' eta car echoes  TARGET LIST.gdoc'
# 'eta DECAM coordinates.gsheet'
# 'eta light echoes in colors.gsheet'
#  etaspec14A.fed.tex
# 'Explosive  Physics  and  Fast  Transients  White  PaperCadence Bianco.gdoc'
# 'Fact Check_Federica Bianco_v2 (1).gdoc'
# 'Fact Check_Federica Bianco_v2.docx'
# 'Fact Check_Federica Bianco_v2.gdoc'
# 'Faculty and Staff Women in Physics.xlsx'
# 'Fast Transients cadence proposal call 11 12.gdoc'
# 'Fast Transients.gslides'
#  FBB_collab_letter.pdf
# 'F.B.Bianso SC Coordinator worksheet.gsheet'
#  fbb_K2_biosketch.gdoc
#  fbbresume.gdoc
#  FBBshortCV.gdoc
#  fbbTedTalk_take1.mov
#  fbb_UD.gdoc
#  fb_teaching.pdf
#  FD-II.gdoc
#  Fed/
#  Fed2/
# 'Fed and Kim.mp4'
# 'federica bianco - computer needs.gdoc'
# 'federica bianco computer needs.gsheet'
# 'FedericaBianco[FinalJPEGs]-257.jpg'
# 'FedericaBianco[FinalJPEGs]-270.jpg'
# 'federica bianco -- funding request contingent upon better understanding of USF support system.gsheet'
# 'Federica Bianco II 2019 Talk prep  saved  .gdoc'
# 'Federica Bianco_PR Guide_TED2019 Fellows.gdoc'
# ' Federica Job Applications 2012 for tim.gsheet'
# 'Federica Job Applications 2012.gsheet'
# 'fed job apps 2014-5 Andy.gsheet'
# 'fed job apps 2014-5 - Charles.gsheet'
# 'fed job apps 2014-5.gsheet'
# 'fed job apps 2014-5 HOGG.gsheet'
# 'Female Undergrads in Physics for 2193.xlsx'
#  fevel.gsheet
# 'fig5 .gdraw'
#  fights/
#  filament/
#  File_000.jpeg
#  File_000.mov
# 'File May 11, 12 35 26 PM.mov'
# 'final 2013.gdoc'
#  Fragment.tex.gdoc
#  FTN_20110623_Charon_boxcar.ps
#  FTN_20110623_Pluto_halflight.ps
# "gabriella's thesis - copy.gdoc"
# 'Gaia-LSST Synergy and Constraints to Pulsation Theory using LSST: Observations of variable stars in Local Group stellar systems.gdoc'
# 'Galaxies plenary.gslides'
#  GalSClogo.gdraw
# 'GBS Committee Report and Notes.gdoc'
# 'genova quick tour.gmap'
# 'GETTING AND PROCESSING DECAM DATA.gdoc'
# "Gleason's Gym.gmap"
#  GMT2014.pdf
# 'Google Buzz'/
#  graded.csv
#  Guide_to_Chambliss_Judging_final_Dec_2014.pdf
#  GW.jpg
# 'hackathon flowchart.gdraw'
#  HalfSemestergradesMorning.png
# 'Hogg Bianco - NASA K2 Budget (1).xls'
# 'Hogg Bianco - NASA K2 Budget.xls'
#  HOMLPython.gdoc
#  house.gsheet
#  how_to_do_nonlinearWCS
# 'how to share google docs.gdoc'
#  HTIdrawings.png
#  Hubbleconstant.gdoc
#  HW5_s14.pdf
# 'Hypertemporal visible imaging of an urban lightscape can reveal the phase of the electrical grid granular to individual housing units.gdoc'
#  image.jpg
#  IMG_0008.MOV
#  IMG_0117.JPG
#  IMG_0118.JPG
#  IMG_0120.JPG
#  IMG_0229.TRIM.MOV
#  IMG_0316.JPG
#  IMG_0780.MOV
#  IMG_0782.MOV
#  IMG_0783.MOV
#  IMG_0867.JPG
#  IMG_0904.JPG
#  IMG_1716.JPG
#  IMG_1717.JPG
#  IMG_1718.JPG
#  IMG_1719.JPG
#  IMG_1720.JPG
#  IMG_1721.JPG
#  IMG_1722.JPG
#  IMG_1723.JPG
#  IMG_1810.JPG
#  IMG_1811.JPG
#  IMG_1812.JPG
#  IMG_1813.JPG
#  IMG_1814.JPG
#  IMG_1815.JPG
#  IMG_1816.JPG
#  IMG_1817.JPG
#  IMG_1818.JPG
#  IMG_1819.JPG
#  IMG_1890.JPG
#  IMG_20140218_180333.jpg
#  IMG_20140220_192020.jpg
#  IMG_20140221_091155.jpg
#  IMG_20140222_151214.jpg
#  IMG_20140222_151307.jpg
#  IMG_20140222_151309.jpg
#  IMG_20140222_151310.jpg
#  IMG_20140222_151316.jpg
#  IMG_20140222_151416.jpg
#  IMG_20140222_151424.jpg
#  IMG_20140222_171540.jpg
#  IMG_20140222_171541.jpg
#  IMG_20140222_171543.jpg
#  IMG_20140222_171549.jpg
#  IMG_20140222_171556.jpg
#  IMG_20140222_171617.jpg
#  IMG_20140222_172001.jpg
#  IMG_20140222_172142.jpg
#  IMG_20140222_172145.jpg
#  IMG_20140222_172202.jpg
#  IMG_20140222_172207.jpg
#  IMG_20140222_172211.jpg
#  IMG_20140222_173641.jpg
#  IMG_20140222_173916.jpg
#  IMG_20140222_173935.jpg
#  IMG_20140222_173948.jpg
#  IMG_20140222_173957.jpg
#  IMG_20140222_214808.jpg
#  IMG_20140222_214814.jpg
#  IMG_20140222_214817.jpg
#  IMG_20140223_081628.jpg
#  IMG_20140223_081633.jpg
#  IMG_20140223_140059.jpg
#  IMG_20140223_143529.jpg
# 'IMG_20140223_145213 (1).jpg'
#  IMG_20140223_145213.jpg
#  IMG_20190810_081044_exported_stabilized_215728302638536747.mp4
#  IMG_2177.jpg
#  IMG_2178.jpg
#  IMG_2182.jpg
#  IMG_2192-1.jpg
#  IMG_2192.jpg
#  IMG_3406.MOV
#  IMG_6180.MOV
#  IMG_8055.JPG
#  IMG_8056.JPG
#  IMG_8057.JPG
#  IMG_8058.JPG
#  IMG_8059.JPG
# 'IMG_8060 (1).JPG'
#  IMG_8060.JPG
#  IMG_8061.JPG
#  incubator_v3_ajc.docx
#  iraf.gdoc
# 'itg2014 (1)-1.pdf'
#  ItineraryReceipt_24704673402.pdf
# 'Job Description-LSSTCSCC 2015-Dec 1.docx'
# 'jobs 2016.gsheet'
# 'Julien Baur 4.1.18.docx'
# 'July2019 LSSTC executive board  SCs Advisory committee meeting.gdoc'
# 'KBO occultations: historical perspective.gdoc'
# 'KD comb scales spreadsheet.gsheet'
# 'Key numbers final.gdoc'
#  KOI42/
# 'L14 vs CfA.gsheet'
#  Label-327951343.pdf
#  LA.ipynb
#  LE_proposal2014A/
# 'Letter to recommand dissolution of MB.gdoc'
# 'LIHSP 2m observing.gdoc'
# 'LIHSP todo.gdoc'
# 'Linear Regression and OLS notes.gdoc'
# 'Live notes PST-SC chairs meeting 03 27.gdoc'
# 'local info flatiron.gdoc'
# 'LOI AccelNet LSST SCs.gdoc'
#  LSST/
# 'LSST 2018 TSO session.gdoc'
# 'LSST2019: Sci Collab Plenary Talks Tuesday.gslides'
# 'LSST2019: Sci Collab Plenary Talks Wednesday.gslides'
#  LSST2020_rationale_v02.docx
#  LSSTBrokerWorkshop19/
# 'LSST Cadence Hackathon at the Flatiron Institute.gdoc'
# 'LSST Cadence Hacks CCA, Flatiron Institute.gslides'
#  LSSTCCAHackathon/
# 'LSSTC Executive Board SC committee'/
# 'LSST Commissioning Input.gform'
# 'LSST for-scientists webpages feedback.gform'
# 'LSST IKCC.gdoc'
#  LSST_intro_public.pptx
# 'LSST organization.gslides'
# 'lsst.org feedback request .gdoc'
# 'LSST PST and Science Collaboration Chairs Telecon, Wednesday September 26, 2018.gdoc'
# 'LSST PST-SC meeting 02 27 19 notes.gdoc'
# 'LSST SC Accelnet prep form.gform'
# 'LSST SC Chairs accelnet call 02 11 2019.gdoc'
# 'LSST science 101.gslides'
# 'LSST Science Collaborations Status Report - updates August 2019.gslides'
# 'LSST science intro.gslides'
# 'LSSTSNRevolution2017 (1).ppt.gslides'
#  LSSTSNRevolution2017.key
#  LSSTSNRevolution2017.ppt
#  LSSTSNRevolution2017.ppt.gslides
# 'LSST SSSC chair election.gform'
# 'LSST SSSC chair nomination election.gform'
# 'LSST subgroups - Sheet1.gsheet'
# 'LSST TVS'/
# 'LSST TVS chair position.gdoc'
#  LSST-TVS-communicationAugust2016.gdoc
#  LSST_TVS_intro.pdf
# 'LSST TVS subgroup proposal.gform'
# 'LSST_TVS _template (1).key'
# 'LSST_TVS _template (1).kth'
# 'LSST_TVS _template (2).key'
# 'LSST_TVS _template.key'
# 'LSST_TVS _template.kth'
# 'lucia seminar participants.gsheet'
#  Lupton_LSST_PSTSAC_02272018_photometry.pdf
# 'lyman14 velocities.gsheet'
#  macho-taos.gsheet
#  manTrees.gsheet
# 'Mapping the Periphery and Variability of the Magellanic Clouds Olsen .gdoc'
# 'march 9th meeting notes.gdoc'
#  mariaFilippelliRecommandation.gdoc
#  maximizing-potential-lsst.pdf
# 'meeting mimutes template.gdoc'
#  meetingsg.csv
# 'meteor showers in 30 sec.gdoc'
# 'MHealth slides.gdoc'
# 'midterm hints.gdoc'
# 'MMA Cyberinfrastructure LSST call.gdoc'
#  Modjaz-NYUWomenChallenge.pdf
#  Modjaz-WomenNYUChallenge-Abstract.pdf
# 'monday grades.gsheet'
# 'monthly expenses.gsheet'
# 'movies (1).gsheet'
# 'movies (2).gsheet'
#  movies.csv
#  movies.gsheet
# 'moving expenses.gsheet'
# 'ms (1).pdf'
#  MS#ApJS94897.gdoc
#  ms.pdf
#  MVIMG_20190502_180146~2.jpg
#  N0060.pdf
#  N0061.pdf
#  N0080.pdf
#  N0139.pdf
#  N0139_thesisa.pdf
#  N0151.pdf
#  N0281.pdf
#  N0298.pdf
#  N0321.pdf
#  N0321_thesisa.pdf
#  N0386.pdf
#  NASPAA_LOI.gdoc
#  nbs/
# 'nebulae (1).gsheet'
#  nebulae.gdoc
#  nebulae.gsheet
# 'needed for home.gsheet'
# 'new house.gsheet'
# 'Non-Degenerate Eruptove Variables RoadMap.gdoc'
# 'NSF acknowledgement 2.gdoc'
# 'NSF acknowledgement.gdoc'
# 'NSF BIO_Bianco (1).docx'
# 'NSF BIO_Bianco2018.docx'
# 'NSF BIO_Bianco.docx'
# 'NSF BIO_Bianco.docx.gdoc'
#  nsf-biosketch.docx
# 'Nsf career academy.gdoc'
# 'NSF Career Grant proposal, F.gdoc'
#  NYCweatherAPI.py
# 'nyu computers .gsheet'
# 'NYU expenses 2013.gsheet'
# 'nyu letter head.gdoc'
#  NYUtemp-3long-BW.dotx
#  NYUtemp-3long-BW.dotx.gdoc
# 'NZReceipts (1).pdf'
#  NZReceipts.pdf
# 'OANDA exchange rate Australian Dollar to USD.gsheet'
#  ObjectIdentification_MinimalInfo.ods
#  ObjectIdentification_MinimalInfo.ods.gsheet
# 'obs astro fall 2013 '/
# 'obs log'/
#  occkey2014_annotated.pdf
#  oct08_2013-10-25-175504-6092.raw
# 'OSSOS conf call.gdoc'
#  otherAppsImage.jpg
# 'P1060076 (1).jpg'
#  P1060076.jpg
# 'Pages from ABB Book.pdf'
# 'PAGINA 18.pdf'
#  panel.gsheet
# 'Payment Confirmation.pdf'
#  Pbbfight/
#  PEP8_short.gdoc
# 'philly hip bars.gmap'
# 'photo (1).JPG'
#  photo.JPG
#  photometry.pdf
#  photos/
# 'PJ tweets presentation at Marron.gdoc'
#  PLAsTiCCmetrics.key
# 'Plumes slides.gdoc'
# 'Portions of the Slack conversations that may be useful.gdoc'
# 'PRANZO DEL 28.gdoc'
# 'preclass 12.gdoc'
# 'preclass assessment.gsheet'
# 'PRE-CLASS QUIZ PUI2017  Wednesday 10 11 2017.gdoc'
#  Presentation1.gslides
#  Presentation2.gslides
#  presto-colorEWASS19.key
# 'Probing the progenitors channels of stripped SN with the CfA SN sample..gdoc'
# 'Proposal Award Notification-Information Letter 2018-01 Bianco-Street.pdf'
#  proposal_budget_v3.ods
# 'PST Astrometric data products.gdoc'
# 'PTF09q SN 2009bh.gdoc'
# 'pubpolicy survey.gdoc'
#  PUI/
# 'PUI 2015 HW 1 M.gdoc'
# 'PUI 2015 HW 1 W.gdoc'
# 'PUI 2015 HW 3 M.gdoc'
# 'PUI 2015 HW 3 W.gdoc'
# 'PUI 2015 HW 4 W.gdoc'
# 'PUI 2015 HW 5 M W.gdoc'
# 'PUI2016 CLASS GRADES.gsheet'
#  PUI2016_quiz7.gdoc
# 'PUI2016_Tue (1).xlsx'
#  PUI2016_Tue.xlsx
# 'PUI2017final hints.gdoc'
# 'PUI2017final_zz1749 (1).ipynb'
#  PUI2017final_zz1749.ipynb
#  PUI2017grades.gsheet
# 'PUI2017_Morning_HW_1-5_Quiz_Grades (1).xlsx.gsheet'
#  PUI2017_Morning_HW_1-5_Quiz_Grades.xlsx
#  PUI2017_Morning_HW_1-5_Quiz_Grades.xlsx.gsheet
# 'Pui2017 quiz 11 30 PM.gdoc'
# 'PUI2017 quiz 5 Session 1 Wed 10 18 2071.gdoc'
# 'Pui2017 quiz 6 evening.gdoc'
# 'PUI2017quiz Thursday,11 30 2017 PM.gdoc'
# 'PUI2017 Session 1 Thu morning  10 18 2017.gdoc'
# 'PUI2018 Extra Credit Project Proposal.gdoc'
# 'PUI2018 Extra Credit Project Template.gdoc'
# 'PUI Final2018 hints'/
# 'PUI Grading evening.xlsx.gsheet'
# 'PUI midterm 2018'/
#  PUImidtermM2015.gsheet
# 'PUI non CUSP students .gdoc'
# 'Pui quiz 11 am.gdoc'
# 'PUI syllabus Fall 2015.gdoc'
#  PVZLDD.pdf
# 'pymcz referee report .gdoc'
#  Q1_DE-AR0000886_NYUBianco.key
#  Q3_DE-AR0000886_NYUBianco.key.zip
#  Q5_DE-AR0000886_NYUBianco.pdf
# 'Questionnaire (R).docx'
# 'ranking startup.gdoc'
#  ranks.gsheet
# 'reading list.gdoc'
#  references/
# 'repush date.PNG'
# 'research active WiPA-UD.gsheet'
# 'ResearchSummary blavatnikaward .gdoc'
#  residplot.py
# 'Response to Anonymous reviewer #1:.gdoc'
# 'Response to Anonymous reviewer #2.gdoc'
#  resume.gdoc
# 'Review or resubmission.gdoc'
#  rf.10813433.pdf
# 'RF meeting.gdoc'
#  Rhodes_SN.key
#  rstreet_support_letter_signed.pdf
# 'Santa Fe Institute App.docx'
# 'Santa Fe Institute App.docx.gdoc'
#  scan015.pdf
# 'SC Chairs meeting August 30th 2019.gdoc'
# 'SC content.gdoc'
# 'SC coordinator FBB.gdoc'
# 'Science Collaborations.pptx'
# 'Science Collaborations.pptx.gslides'
# 'Science Collaboration  White Paper Responses Federica Bianco Science Collaborations Coordinator  and the Science Collaboration Reps.gslides'
# 'Science Collaboration  White Paper Responses .gslides'
# 'science train.001.jpg'
# 'SCiMMA Data management, communication, and collaboration meeting 1.gdoc'
#  SCOPATONS:.gdoc
# 'Scott Hilberry reference.gdoc'
# 'Screen Shot 2014-06-23 at 3.53.47 PM.png'
# 'Screen Shot 2014-08-23 at 5.40.18 PM.png'
# 'Screen Shot 2015-04-23 at 3.37.05 PM.png'
# 'Screen Shot 2015-04-23 at 3.38.16 PM.png'
# 'Screen Shot 2016-01-17 at 5.21.42 PM.png'
# 'Screen Shot 2018-06-08 at 11.44.56 PM.png'
# 'Screen Shot 2019-05-02 at 11.39.54 PM.png'
# 'SC speakers PCW 2019.gsheet'
#  seamlesslyPoor.ipynb
# 'Searching for white dwarf transits with LSST  - Silvotti.gdoc'
#  Sedna_2013-01-10T05h09m02s.jpg
#  Sedna_2013-01-13T12h25m42s.jpg
# 'SETI LSST budget.gsheet'
# 'setting up my new mac mountainlion and ElCapitan.gdoc'
# 'shi recommendation.gdoc'
# 'Shutter setup'/
#  shutterstock_483529342.jpg
# 'SierraLeone_urban_observatory (1).pdf'
#  SierraLeone_urban_observatory.pdf
#  sky_separation.py
# 'slides and talks'/
#  sloth.mp4
#  SLSC.gdraw
#  smwlvsticker.gdraw
#  SN07gr.photometry_derived.png
#  sn1990B_Ic-norm_4_z_comp0001_snidflux.ps
#  sn2005eo_flux.dat
#  sn.gdoc
#  SN-syllabus.doc.gdoc
#  SN_w_max_Fe_measured.gdoc
#  SNYUqrcode_fancy
#  SNYUqrcode.png
# 'Sogno Berlino.gdoc'
#  Somayeh_Khakpash.mov
# 'Southern Poverty Law Center'/
# 'sparring class.docx'
# 'sparring class.pages'
# 'sparring class.pdf'
# 'SPL DATAKIND.gdoc'
# 'spring hackaton.gdoc'
# 'SQUID-Bike, Street Quality IDentification for citywide Bike Lane infrastructure (2).pdf'
#  ssscsticker.gdraw
#  startupsUD.ipynb
#  Stellar_Evolution_large.jpg
# 'stripped SN date of max from MC resampling.gdoc'
# 'subgroup presentations.gsheet'
# 'Summary Sci Collab activities and LSSTPCW2019 SC Plenary Talks.gslides'
#  Supernovae.zip
# 'Swift Cycle 11 NDA.pdf'
#  _system_appendPDF_proof_hi.pdf
# 'Talking Guerilla Science.pdf'
#  talks/
# 'Target  of  Opportunity  Observations  ofGravitational  Wave  Events  with  LSST Margutti.gdoc'
# 'TAs 2018.gsheet'
# 'TDEs  with  LSST Bricman.gdoc'
# 'TED fellow space show'/
# 'TED slides'/
#  test_dir/
#  test_python_access.gsheet
# 'The  Diverse  Science  Return  from  a  Wide-AreaSurvey  of  the  Galactic  Plane  - Street.gdoc'
# 'This project will work to assess the viability of social media, particularly twitter, as a meter to measure the response of the population to policy implementation in the prosecutorial justice sector.gdoc'
# "Tiffany Patafio's Personal Meeting Room-20181029 1702-1.arf"
# 'Tips on clustering.gdoc'
#  tmp.key
#  tobacco/
#  toms_and_brokers_lsst2018_fed.pdf
#  total_Ib_3_4_2_dh.ps
# 'transient chapter tables.gdoc'
#  transients_standalone.pdf
# 'Transients & Variable Stars SC - Blending impacts & metrics.gslides'
# 'Travel Expense Pre Authorization Form.docx'
# 'TVS 2019 Task Force Sign up.gform'
# 'TVS call 03 05 2018.gdoc'
# 'TVS conf call 01 23 2019.gdoc'
# 'TVS_full_list (1).gsheet'
# 'TVS_full_list_contact (1).csv'
# 'TVS_full_list_contact (1).csv.gsheet'
# 'TVS_full_list_contact (2).csv'
# 'TVS_full_list_contact (2).csv.gsheet'
#  TVS_full_list_contact.csv
#  TVS_full_list_contact.csv.gsheet
#  TVS_full_list.gsheet
#  TVS_full_list.numbers
#  TVS_full_list.xlsx
#  TVSlogo.gdraw
#  TVSlogolabel.gdraw
# 'TVS LSST@asia.gslides'
# 'TVS LSST cadence proposals.gdoc'
# 'TVS LSST call 10 20.gdoc'
# 'TVS metrics and survey cadence proposals.gslides'
# 'TVS publication report.gform'
# 'TVS roadmap blur.gdoc'
# 'TVS Roadmap Meeting Ride Share sign up.gsheet'
# 'TVS roadmap subgroups.gsheet'
# 'TVS Rodad Map March 2016 Schedule.gdoc'
# 'TVS-SMWLV meeting and hackathon 2019.gform'
# 'TVS-SMWLV meeting and hackathon 2019 (Responses).gsheet'
#  tvssticker.gdraw
# 'TVS Subgroup Leads Telecon 2019 July 1st.gdoc'
# 'TVS subgroup proposal.gform'
# 'TVS task force proposal 2019.gform'
# 'TVS task force proposal 2019 (Responses).gsheet'
# 'TVS White Paper Submissions.gsheet'
# 'TVS WP submissions.gsheet'
# 'UD-BNL Bianco Slosar  .gdoc'
#  udclass.key
# 'UD Fall hackathon 2019.gdoc'
# 'UD startup flexibility.gsheet'
#  UI4_PUI2018.key
# 'Unique  Science  from  a  Coordinated  LSST-WFIRSTSurvey  of  the  Galactic  Bulge Street.gdoc'
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (1).html'
# 'Untitled Diagram (2).html'
# 'Untitled Diagram (3).html'
# 'Untitled Diagram (4).html'
# 'Untitled Diagram (5).html'
# 'Untitled Diagram.drawio'
# 'Untitled Diagram.html'
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (22).gdoc'
# 'Untitled document (23).gdoc'
# 'Untitled document (24).gdoc'
# 'Untitled document (25).gdoc'
# 'Untitled document (26).gdoc'
# 'Untitled document (27).gdoc'
# 'Untitled document (28).gdoc'
# 'Untitled document (29).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (30).gdoc'
# 'Untitled document (31).gdoc'
# 'Untitled document (32).gdoc'
# 'Untitled document (33).gdoc'
# 'Untitled document (34).gdoc'
# 'Untitled document (35).gdoc'
# 'Untitled document (36).gdoc'
# 'Untitled document (37).gdoc'
# 'Untitled document (38).gdoc'
# 'Untitled document (39).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (40).gdoc'
# 'Untitled document (41).gdoc'
# 'Untitled document (42).gdoc'
# 'Untitled document (43).gdoc'
# 'Untitled document (44).gdoc'
# 'Untitled document (45).gdoc'
# 'Untitled document (46).gdoc'
# 'Untitled document (47).gdoc'
# 'Untitled document (48).gdoc'
# 'Untitled document (49).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (50).gdoc'
# 'Untitled document (51).gdoc'
# 'Untitled document (52).gdoc'
# 'Untitled document (53).gdoc'
# 'Untitled document (54).gdoc'
# 'Untitled document (55).gdoc'
# 'Untitled document (56).gdoc'
# 'Untitled document (57).gdoc'
# 'Untitled document (58).gdoc'
# 'Untitled document (59).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (60).gdoc'
# 'Untitled document (61).gdoc'
# 'Untitled document (62).gdoc'
# 'Untitled document (63).gdoc'
# 'Untitled document (64).gdoc'
# 'Untitled document (65).gdoc'
# 'Untitled document (66).gdoc'
# 'Untitled document (67).gdoc'
# 'Untitled document (68).gdoc'
# 'Untitled document (69).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (70).gdoc'
# 'Untitled document (71).gdoc'
# 'Untitled document (72).gdoc'
# 'Untitled document (73).gdoc'
# 'Untitled document (74).gdoc'
# 'Untitled document (75).gdoc'
# 'Untitled document (76).gdoc'
# 'Untitled document (77).gdoc'
# 'Untitled document (78).gdoc'
# 'Untitled document (79).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (80).gdoc'
# 'Untitled document (81).gdoc'
# 'Untitled document (82).gdoc'
# 'Untitled document (83).gdoc'
# 'Untitled document (84).gdoc'
# 'Untitled document (85).gdoc'
# 'Untitled document (86).gdoc'
# 'Untitled document (87).gdoc'
# 'Untitled document (88).gdoc'
# 'Untitled document (89).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (90).gdoc'
# 'Untitled document (91).gdoc'
# 'Untitled document (92).gdoc'
# 'Untitled document (93).gdoc'
# 'Untitled document (94).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled drawing (1).gdraw'
# 'Untitled drawing.gdraw'
# 'Untitled form (1).gform'
# 'Untitled form (2).gform'
# 'Untitled form (3).gform'
# 'Untitled form (4).gform'
# 'Untitled form (5).gform'
# 'Untitled form.gform'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation (2).gslides'
# 'Untitled presentation (3).gslides'
# 'Untitled presentation (4).gslides'
# 'Untitled presentation (5).gslides'
# 'Untitled presentation (6).gslides'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (10).gsheet'
# 'Untitled spreadsheet (11).gsheet'
# 'Untitled spreadsheet (12).gsheet'
# 'Untitled spreadsheet (13).gsheet'
# 'Untitled spreadsheet (14).gsheet'
# 'Untitled spreadsheet (15).gsheet'
# 'Untitled spreadsheet (16).gsheet'
# 'Untitled spreadsheet (17).gsheet'
# 'Untitled spreadsheet (18).gsheet'
# 'Untitled spreadsheet (19).gsheet'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled Spreadsheet (1).gsheet'
# 'Untitled spreadsheet (20).gsheet'
# 'Untitled spreadsheet (21).gsheet'
# 'Untitled spreadsheet (22).gsheet'
# 'Untitled spreadsheet (23).gsheet'
# 'Untitled spreadsheet (24).gsheet'
# 'Untitled spreadsheet (25).gsheet'
# 'Untitled spreadsheet (26).gsheet'
# 'Untitled spreadsheet (27).gsheet'
# 'Untitled spreadsheet (28).gsheet'
# 'Untitled spreadsheet (29).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled Spreadsheet (2).gsheet'
# 'Untitled spreadsheet (30).gsheet'
# 'Untitled spreadsheet (31).gsheet'
# 'Untitled spreadsheet (32).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet (8).gsheet'
# 'Untitled spreadsheet (9).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'Untitled Spreadsheet.gsheet'
# 'unVEil  the  darknesS  of  The  gAlactic  buLgE  (VESTALE) Bono   DallOra.gdoc'
# 'UO data acquisition.gsheet'
# 'UO Hypertemporal photometry of City Lights.gdoc'
#  uo.pptx
# 'UO storage.gsheet'
# 'Urban Metabolism studies: detection and tracking of building generated pollutant plumes.gdoc'
# 'US curriculum meeting.gdoc'
# 'UW (1).zip'
#  UW.zip
# 'vegan and veggy meals in philly.gmap'
#  velocity_2.png
#  velocity.pdf
#  VID_20140222_151219.mp4
#  VID_20190806_172853.mp4
# 'Vira comet.gdoc'
# 'Vision for a Data Science curriculum for Public Service.gdoc'
#  vphfe.gsheet
# 'wednesday grades.gsheet'
# 'Welcome message draft.gdoc'
# 'well sampled SESN lightcurves.gsheet'
#  wessoccs.zip
# 'Wiki to HTML flow.gdoc'
# 'WIPA-UD .gform'
#  workspaceswDECAMeta03a3.mov
# 'Wsession HW1-5.gsheet'
#  XHTDEE.pdf
# 'Xianbo Gao reference letter.pdf'
#  yana_fdnyshow2018.mov
#  Yuqian_appendicxA-D.gdoc
# 'yuqian reference letter.gdoc'
# 'ZHANG Lingyi Resume.pdf'

# %% [markdown]
# Some of the most common and useful are:
# * ls - list the files in the current directory
# * cp - copy one file to another
# * cd - change the directory
# * mv - rename (move) a file
# * mkdir - make a directory
# * rm - delete a file
# * rmdir - delete an empty directory
#
# Bear in mind **these are <u>not</u> python commands**, but jupyter understands them.  Here are some examples that
#
# 1. list the files in your google drive
# 2. make a directory, test_dir, in your Google Drive
# 3. copy a file from google drive, renaming it
# 4. moving that copy into test_dir
# 5. deleting the file from test_dit
# 6. deleting the test_dir directory
# 7. changing directories to your google drive
# 8. listing the files there
# 9. identifying your current working directory
# 10. getting back to your colaboratory home directory

# %% [markdown]
# Make a new directory (folder)

# %%
mkdir "drive/My Drive/test_dir"

# %%
ls -ltr "drive/My Drive" #-ltr prints the permissions on each file and sorts the files by date last opened/modified
# Out:
# total 8567038
# -rw------- 1 root root       151 Dec  9  2009  FD-II.gdoc
# -rw------- 1 root root       151 Dec 20  2009 'PRANZO DEL 28.gdoc'
# -rw------- 1 root root       151 Dec 26  2009  Fragment.tex.gdoc
# -rw------- 1 root root       151 Jan  8  2010 'Sogno Berlino.gdoc'
# -rw------- 1 root root       151 Apr 19  2010  DDT_HD187091.gdoc
# -rw------- 1 root root       151 Nov  9  2010 'LIHSP todo.gdoc'
# -rw------- 1 root root    144675 Jun 24  2011  FTN_20110623_Pluto_halflight.ps
# -rw------- 1 root root    111975 Jun 24  2011  FTN_20110623_Charon_boxcar.ps
# -rw------- 1 root root       151 Jul 28  2011  nebulae.gsheet
# -rw------- 1 root root       151 Jul 28  2011 'nebulae (1).gsheet'
# -rw------- 1 root root       151 Oct  5  2011 'aas membership.gsheet'
# -rw------- 1 root root       151 Mar  1  2012 'federica bianco -- funding request contingent upon better understanding of USF support system.gsheet'
# -rw------- 1 root root       151 Mar  6  2012 'federica bianco - computer needs.gdoc'
# -rw------- 1 root root       151 Mar  7  2012 'federica bianco computer needs.gsheet'
# -rw------- 1 root root       151 Mar 18  2012  berlusconi_eng.doc.gdoc
# -rw------- 1 root root     49788 Aug 20  2012  Sedna_2013-01-10T05h09m02s.jpg
# -rw------- 1 root root     57468 Aug 20  2012  Sedna_2013-01-13T12h25m42s.jpg
# -rw------- 1 root root       151 Sep 12  2012 'moving expenses.gsheet'
# -rw------- 1 root root       151 Sep 17  2012 'nyu computers .gsheet'
# -rw------- 1 root root       151 Sep 30  2012 'new house.gsheet'
# -rw------- 1 root root     56660 Oct  1  2012 'Payment Confirmation.pdf'
# -rw------- 1 root root       151 Oct 18  2012 'OSSOS conf call.gdoc'
# -rw------- 1 root root     90180 Nov 13  2012 'AAS - EDU cheatsheet.pdf'
# -rw------- 1 root root       151 Nov 26  2012 ' Federica Job Applications 2012 for tim.gsheet'
# -rw------- 1 root root       151 Nov 26  2012 'Federica Job Applications 2012.gsheet'
# -rw------- 1 root root       151 Feb 13  2013 '11fe summary.gdoc'
# -rw------- 1 root root       151 Feb 13  2013  iraf.gdoc
# -rw------- 1 root root       151 Feb 13  2013  sn.gdoc
# -rw------- 1 root root     15788 Mar  2  2013  CfA.SNIbc.BIGINFO.list.txt
# -rw------- 1 root root       151 Mar 18  2013 'eta light echoes in colors.gsheet'
# -rw------- 1 root root       151 Apr  3  2013  eta07_eta09.gsheet
# -rw------- 1 root root       151 Apr  4  2013 'eta DECAM coordinates.gsheet'
# -rw------- 1 root root       151 Jun 19  2013 'NYU expenses 2013.gsheet'
# -rw------- 1 root root       151 Jul 10  2013  SN-syllabus.doc.gdoc
# -rw------- 1 root root       151 Aug 13  2013 'AAS check list.gsheet'
# drwx------ 2 root root      4096 Sep  5  2013 'Google Buzz'/
# -rw------- 1 root root       151 Sep 13  2013 'aas 2011 austin costs.gsheet'
# -rw------- 1 root root       151 Sep 22  2013 'amazing women.gdoc'
# drwx------ 2 root root      4096 Sep 22  2013 'obs log'/
# -rw------- 1 root root       151 Sep 22  2013 'NSF acknowledgement.gdoc'
# -rw------- 1 root root       151 Sep 22  2013 'monthly expenses.gsheet'
# drwx------ 2 root root      4096 Oct  8  2013 'slides and talks'/
# -rw------- 1 root root       151 Nov 12  2013 'well sampled SESN lightcurves.gsheet'
# -rw------- 1 root root       151 Nov 25  2013 'NSF acknowledgement 2.gdoc'
# -rw------- 1 root root       151 Nov 25  2013  nebulae.gdoc
# -rw------- 1 root root      2288 Dec  2  2013  2013Jul15_obslog_0327.log
# drwx------ 2 root root      4096 Dec  2  2013 'obs astro fall 2013 '/
# -rw------- 1 root root     38463 Dec  4  2013  how_to_do_nonlinearWCS
# -rw------- 1 root root       151 Dec  9  2013  Hubbleconstant.gdoc
# -rw------- 1 root root       151 Dec  9  2013 'preclass 12.gdoc'
# -rw------- 1 root root      5520 Dec 13  2013  sn2005eo_flux.dat
# -rw------- 1 root root       151 Dec 16  2013 'LIHSP 2m observing.gdoc'
# -rw------- 1 root root       151 Dec 16  2013 'final 2013.gdoc'
# -rw------- 1 root root       151 Dec 16  2013 'Untitled spreadsheet (32).gsheet'
# -rw------- 1 root root    189742 Dec 17  2013 'AAS Poster Quaoar.jpg'
# -rw------- 1 root root       151 Dec 20  2013  CfA.SNIbc.BIGINFO_notused.gsheet
# -rw------- 1 root root       151 Jan  8  2014 'Copy of Occultation Key Project .gdoc'
# -rw------- 1 root root    982824 Jan 10  2014  occkey2014_annotated.pdf
# -rw------- 1 root root       151 Jan 13  2014 'Untitled spreadsheet (31).gsheet'
# -rw------- 1 root root     98288 Jan 17  2014 'itg2014 (1)-1.pdf'
# -rw------- 1 root root       151 Jan 21  2014 'Untitled spreadsheet (30).gsheet'
# -rw------- 1 root root   2858676 Feb  6  2014  total_Ib_3_4_2_dh.ps
# drwx------ 2 root root      4096 Feb 20  2014  KOI42/
# drwx------ 2 root root      4096 Feb 20  2014  LE_proposal2014A/
# -rw------- 1 root root    753113 Feb 23  2014  IMG_20140222_214817.jpg
# -rw------- 1 root root    865962 Feb 23  2014  IMG_20140220_192020.jpg
# -rw------- 1 root root   1147904 Feb 23  2014  IMG_20140222_171540.jpg
# -rw------- 1 root root    771921 Feb 23  2014  IMG_20140222_151214.jpg
# -rw------- 1 root root    647573 Feb 23  2014  IMG_20140222_172145.jpg
# -rw------- 1 root root    972078 Feb 23  2014  IMG_20140222_172142.jpg
# -rw------- 1 root root   1153614 Feb 23  2014  IMG_20140221_091155.jpg
# -rw------- 1 root root    790585 Feb 23  2014  IMG_20140223_081628.jpg
# -rw------- 1 root root   1026917 Feb 23  2014  IMG_20140222_173948.jpg
# -rw------- 1 root root    836213 Feb 23  2014  IMG_20140222_172211.jpg
# -rw------- 1 root root    614266 Feb 23  2014  IMG_20140222_151309.jpg
# -rw------- 1 root root   1090962 Feb 23  2014  IMG_20140222_173957.jpg
# -rw------- 1 root root     48977 Feb 23  2014  IMG_20140222_151424.jpg
# -rw------- 1 root root   1015513 Feb 23  2014  IMG_20140222_173916.jpg
# -rw------- 1 root root    894015 Feb 23  2014  IMG_20140222_171543.jpg
# -rw------- 1 root root     45235 Feb 23  2014  IMG_20140222_151416.jpg
# -rw------- 1 root root     96280 Feb 23  2014  IMG_20140218_180333.jpg
# -rw------- 1 root root    662471 Feb 23  2014  IMG_20140222_151307.jpg
# -rw------- 1 root root    872594 Feb 23  2014  IMG_20140223_081633.jpg
# -rw------- 1 root root    632032 Feb 23  2014  IMG_20140222_171556.jpg
# -rw------- 1 root root    954403 Feb 23  2014  IMG_20140222_171549.jpg
# -rw------- 1 root root    894592 Feb 23  2014  IMG_20140222_172202.jpg
# -rw------- 1 root root    884380 Feb 23  2014  IMG_20140222_173641.jpg
# -rw------- 1 root root    951802 Feb 23  2014  IMG_20140222_173935.jpg
# -rw------- 1 root root    983846 Feb 23  2014  IMG_20140222_171617.jpg
# -rw------- 1 root root    613815 Feb 23  2014  IMG_20140222_151310.jpg
# -rw------- 1 root root   1029796 Feb 23  2014  IMG_20140222_214814.jpg
# -rw------- 1 root root    960219 Feb 23  2014  IMG_20140222_171541.jpg
# -rw------- 1 root root    877602 Feb 23  2014  IMG_20140222_172207.jpg
# -rw------- 1 root root    788155 Feb 23  2014  IMG_20140222_172001.jpg
# -rw------- 1 root root    670857 Feb 23  2014  IMG_20140222_151316.jpg
# -rw------- 1 root root    995305 Feb 23  2014  IMG_20140222_214808.jpg
# -rw------- 1 root root  13891242 Feb 23  2014  VID_20140222_151219.mp4
# -rw------- 1 root root    912825 Feb 23  2014  IMG_20140223_143529.jpg
# -rw------- 1 root root    901382 Feb 23  2014  IMG_20140223_140059.jpg
# -rw------- 1 root root   1010925 Feb 23  2014 'IMG_20140223_145213 (1).jpg'
# -rw------- 1 root root   1010925 Feb 25  2014  IMG_20140223_145213.jpg
# -rw------- 1 root root       151 Mar  2  2014  behavpp.gslides
# -rw------- 1 root root     95212 Mar  4  2014  HW5_s14.pdf
# -rw------- 1 root root   1424702 Mar 17  2014  Supernovae.zip
# -rw------- 1 root root    398494 Mar 21  2014 'ms (1).pdf'
# -rw------- 1 root root       151 Mar 25  2014 'Untitled document (89).gdoc'
# -rw------- 1 root root   2240533 Mar 26  2014  image.jpg
# -rw------- 1 root root    642804 Mar 29  2014  photo.JPG
# -rw------- 1 root root   3399234 Mar 30  2014  IMG_0008.MOV
# -rw------- 1 root root       151 Apr  4  2014 'Chotard+ 2011.gslides'
# -rw------- 1 root root       151 Apr  7  2014 'Untitled presentation (6).gslides'
# -rw------- 1 root root       151 May  7  2014  MS#ApJS94897.gdoc
# -rw------- 1 root root    132888 May 10  2014 'photo (1).JPG'
# -rw------- 1 root root       151 May 15  2014 'Probing the progenitors channels of stripped SN with the CfA SN sample..gdoc'
# -rw------- 1 root root       151 May 29  2014 'eta car echoes meeting 04 23.gdoc'
# -rw------- 1 root root    245579 Jun 10  2014  Stellar_Evolution_large.jpg
# -rw------- 1 root root    654426 Jun 11  2014  wessoccs.zip
# -rw------- 1 root root       151 Jun 17  2014 'bianco+2014 answers.gdoc'
# -rw------- 1 root root       151 Jun 18  2014 'lyman14 velocities.gsheet'
# -rw------- 1 root root    389742 Jun 23  2014 'Screen Shot 2014-06-23 at 3.53.47 PM.png'
# -rw------- 1 root root       151 Jun 25  2014 'Untitled spreadsheet (25).gsheet'
# -rw------- 1 root root       151 Jun 30  2014 'Untitled spreadsheet (27).gsheet'
# -rw------- 1 root root    177091 Jul 26  2014  IMG_2177.jpg
# -rw------- 1 root root    242442 Jul 26  2014  IMG_2178.jpg
# -rw------- 1 root root    240141 Jul 26  2014  IMG_2182.jpg
# -rw------- 1 root root    723341 Jul 26  2014  IMG_2192.jpg
# -rw------- 1 root root    723341 Jul 26  2014  IMG_2192-1.jpg
# -rw------- 1 root root   6264978 Aug  2  2014  Rhodes_SN.key
# -rw------- 1 root root       151 Aug  6  2014 'meteor showers in 30 sec.gdoc'
# -rw------- 1 root root   1941672 Aug 10  2014  IMG_0904.JPG
# -rw------- 1 root root    689657 Aug 10  2014  IMG_0867.JPG
# -rw------- 1 root root       151 Aug 11  2014 'Copy of CfA.SNIbc.BIGINFO.list.gsheet'
# -rw------- 1 root root       151 Aug 13  2014 'Untitled document (90).gdoc'
# -rw------- 1 root root       151 Aug 14  2014 ' eta car echoes  TARGET LIST.gdoc'
# -rw------- 1 root root       151 Aug 21  2014 'OANDA exchange rate Australian Dollar to USD.gsheet'
# -rw------- 1 root root       151 Aug 23  2014  d11_dom.gsheet
# -rw------- 1 root root     33762 Aug 23  2014 'Screen Shot 2014-08-23 at 5.40.18 PM.png'
# -rw------- 1 root root       151 Aug 26  2014 'Untitled document (78).gdoc'
# -rw------- 1 root root      8751 Aug 27  2014  SN07gr.photometry_derived.png
# -rw------- 1 root root    386503 Oct  2  2014  SNYUqrcode_fancy
# -rw------- 1 root root      3117 Oct  2  2014  SNYUqrcode.png
# -rw------- 1 root root   2034677 Oct  4  2014  GMT2014.pdf
# -rw------- 1 root root       151 Oct  8  2014  vphfe.gsheet
# -rw------- 1 root root       151 Oct  8  2014  fevel.gsheet
# -rw------- 1 root root       151 Oct  8  2014 'Untitled Spreadsheet (2).gsheet'
# -rw------- 1 root root      1675 Oct  8  2014  comp_Fe_old_new.csv
# -rw------- 1 root root       151 Oct  8  2014  comp_Fe_old_new.gsheet
# -rw------- 1 root root    625308 Oct 26  2014  building-comprehensive-complete.zip
# -rw------- 1 root root       151 Nov  5  2014 'Untitled document (82).gdoc'
# -rw------- 1 root root       151 Nov  7  2014 'Untitled spreadsheet (28).gsheet'
# -rw------- 1 root root     26069 Nov  7  2014  2003VS2.png
# -rw------- 1 root root    222756 Nov 13  2014  11img-179017.png
# -rw------- 1 root root     71455 Nov 15  2014 'Swift Cycle 11 NDA.pdf'
# -rw------- 1 root root       151 Nov 19  2014 'fed job apps 2014-5 HOGG.gsheet'
# -rw------- 1 root root       151 Dec  4  2014 'Untitled spreadsheet (20).gsheet'
# -rw------- 1 root root       151 Dec 13  2014  panel.gsheet
# -rw------- 1 root root       151 Dec 17  2014 'Untitled Spreadsheet (1).gsheet'
# -rw------- 1 root root       151 Dec 28  2014 'fed job apps 2014-5.gsheet'
# -rw------- 1 root root       151 Dec 30  2014 'fed job apps 2014-5 - Charles.gsheet'
# -rw------- 1 root root    234426 Jan  1  2015  Guide_to_Chambliss_Judging_final_Dec_2014.pdf
# -rw------- 1 root root       151 Jan  5  2015 'Untitled spreadsheet (24).gsheet'
# -rw------- 1 root root       151 Jan 13  2015 'Untitled document (79).gdoc'
# -rw------- 1 root root       151 Jan 16  2015 'L14 vs CfA.gsheet'
# -rw------- 1 root root    524798 Jan 19  2015 'science train.001.jpg'
# -rw------- 1 root root     58354 Feb  1  2015  Abundance_Maryam_29_Aug13.pro
# -rw------- 1 root root     32768 Feb  3  2015  Bianco--1-26-2015.doc
# -rw------- 1 root root       151 Feb  6  2015 'KBO occultations: historical perspective.gdoc'
# -rw------- 1 root root       151 Feb  6  2015 'Untitled document (63).gdoc'
# -rw------- 1 root root       151 Feb 17  2015 'Untitled spreadsheet (19).gsheet'
# -rw------- 1 root root       151 Feb 26  2015 'how to share google docs.gdoc'
# -rw------- 1 root root       151 Mar  2  2015 'lucia seminar participants.gsheet'
# -rw------- 1 root root       151 Mar  3  2015  fbbresume.gdoc
# -rw------- 1 root root    999471 Mar  3  2015  Label-327951343.pdf
# -rw------- 1 root root       151 Mar  3  2015 'Untitled document (64).gdoc'
# -rw------- 1 root root       151 Mar 10  2015 'fed job apps 2014-5 Andy.gsheet'
# -rw------- 1 root root       151 Mar 11  2015 'Untitled document (72).gdoc'
# -rw------- 1 root root    669434 Mar 19  2015 'UW (1).zip'
# -rw------- 1 root root       151 Mar 24  2015  Abundance_Maryam_29_Aug13.pro.gdoc
# -rw------- 1 root root    669434 Mar 27  2015  UW.zip
# -rw------- 1 root root       151 Apr  2  2015 'KD comb scales spreadsheet.gsheet'
# -rw------- 1 root root   2420580 Apr  6  2015  P1060076.jpg
# -rw------- 1 root root   2420580 Apr  6  2015 'P1060076 (1).jpg'
# -rw------- 1 root root         0 Apr  6  2015  IMG_0780.MOV
# -rw------- 1 root root         0 Apr  6  2015  IMG_0782.MOV
# -rw------- 1 root root         0 Apr  6  2015  IMG_0783.MOV
# -rw------- 1 root root       151 Apr  9  2015 'Abundance_Maryam_29_Aug13 (1).pro.gdoc'
# -rw------- 1 root root       151 Apr 16  2015 'Untitled document (58).gdoc'
# -rw------- 1 root root       151 Apr 22  2015 'Boxing Answers .gdoc'
# -rw------- 1 root root    306757 Apr 27  2015 'Screen Shot 2015-04-23 at 3.38.16 PM.png'
# -rw------- 1 root root    307695 Apr 27  2015 'Screen Shot 2015-04-23 at 3.37.05 PM.png'
# -rw------- 1 root root     29594 May  7  2015  sn1990B_Ic-norm_4_z_comp0001_snidflux.ps
# -rw------- 1 root root      2776 May  8  2015  bootplot4.py
# -rw------- 1 root root      4288 May  8  2015  residplot.py
# -rw------- 1 root root     98954 May 13  2015  otherAppsImage.jpg
# -rw------- 1 root root    356486 May 14  2015 'PAGINA 18.pdf'
# -rw------- 1 root root   1652482 May 18  2015  ms.pdf
# -rw------- 1 root root     50396 May 25  2015  5.25.pdf
# -rw------- 1 root root     36164 Jun  5  2015  ObjectIdentification_MinimalInfo.ods
# -rw------- 1 root root       151 Jun  5  2015  ObjectIdentification_MinimalInfo.ods.gsheet
# -rw------- 1 root root       119 Jun  6  2015 'vegan and veggy meals in philly.gmap'
# -rw------- 1 root root       119 Jun  6  2015 'philly hip bars.gmap'
# -rw------- 1 root root       119 Jun  6  2015 "Gleason's Gym.gmap"
# -rw------- 1 root root    323864 Jun  9  2015  11bov.pdf
# -rw------- 1 root root     76800 Jun 25  2015 'Hogg Bianco - NASA K2 Budget (1).xls'
# -rw------- 1 root root     76800 Jun 28  2015 'Hogg Bianco - NASA K2 Budget.xls'
# -rw------- 1 root root       151 Jun 29  2015  fbb_K2_biosketch.gdoc
# -rw------- 1 root root       151 Jun 29  2015 'Untitled document (60).gdoc'
# -rw------- 1 root root    425264 Jun 29  2015  rstreet_support_letter_signed.pdf
# -rw------- 1 root root     89871 Jun 29  2015  FBB_collab_letter.pdf
# -rw------- 1 root root       151 Jun 30  2015 'Untitled document (61).gdoc'
# -rw------- 1 root root       151 Jul  9  2015 'US curriculum meeting.gdoc'
# -rw------- 1 root root       151 Jul 13  2015 'Dear Editors of Astronomy&Computing,.gdoc'
# -rw------- 1 root root   2707858 Jul 17  2015  scan015.pdf
# -rw------- 1 root root       151 Jul 23  2015  macho-taos.gsheet
# -rw------- 1 root root       151 Jul 24  2015 'Untitled Spreadsheet.gsheet'
# -rw------- 1 root root     51306 Jul 25  2015  etaspec14A.fed.tex
# -rw------- 1 root root  13886349 Jul 31  2015  workspaceswDECAMeta03a3.mov
# -rw------- 1 root root   1011062 Aug 17  2015  IMG_6180.MOV
# -rw------- 1 root root       151 Aug 19  2015 'GETTING AND PROCESSING DECAM DATA.gdoc'
# -rw------- 1 root root       151 Aug 25  2015 'RF meeting.gdoc'
# -rw------- 1 root root       151 Sep  7  2015 'Untitled spreadsheet.gsheet'
# -rw------- 1 root root       151 Sep 16  2015  co_fed.gdoc
# -rw------- 1 root root       151 Sep 27  2015  CfA.SNIbc.BIGINFO.list.gsheet
# -rw------- 1 root root       151 Sep 29  2015 'PUI 2015 HW 3 M.gdoc'
# -rw------- 1 root root       151 Sep 29  2015 'PUI 2015 HW 3 W.gdoc'
# -rw------- 1 root root     53185 Sep 30  2015  NYUtemp-3long-BW.dotx
# -rw------- 1 root root       151 Sep 30  2015  NYUtemp-3long-BW.dotx.gdoc
# -rw------- 1 root root       151 Oct  9  2015 'PUI 2015 HW 4 W.gdoc'
# -rw------- 1 root root       151 Oct 15  2015 'PUI 2015 HW 5 M W.gdoc'
# -rw------- 1 root root       151 Oct 26  2015 'midterm hints.gdoc'
# -rw------- 1 root root       119 Oct 28  2015 'genova quick tour.gmap'
# -rw------- 1 root root       151 Nov  1  2015 'Untitled spreadsheet (2).gsheet'
# -rw------- 1 root root     36014 Nov  5  2015 'repush date.PNG'
# -rw------- 1 root root       151 Nov  7  2015 'LSST TVS chair position.gdoc'
# -rw------- 1 root root       151 Nov  9  2015  PUImidtermM2015.gsheet
# -rw------- 1 root root    139278 Nov 15  2015  fb_teaching.pdf
# -rw------- 1 root root       151 Nov 17  2015 'Untitled document (5).gdoc'
# -rw------- 1 root root     65481 Nov 19  2015  XHTDEE.pdf
# -rw------- 1 root root       151 Nov 20  2015 'transient chapter tables.gdoc'
# -rw------- 1 root root       151 Nov 20  2015 'Untitled document (54).gdoc'
# -rw------- 1 root root       151 Dec  1  2015 'application season 2015.gsheet'
# drwx------ 2 root root      4096 Dec  3  2015  __appdata__/
# -rw------- 1 root root       151 Dec  4  2015 'UO Hypertemporal photometry of City Lights.gdoc'
# -rw------- 1 root root      5159 Dec  4  2015 'application season 2015.xlsx'
# -rw------- 1 root root       151 Dec  7  2015 'pymcz referee report .gdoc'
# -rw------- 1 root root       151 Dec 16  2015 'Response to Anonymous reviewer #1:.gdoc'
# -rw------- 1 root root       151 Dec 16  2015 'Response to Anonymous reviewer #2.gdoc'
# -rw------- 1 root root       151 Jan  9  2016 'astro 101 2013 grades.gsheet'
# -rw------- 1 root root       151 Jan 14  2016 'Wsession HW1-5.gsheet'
# -rw------- 1 root root     23223 Jan 15  2016  velocity.pdf
# -rw------- 1 root root    966900 Jan 17  2016 'Screen Shot 2016-01-17 at 5.21.42 PM.png'
# -rw------- 1 root root       151 Jan 21  2016 'ResearchSummary blavatnikaward .gdoc'
# -rw------- 1 root root       151 Jan 28  2016 'Scott Hilberry reference.gdoc'
# -rw------- 1 root root       151 Feb  3  2016 'nyu letter head.gdoc'
# -rw------- 1 root root       151 Feb  3  2016 'shi recommendation.gdoc'
# -rw------- 1 root root       151 Feb  6  2016 'yuqian reference letter.gdoc'
# -rw------- 1 root root       151 Feb  6  2016 'PTF09q SN 2009bh.gdoc'
# -rw------- 1 root root       151 Feb  8  2016 'TVS Rodad Map March 2016 Schedule.gdoc'
# -rw------- 1 root root       151 Feb  9  2016 'TVS roadmap blur.gdoc'
# -rw------- 1 root root       151 Feb  9  2016 'spring hackaton.gdoc'
# -rw------- 1 root root    184192 Feb 10  2016  TVS_full_list.numbers
# -rw------- 1 root root    497337 Feb 10  2016  TVS_full_list.xlsx
# -rw------- 1 root root       151 Feb 10  2016  TVS_full_list.gsheet
# -rw------- 1 root root       151 Feb 10  2016 'TVS_full_list (1).gsheet'
# -rw------- 1 root root       151 Feb 10  2016 'LSST subgroups - Sheet1.gsheet'
# -rw------- 1 root root   5126096 Feb 10  2016 'Pages from ABB Book.pdf'
# -rw------- 1 root root       151 Feb 11  2016  AS4_TDA_Nov2015_20160119notes_ecb.docx.gdoc
# -rw------- 1 root root     31274 Feb 11  2016  AS4_TDA_20160211.docx
# -rw------- 1 root root   1533249 Feb 12  2016  GW.jpg
# -rw------- 1 root root       151 Feb 25  2016 'setting up my new mac mountainlion and ElCapitan.gdoc'
# -rw------- 1 root root       151 Feb 26  2016 'TVS roadmap subgroups.gsheet'
# -rw------- 1 root root       151 Feb 26  2016 'Ejecta mass Phot Analysis paper outline 2015-16.gdoc'
# -rw------- 1 root root       151 Feb 28  2016 'Vira comet.gdoc'
# -rw------- 1 root root     56820 Mar 10  2016  velocity_2.png
# -rw------- 1 root root     13798 Mar 14  2016  TVS_full_list_contact.csv
# -rw------- 1 root root       151 Mar 15  2016 'TVS_full_list_contact (2).csv.gsheet'
# -rw------- 1 root root     14088 Mar 15  2016 'TVS_full_list_contact (1).csv'
# -rw------- 1 root root       151 Mar 15  2016  TVS_full_list_contact.csv.gsheet
# -rw------- 1 root root     14480 Mar 15  2016 'TVS_full_list_contact (2).csv'
# -rw------- 1 root root      2208 Mar 15  2016  meetingsg.csv
# -rw------- 1 root root       151 Mar 17  2016 'stripped SN date of max from MC resampling.gdoc'
# -rw------- 1 root root       151 Mar 17  2016  SN_w_max_Fe_measured.gdoc
# -rw------- 1 root root     49250 Mar 20  2016  Modjaz-WomenNYUChallenge-Abstract.pdf
# -rw------- 1 root root    432229 Mar 20  2016  Modjaz-NYUWomenChallenge.pdf
# -rw------- 1 root root       151 Mar 24  2016 'subgroup presentations.gsheet'
# -rw------- 1 root root       151 Mar 25  2016 'Untitled document (11).gdoc'
# -rw------- 1 root root       151 Mar 25  2016 'TVS Roadmap Meeting Ride Share sign up.gsheet'
# -rw------- 1 root root       151 Mar 25  2016 'Non-Degenerate Eruptove Variables RoadMap.gdoc'
# -rw------- 1 root root       151 Mar 25  2016 'TVS_full_list_contact (1).csv.gsheet'
# -rw------- 1 root root       151 Mar 28  2016 'monday grades.gsheet'
# -rw------- 1 root root       151 Apr  3  2016  test_python_access.gsheet
# -rw------- 1 root root    269100 Apr  7  2016  transients_standalone.pdf
# -rw------- 1 root root       151 Apr  8  2016  Yuqian_appendicxA-D.gdoc
# -rw------- 1 root root       151 Apr 19  2016 'Untitled presentation.gslides'
# drwx------ 2 root root      4096 Apr 20  2016  filament/
# -rw------- 1 root root       151 Apr 25  2016 'Untitled document (14).gdoc'
# -rw------- 1 root root    501868 May 13  2016  ESB_119.75_camera4_50ms_1999_1706.GIF
# -rw------- 1 root root  71448184 Jun  3  2016 'LSST_TVS _template (2).key'
# -rw------- 1 root root   2314544 Jun  5  2016  IMG_0316.JPG
# -rw------- 1 root root  71445709 Jun  6  2016 'LSST_TVS _template (1).kth'
# -rw------- 1 root root  71545977 Jun  6  2016 'LSST_TVS _template (1).key'
# -rw------- 1 root root  73013352 Jun  7  2016 'LSST_TVS _template.kth'
# -rw------- 1 root root  73013773 Jun  7  2016 'LSST_TVS _template.key'
# -rw------- 1 root root       151 Jun 29  2016 'Untitled document (10).gdoc'
# dr-x------ 2 root root      4096 Jul  4  2016  Pbbfight/
# -rw------- 1 root root 647900664 Jul  4  2016 'Fed and Kim.mp4'
# -rw------- 1 root root 137243311 Jul  4  2016  00104.mov
# -rw------- 1 root root 124444801 Jul  4  2016  00103.mov
# -rw------- 1 root root 121389988 Jul  4  2016  00102.mov
# -rw------- 1 root root 121478075 Jul  4  2016  00101.mov
# -rw------- 1 root root       151 Jul 12  2016 'Untitled document (94).gdoc'
# -rw------- 1 root root       151 Jul 13  2016 'Untitled document (93).gdoc'
# -rw------- 1 root root     94902 Jul 17  2016 'Talking Guerilla Science.pdf'
# -rw------- 1 root root       151 Jul 18  2016  SCOPATONS:.gdoc
# -rw------- 1 root root       151 Jul 21  2016 'Untitled document (92).gdoc'
# -rw------- 1 root root       151 Jul 27  2016 'Untitled document (91).gdoc'
# -rw------- 1 root root       151 Aug  6  2016 'Wiki to HTML flow.gdoc'
# -rw------- 1 root root     72409 Aug 17  2016  PVZLDD.pdf
# -rw------- 1 root root       151 Aug 21  2016 'Untitled document (88).gdoc'
# -rw------- 1 root root       151 Aug 22  2016 'Untitled document (87).gdoc'
# -rw------- 1 root root       151 Aug 24  2016 'Untitled document (86).gdoc'
# -rw------- 1 root root       151 Aug 26  2016 'Untitled document (85).gdoc'
# -rw------- 1 root root       151 Sep  2  2016 'PUI syllabus Fall 2015.gdoc'
# -rw------- 1 root root       151 Sep  3  2016  LSST-TVS-communicationAugust2016.gdoc
# -rw------- 1 root root       151 Sep  4  2016  PEP8_short.gdoc
# -rw------- 1 root root    695388 Sep  7  2016  File_000.jpeg
# -rw------- 1 root root       151 Sep 10  2016 'preclass assessment.gsheet'
# -rw------- 1 root root       151 Sep 14  2016 'UO data acquisition.gsheet'
# -rw------- 1 root root       151 Sep 14  2016 'UO storage.gsheet'
# -rw------- 1 root root       151 Sep 15  2016 'Untitled spreadsheet (29).gsheet'
# -rw------- 1 root root       151 Sep 27  2016 'Untitled document (84).gdoc'
# -rw------- 1 root root       151 Oct  7  2016 'Camping graucery list.gdoc'
# -rw------- 1 root root       151 Oct 12  2016 'Untitled document (83).gdoc'
# -rw------- 1 root root       151 Oct 12  2016 'Untitled document (81).gdoc'
# -rw------- 1 root root     24104 Oct 13  2016 'Travel Expense Pre Authorization Form.docx'
# -rw------- 1 root root       151 Oct 18  2016  mariaFilippelliRecommandation.gdoc
# -rw------- 1 root root       151 Oct 20  2016 'Untitled spreadsheet (26).gsheet'
# -rw------- 1 root root       151 Oct 20  2016 'TVS LSST call 10 20.gdoc'
# -rw------- 1 root root  26803274 Oct 25  2016  LSST_TVS_intro.pdf
# -rw------- 1 root root       151 Oct 28  2016 'TVS LSST cadence proposals.gdoc'
# -rw------- 1 root root       151 Oct 28  2016 'Untitled document (80).gdoc'
# -rw------- 1 root root   1559873 Nov  1  2016  N0386.pdf
# -rw------- 1 root root     24601 Nov  1  2016  N0321_thesisa.pdf
# -rw------- 1 root root   1665573 Nov  1  2016  N0321.pdf
# -rw------- 1 root root    380309 Nov  1  2016  N0298.pdf
# -rw------- 1 root root    212168 Nov  1  2016  N0281.pdf
# -rw------- 1 root root   1271871 Nov  1  2016  N0151.pdf
# -rw------- 1 root root     26981 Nov  1  2016  N0139_thesisa.pdf
# -rw------- 1 root root   1315061 Nov  1  2016  N0139.pdf
# -rw------- 1 root root   5585865 Nov  1  2016  N0080.pdf
# -rw------- 1 root root 153735373 Nov  1  2016  N0061.pdf
# -rw------- 1 root root   1138286 Nov  1  2016  N0060.pdf
# -rw------- 1 root root       151 Nov  2  2016 'Untitled document (77).gdoc'
# -rw------- 1 root root       151 Nov  3  2016 'Untitled document (76).gdoc'
# -rw------- 1 root root     24158 Nov 18  2016 'PUI2016_Tue (1).xlsx'
# -rw------- 1 root root       151 Nov 19  2016 'Untitled spreadsheet (23).gsheet'
# -rw------- 1 root root       151 Nov 19  2016 'Untitled spreadsheet (22).gsheet'
# -rw------- 1 root root       151 Nov 25  2016 'Untitled spreadsheet (21).gsheet'
# -rw------- 1 root root       151 Nov 29  2016 'Untitled document (75).gdoc'
# -rw------- 1 root root       151 Nov 29  2016 'Untitled document (74).gdoc'
# -rw------- 1 root root       151 Dec  4  2016 'jobs 2016.gsheet'
# -rw------- 1 root root       151 Dec  6  2016 'Untitled document (73).gdoc'
# -rw------- 1 root root      9010 Dec  8  2016  carousel_image_fb084d49f0320057c720_DSC_0777.JPG
# -rw------- 1 root root       151 Dec  8  2016  PUI2016_quiz7.gdoc
# -rw------- 1 root root   1242329 Dec 12  2016  maximizing-potential-lsst.pdf
# -rw------- 1 root root       151 Dec 13  2016 'Untitled document (71).gdoc'
# -rw------- 1 root root       151 Dec 13  2016 'wednesday grades.gsheet'
# -rw------- 1 root root       151 Dec 17  2016 'census tracts geoid hint.gdoc'
# -rw------- 1 root root       151 Dec 17  2016 'Portions of the Slack conversations that may be useful.gdoc'
# -rw------- 1 root root     21817 Dec 22  2016  PUI2016_Tue.xlsx
# -rw------- 1 root root     15184 Dec 22  2016  rf.10813433.pdf
# -rw------- 1 root root       151 Dec 25  2016 'Untitled document (70).gdoc'
# -rw------- 1 root root       151 Dec 26  2016 'PUI2016 CLASS GRADES.gsheet'
# -rw------- 1 root root  26542080 Jan 18  2017  oct08_2013-10-25-175504-6092.raw
# -rw------- 1 root root       151 Feb 10  2017 'Untitled document (69).gdoc'
# -rw------- 1 root root    701147 Feb 12  2017 'sparring class.pages'
# -rw------- 1 root root    359720 Feb 12  2017 'sparring class.pdf'
# -rw------- 1 root root    869213 Feb 12  2017 'sparring class.docx'
# drwx------ 2 root root      4096 Feb 25  2017 'Shutter setup'/
# -rw------- 1 root root       151 Mar  4  2017 'Untitled document (68).gdoc'
# -rw------- 1 root root  32291366 Mar  4  2017 'NZReceipts (1).pdf'
# -rw------- 1 root root  32291366 Mar  4  2017  NZReceipts.pdf
# -rw------- 1 root root       151 Mar  4  2017 'Untitled document (67).gdoc'
# -rw------- 1 root root       151 Mar  4  2017 'Untitled document (66).gdoc'
# -rw------- 1 root root       151 Mar  6  2017 'Untitled document (65).gdoc'
# -rw------- 1 root root       151 Mar 13  2017 'DTU17 classification data challenge.gdoc'
# -rw------- 1 root root       151 Mar 17  2017 'NSF BIO_Bianco.docx.gdoc'
# -rw------- 1 root root     13383 Mar 21  2017 'NSF BIO_Bianco (1).docx'
# -rw------- 1 root root       151 Mar 25  2017 'Untitled document (62).gdoc'
# -rw------- 1 root root       151 Apr 13  2017 'Untitled presentation (5).gslides'
# -rw------- 1 root root    132731 Apr 13  2017  CSIAgenda4.12.17.pdf
# -rw------- 1 root root       151 Apr 14  2017 'Untitled form (5).gform'
# -rw------- 1 root root       151 Apr 17  2017 'Welcome message draft.gdoc'
# -rw------- 1 root root  85104199 May 11  2017 'File May 11, 12 35 26 PM.mov'
# -rw------- 1 root root     67873 Jun  9  2017  ItineraryReceipt_24704673402.pdf
# -rw------- 1 root root  64361458 Jul 14  2017  PLAsTiCCmetrics.key
# -rw------- 1 root root  27073632 Jul 29  2017 'SQUID-Bike, Street Quality IDentification for citywide Bike Lane infrastructure (2).pdf'
# -rw------- 1 root root       151 Sep 13  2017 'PUI 2015 HW 1 W.gdoc'
# drwx------ 3 root root      4096 Sep 13  2017 'Southern Poverty Law Center'/
# -rw------- 1 root root       151 Sep 21  2017 'Untitled document (59).gdoc'
# drwx------ 2 root root      4096 Sep 21  2017 'class quiz'/
# -rw------- 1 root root       151 Sep 26  2017 'SPL DATAKIND.gdoc'
# -rw------- 1 root root       151 Sep 30  2017 'SC coordinator FBB.gdoc'
# -rw------- 1 root root       151 Oct 11  2017 'PRE-CLASS QUIZ PUI2017  Wednesday 10 11 2017.gdoc'
# -rw------- 1 root root       151 Oct 13  2017 'Untitled document (57).gdoc'
# -rw------- 1 root root       151 Oct 16  2017 'PUI 2015 HW 1 M.gdoc'
# -rw------- 1 root root       151 Oct 18  2017 'PUI2017 quiz 5 Session 1 Wed 10 18 2071.gdoc'
# -rw------- 1 root root       151 Oct 18  2017 'Linear Regression and OLS notes.gdoc'
# -rw------- 1 root root       151 Oct 19  2017 'PUI2017 Session 1 Thu morning  10 18 2017.gdoc'
# -rw------- 1 root root       151 Oct 21  2017 'reading list.gdoc'
# -rw------- 1 root root       151 Oct 26  2017 'Untitled document (56).gdoc'
# -rw------- 1 root root       151 Oct 26  2017 'Untitled document (55).gdoc'
# -rw------- 1 root root       151 Oct 26  2017 'Untitled spreadsheet (18).gsheet'
# -rw------- 1 root root       151 Nov  2  2017 'Untitled spreadsheet (17).gsheet'
# drwx------ 2 root root      4096 Nov  2  2017  talks/
# -rw------- 1 root root   9941504 Nov  2  2017  LSSTSNRevolution2017.ppt
# -rw------- 1 root root  10425216 Nov  2  2017  LSSTSNRevolution2017.key
# -rw------- 1 root root       151 Nov  2  2017 'LSSTSNRevolution2017 (1).ppt.gslides'
# -rw------- 1 root root   3392818 Nov  3  2017 'Science Collaborations.pptx'
# -rw------- 1 root root       151 Nov  3  2017 'Science Collaborations.pptx.gslides'
# -rw------- 1 root root       151 Nov  3  2017  LSSTSNRevolution2017.ppt.gslides
# -rw------- 1 root root 197479472 Nov  3  2017  uo.pptx
# drwx------ 2 root root      4096 Nov  3  2017  Fed/
# drwx------ 2 root root      4096 Nov  3  2017  Fed2/
# -rw------- 1 root root 449918726 Nov  3  2017  LSST_intro_public.pptx
# drwx------ 2 root root      4096 Nov  4  2017  nbs/
# -rw------- 1 root root      7639 Nov  6  2017  PUI2017_Morning_HW_1-5_Quiz_Grades.xlsx
# -rw------- 1 root root       151 Nov  6  2017 'PUI2017_Morning_HW_1-5_Quiz_Grades (1).xlsx.gsheet'
# -rw------- 1 root root       151 Nov  6  2017  PUI2017_Morning_HW_1-5_Quiz_Grades.xlsx.gsheet
# -rw------- 1 root root       151 Nov  6  2017 'PUI Grading evening.xlsx.gsheet'
# -rw------- 1 root root       151 Nov 15  2017 'Untitled document.gdoc'
# -rw------- 1 root root    174751 Nov 26  2017  bookmarks_11_26_17.html
# -rw------- 1 root root       151 Nov 30  2017 'Untitled document (1).gdoc'
# -rw------- 1 root root       151 Nov 30  2017 'Pui2017 quiz 11 30 PM.gdoc'
# -rw------- 1 root root       151 Nov 30  2017 'PUI2017quiz Thursday,11 30 2017 PM.gdoc'
# -rw------- 1 root root     49639 Dec  2  2017 'BEST HACK (1).pdf'
# -rw------- 1 root root       151 Dec 14  2017 'Tips on clustering.gdoc'
# -rw------- 1 root root       151 Dec 15  2017 'PUI2017final hints.gdoc'
# -rw------- 1 root root       151 Dec 18  2017 'Untitled document (2).gdoc'
# -rw------- 1 root root       151 Dec 23  2017 'Untitled spreadsheet (1).gsheet'
# -rw------- 1 root root  53287493 Dec 24  2017  PUI2017final_zz1749.ipynb
# -rw------- 1 root root  53287493 Dec 24  2017 'PUI2017final_zz1749 (1).ipynb'
# -rw------- 1 root root       151 Jan  5  2018 'Untitled document (3).gdoc'
# -rw------- 1 root root       151 Jan  5  2018 'Untitled document (4).gdoc'
# drwx------ 2 root root      4096 Jan 23  2018  references/
# drwx------ 2 root root      4096 Jan 23  2018  PUI/
# drwx------ 2 root root      4096 Jan 24  2018  CUSP/
# -rw------- 1 root root       151 Jan 24  2018  FBBshortCV.gdoc
# -rw------- 1 root root    149248 Jan 28  2018 'Santa Fe Institute App.docx'
# -rw------- 1 root root       151 Jan 28  2018 'Santa Fe Institute App.docx.gdoc'
# -rw------- 1 root root    472988 Jan 29  2018 'Julien Baur 4.1.18.docx'
# -rw------- 1 root root       151 Feb  2  2018  fbb_UD.gdoc
# -rw------- 1 root root     21653 Feb  2  2018 'NSF BIO_Bianco.docx'
# -rw------- 1 root root       151 Feb  2  2018 'Untitled document (6).gdoc'
# -rw------- 1 root root       151 Feb  2  2018 'Untitled drawing.gdraw'
# -rw------- 1 root root       151 Feb  3  2018 'Urban Metabolism studies: detection and tracking of building generated pollutant plumes.gdoc'
# -rw------- 1 root root  65925849 Feb  4  2018  File_000.mov
# -rw------- 1 root root       151 Feb  6  2018  ranks.gsheet
# -rw------- 1 root root  23447367 Feb 12  2018  IMG_0229.TRIM.MOV
# -rw------- 1 root root       151 Feb 12  2018 'Untitled document (7).gdoc'
# -rw------- 1 root root       151 Feb 12  2018 'This project will work to assess the viability of social media, particularly twitter, as a meter to measure the response of the population to policy implementation in the prosecutorial justice sector.gdoc'
# -rw------- 1 root root 401030340 Feb 13  2018  DSC_0089.AVI
# -rw------- 1 root root       151 Feb 15  2018 'TVS subgroup proposal.gform'
# -rw------- 1 root root       151 Feb 19  2018 'Untitled document (8).gdoc'
# -rw------- 1 root root       151 Feb 23  2018 'Untitled spreadsheet (3).gsheet'
# -rw------- 1 root root   2196293 Feb 27  2018  photometry.pdf
# -rw------- 1 root root   2196293 Feb 27  2018  Lupton_LSST_PSTSAC_02272018_photometry.pdf
# -rw------- 1 root root     13985 Mar  2  2018 '2018 Capstone assignments FINAL.XLSX'
# -rw------- 1 root root       151 Mar  6  2018 'TVS call 03 05 2018.gdoc'
# -rw------- 2 root root       151 Mar  9  2018 'lsst.org feedback request .gdoc'
# -rw------- 1 root root       151 Mar  9  2018 'march 9th meeting notes.gdoc'
# -rw------- 1 root root     53392 Mar  9  2018 'Job Description-LSSTCSCC 2015-Dec 1.docx'
# drwx------ 2 root root      4096 Mar 15  2018 'Colab Notebooks'/
# -rw------- 1 root root     85186 Mar 15  2018 '2018 Capstone assignments - worksheets.xlsx'
# -rw------- 1 root root       151 Mar 20  2018 '2018 Capstone assignments - worksheets.xlsx.gsheet'
# -rw------- 1 root root       151 Mar 20  2018  CUSPstudents_netIDGithub.gsheet
# -rw------- 1 root root     40885 Mar 23  2018 'ZHANG Lingyi Resume.pdf'
# -rw------- 1 root root       151 Mar 24  2018 'Untitled document (9).gdoc'
# -rw------- 1 root root      3110 Mar 27  2018 'Untitled Diagram.html'
# -rw------- 1 root root      5224 Mar 27  2018 'Untitled Diagram (1).html'
# -rw------- 1 root root       151 Mar 28  2018 'PST Astrometric data products.gdoc'
# -rw------- 1 root root     62687 Apr  1  2018 'Xianbo Gao reference letter.pdf'
# -rw------- 1 root root      3160 Apr  3  2018 'Untitled Diagram (2).html'
# -rw------- 1 root root      3160 Apr  3  2018 'Untitled Diagram (3).html'
# -rw------- 1 root root       151 Apr 11  2018 "gabriella's thesis - copy.gdoc"
# -rw------- 1 root root       151 Apr 16  2018 'Untitled form.gform'
# -rw------- 1 root root   9346936 Apr 16  2018  Bianco_SC_F2F2018.pdf
# -rw------- 1 root root   9346936 Apr 16  2018 'Bianco_SC_F2F2018 (1).pdf'
# -rw------- 1 root root       151 Apr 23  2018 'Untitled form (1).gform'
# -rw------- 1 root root 963544022 Apr 24  2018  yana_fdnyshow2018.mov
# -rw------- 1 root root   2362151 May  7  2018  IMG_8059.JPG
# -rw------- 1 root root   2160549 May  7  2018  IMG_8056.JPG
# -rw------- 1 root root   1970276 May  7  2018  IMG_8058.JPG
# -rw------- 1 root root   2115846 May  7  2018  IMG_8061.JPG
# -rw------- 1 root root   2061151 May  7  2018  IMG_8057.JPG
# -rw------- 1 root root   2157539 May  7  2018  IMG_8060.JPG
# -rw------- 1 root root   2120814 May  7  2018  IMG_8055.JPG
# -rw------- 1 root root   2157539 May  7  2018 'IMG_8060 (1).JPG'
# -rw------- 1 root root       151 May 22  2018 'Untitled document (12).gdoc'
# -rw------- 1 root root       151 May 22  2018 'Untitled document (13).gdoc'
# -rw------- 1 root root       151 May 26  2018 'ranking startup.gdoc'
# drwx------ 2 root root      4096 May 27  2018 'LSST TVS'/
# -rw------- 1 root root 579828857 May 29  2018  Q1_DE-AR0000886_NYUBianco.key
# -rw------- 1 root root       151 Jun  3  2018  house.gsheet
# -rw------- 1 root root       151 Jun  6  2018 'UD startup flexibility.gsheet'
# -rw------- 1 root root     97966 Jun  9  2018 'Screen Shot 2018-06-08 at 11.44.56 PM.png'
# -rw------- 1 root root       151 Jun 11  2018 'added coauthors.gsheet'
# -rw------- 1 root root     21434 Jun 18  2018  Budget_justification_NSF_UWM_Bianco.docx
# -rw------- 1 root root       151 Jun 18  2018 'Untitled spreadsheet (4).gsheet'
# -rw------- 1 root root     21893 Jun 18  2018 'NSF BIO_Bianco2018.docx'
# -rw------- 1 root root     19925 Jun 21  2018  startupsUD.ipynb
# -rw------- 1 root root      4470 Jun 21  2018 'Untitled Diagram (4).html'
# -rw------- 1 root root     39472 Jun 26  2018  box_whisker_pca.png
# -rw------- 1 root root       151 Jun 27  2018 'TVS publication report.gform'
# -rw------- 1 root root    399030 Jun 28  2018 'Proposal Award Notification-Information Letter 2018-01 Bianco-Street.pdf'
# -rw------- 1 root root    119331 Jun 28  2018 '4 Form W-9.pdf'
# -rw------- 1 root root     13459 Jun 28  2018 '3 2017 Financial Report Template.xlsx'
# -rw------- 1 root root   2138042 Jun 28  2018 '2 2017 Final Report and Financial Attestation Forms.pdf'
# -rw------- 1 root root    897915 Jun 28  2018 '1 2017 Proposal Award Information Form & Guidelines.pdf'
# -rw------- 1 root root       151 Jul  1  2018 'Untitled form (2).gform'
# -rw------- 1 root root       151 Jul  3  2018 'pubpolicy survey.gdoc'
# -rw------- 1 root root    330719 Jul  8  2018  seamlesslyPoor.ipynb
# -rw------- 1 root root       151 Jul  9  2018 'Untitled form (3).gform'
# -rw------- 1 root root   5981648 Jul 17  2018  2018-07-17_SC.pdf
# -rw------- 1 root root       151 Jul 17  2018 'PJ tweets presentation at Marron.gdoc'
# drwx------ 2 root root      4096 Jul 19  2018  LSSTCCAHackathon/
# -rw------- 1 root root       151 Jul 25  2018 'MHealth slides.gdoc'
# -rw------- 1 root root       151 Jul 26  2018 'Plumes slides.gdoc'
# -rw------- 1 root root       151 Jul 26  2018 'Untitled document (15).gdoc'
# -rw------- 1 root root       151 Jul 31  2018 'Hypertemporal visible imaging of an urban lightscape can reveal the phase of the electrical grid granular to individual housing units.gdoc'
# -rw------- 1 root root       151 Aug  8  2018 'LSST TVS subgroup proposal.gform'
# -rw------- 1 root root       151 Aug  8  2018 'Untitled document (16).gdoc'
# -rw------- 1 root root       151 Aug  8  2018 'Untitled spreadsheet (5).gsheet'
# -rw------- 1 root root       151 Aug  8  2018 'TAs 2018.gsheet'
# -rw------- 1 root root   2235526 Aug  8  2018  IMG_0120.JPG
# -rw------- 1 root root   1844382 Aug  8  2018  IMG_0118.JPG
# -rw------- 1 root root   2606914 Aug  8  2018  IMG_0117.JPG
# -rw------- 1 root root       151 Aug 14  2018 'Transients & Variable Stars SC - Blending impacts & metrics.gslides'
# -rw------- 1 root root       151 Aug 17  2018 'Untitled spreadsheet (6).gsheet'
# -rw------- 1 root root       151 Aug 17  2018 'Untitled spreadsheet (7).gsheet'
# -rw------- 1 root root     11617 Aug 17  2018  movies.csv
# -rw------- 1 root root       151 Aug 17  2018  movies.gsheet
# -rw------- 1 root root       151 Aug 17  2018 'movies (1).gsheet'
# -rw------- 1 root root       151 Aug 17  2018 'movies (2).gsheet'
# -rw------- 1 root root     16223 Aug 17  2018  alienmovies.tsv
# -rw------- 1 root root       151 Aug 17  2018  alienmovies.gsheet
# -rw------- 1 root root       151 Aug 22  2018 'Untitled document (17).gdoc'
# -rw------- 1 root root       151 Aug 22  2018 'Copy of all_music_gear.gsheet'
# -rw------- 1 root root     43367 Aug 23  2018  A1DBA84B-27E0-4B23-A409-135AA52FB3FD.png
# -rw------- 1 root root       151 Aug 23  2018 'Untitled document (18).gdoc'
# -rw------- 1 root root     40795 Aug 26  2018 'BIA02-01 Modified Provisional Application - with GA_s changes-c SEK.docx'
# -rw------- 1 root root       151 Aug 28  2018 'BIA02-01 Modified Provisional Application - with GA_s changes-c SEK.gdoc'
# -rw------- 1 root root       151 Aug 28  2018 'Copy of BIA02-01 Modified Provisional Application - with GA_s changes-c SEK - sek.gdoc'
# -rw------- 1 root root       151 Aug 28  2018 'Key numbers final.gdoc'
# -rw------- 1 root root       151 Aug 29  2018 'LSST organization.gslides'
# -rw------- 1 root root     14300 Aug 30  2018 'Questionnaire (R).docx'
# -rw------- 1 root root       151 Sep  5  2018 'Done for house.gsheet'
# -rw------- 2 root root       151 Sep  5  2018 'SC content.gdoc'
# -rw------- 1 root root       151 Sep  9  2018 'Untitled document (19).gdoc'
# -rw------- 1 root root       151 Sep  9  2018 'Untitled document (20).gdoc'
# -rw------- 1 root root       151 Sep 10  2018 'PUI non CUSP students .gdoc'
# -rw------- 1 root root     36382 Sep 12  2018 'Untitled Diagram (5).html'
# -rw------- 1 root root    199141 Sep 12  2018  HTIdrawings.png
# -rw------- 1 root root       151 Sep 15  2018 'AAS12948 referee report.gdoc'
# -rw------- 1 root root       151 Sep 16  2018 'Untitled spreadsheet (8).gsheet'
# -rw------- 1 root root       151 Sep 16  2018 'F.B.Bianso SC Coordinator worksheet.gsheet'
# -rw------- 1 root root       151 Sep 17  2018 'local info flatiron.gdoc'
# -rw------- 1 root root       151 Sep 20  2018 'Untitled document (21).gdoc'
# -rw------- 1 root root       151 Sep 24  2018 'Science Collaboration  White Paper Responses Federica Bianco Science Collaborations Coordinator  and the Science Collaboration Reps.gslides'
# -rw------- 1 root root       151 Sep 24  2018 'Untitled document (22).gdoc'
# -rw------- 1 root root       151 Sep 24  2018 'Fast Transients.gslides'
# -rw------- 1 root root       151 Sep 26  2018 'LSST PST and Science Collaboration Chairs Telecon, Wednesday September 26, 2018.gdoc'
# drwx------ 2 root root      4096 Sep 28  2018  August/
# -rw------- 1 root root       151 Oct  2  2018 'Untitled document (23).gdoc'
# -rw------- 1 root root  23154058 Oct  3  2018  UI4_PUI2018.key
# -rw------- 1 root root       151 Oct  7  2018 'Science Collaboration  White Paper Responses .gslides'
# -rw------- 1 root root       151 Oct  8  2018 'LSST Cadence Hacks CCA, Flatiron Institute.gslides'
# -rw------- 1 root root       151 Oct 12  2018 'Pui2017 quiz 6 evening.gdoc'
# -rw------- 1 root root       151 Oct 18  2018 'Electromagnetic Follow Up of MMA triggers.gdoc'
# -rw------- 1 root root       151 Oct 19  2018 'Untitled document (24).gdoc'
# -rw------- 1 root root   1184867 Oct 20  2018  _system_appendPDF_proof_hi.pdf
# -rw------- 1 root root       151 Oct 24  2018 'MMA Cyberinfrastructure LSST call.gdoc'
# -rw------- 1 root root       151 Oct 24  2018 'Untitled document (25).gdoc'
# -rw------- 1 root root       151 Oct 24  2018 'LSST 2018 TSO session.gdoc'
# -rw------- 1 root root       151 Nov  1  2018 'Copy of 6. Aggregation task.gdoc'
# drwx------ 2 root root      4096 Nov  7  2018 'PUI midterm 2018'/
# -rw------- 1 root root       151 Nov 13  2018 'Untitled presentation (1).gslides'
# -rw------- 1 root root 214190212 Nov 13  2018  Q3_DE-AR0000886_NYUBianco.key.zip
# -rw------- 1 root root       151 Nov 13  2018 'Fast Transients cadence proposal call 11 12.gdoc'
# -rw------- 1 root root       151 Nov 13  2018 'Untitled spreadsheet (9).gsheet'
# -rw------- 1 root root       151 Nov 13  2018 'Nsf career academy.gdoc'
# -rw------- 1 root root       151 Nov 14  2018  manTrees.gsheet
# -rw------- 1 root root       151 Nov 14  2018 'TVS White Paper Submissions.gsheet'
# -rw------- 1 root root 256669346 Nov 14  2018 "Tiffany Patafio's Personal Meeting Room-20181029 1702-1.arf"
# -rw------- 1 root root     18304 Nov 15  2018  HalfSemestergradesMorning.png
# -rw------- 1 root root       151 Nov 18  2018 'Untitled spreadsheet (10).gsheet'
# -rw------- 1 root root       151 Nov 19  2018 'Untitled document (26).gdoc'
# -rw------- 1 root root      3089 Nov 21  2018  sky_separation.py
# -rw------- 1 root root       151 Nov 22  2018 'Target  of  Opportunity  Observations  ofGravitational  Wave  Events  with  LSST Margutti.gdoc'
# -rw------- 1 root root       151 Nov 22  2018 'An Extreme Rolling Cadence (for TDEs) Gezari.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Mapping the Periphery and Variability of the Magellanic Clouds Olsen .gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Unique  Science  from  a  Coordinated  LSST-WFIRSTSurvey  of  the  Galactic  Bulge Street.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'The  Diverse  Science  Return  from  a  Wide-AreaSurvey  of  the  Galactic  Plane  - Street.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'A  Higher  Cadence  Subsurvey  Located  in  the Galactic  Plane Lund.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Gaia-LSST Synergy and Constraints to Pulsation Theory using LSST: Observations of variable stars in Local Group stellar systems.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Searching for white dwarf transits with LSST  - Silvotti.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Continuous  Cadence  Acquisition  of  the  LSSTDeep  Drilling  Fields Bell.gdoc'
# -rw------- 1 root root       151 Nov 25  2018 'A  Cadence  to  Reduce  Aliasing  in  LSST Bell.gdoc'
# -rw------- 1 root root       151 Nov 25  2018 'TVS WP submissions.gsheet'
# -rw------- 1 root root       151 Nov 27  2018 'Explosive  Physics  and  Fast  Transients  White  PaperCadence Bianco.gdoc'
# -rw------- 1 root root       151 Nov 28  2018 'Blazars  (and  FRBs)  with  LSST Raiteri.gdoc'
# -rw------- 1 root root     53696 Nov 28  2018  Bianco.pdf
# -rw------- 1 root root       151 Nov 29  2018 'unVEil  the  darknesS  of  The  gAlactic  buLgE  (VESTALE) Bono   DallOra.gdoc'
# -rw------- 1 root root       151 Nov 29  2018 'Untitled document (31).gdoc'
# -rw------- 1 root root       151 Nov 29  2018 'Bianco UDel Phsyica&Astronomy   DSI  postdoc PDR.gdoc'
# -rw------- 1 root root       151 Nov 29  2018 'TDEs  with  LSST Bricman.gdoc'
# -rw------- 1 root root       151 Dec  2  2018 'PUI2018 Extra Credit Project Proposal.gdoc'
# -rw------- 1 root root       151 Dec  6  2018 'Pui quiz 11 am.gdoc'
# -rw------- 1 root root    336231 Dec  6  2018 'Committees guidelines from Executive Board Handbook_Final_R2_21Mar2018.pdf'
# -rw------- 1 root root       151 Dec  8  2018 'December 7th CUSP HackDay.gdoc'
# -rw------- 1 root root  94342945 Dec  9  2018  Somayeh_Khakpash.mov
# -rw------- 1 root root       151 Dec 10  2018 'December 10 LSST SC chairs call.gdoc'
# -rw------- 1 root root       151 Dec 14  2018 'Untitled document (40).gdoc'
# drwx------ 2 root root      4096 Dec 15  2018 'PUI Final2018 hints'/
# -rw------- 1 root root       151 Dec 18  2018 'PUI2018 Extra Credit Project Template.gdoc'
# -rw------- 1 root root       151 Dec 18  2018 'December 6 LSST SC chairs call.gdoc'
# -rw------- 1 root root       151 Dec 21  2018 'Untitled document (33).gdoc'
# -rw------- 1 root root      1050 Dec 26  2018  graded.csv
# -rw------- 1 root root   6229203 Jan  1  2019  Bianco_Federica-2018-03.jpg
# -rw------- 1 root root   9479331 Jan  1  2019 'FedericaBianco[FinalJPEGs]-270.jpg'
# -rw------- 1 root root  15117523 Jan  1  2019 'FedericaBianco[FinalJPEGs]-257.jpg'
# -rw------- 1 root root       151 Jan  4  2019 'Copy of Carreer Grant Proposal 01 03 2019.gdoc'
# -rw------- 1 root root       151 Jan  5  2019 'Carreer Grant Proposal 01 03 2019.gdoc'
# -rw------- 1 root root       151 Jan  5  2019 'Untitled spreadsheet (11).gsheet'
# -rw------- 1 root root  35469816 Jan  5  2019 'BiancoAAS233TownHallPPT 3.key'
# -rw------- 1 root root  35032358 Jan  5  2019 'BiancoAAS233TownHallPPT 3 (1).key'
# -rw------- 1 root root       151 Jan 11  2019 'LSST Cadence Hackathon at the Flatiron Institute.gdoc'
# -rw------- 1 root root       151 Jan 13  2019 'Untitled document (27).gdoc'
# -rw------- 1 root root       151 Jan 13  2019 'Untitled document (28).gdoc'
# -rw------- 1 root root       151 Jan 13  2019 'Untitled document (36).gdoc'
# -rw------- 1 root root       151 Jan 15  2019  PUI2017grades.gsheet
# -rw------- 1 root root       151 Jan 16  2019  draft.gdoc
# -rw------- 1 root root       151 Jan 25  2019 'TVS conf call 01 23 2019.gdoc'
# -rw------- 2 root root       151 Feb  1  2019 'GBS Committee Report and Notes.gdoc'
# -rw------- 1 root root       151 Feb  7  2019 'LOI AccelNet LSST SCs.gdoc'
# -rw------- 1 root root       151 Feb 11  2019 'LSST SC Accelnet prep form.gform'
# -rw------- 1 root root       151 Feb 12  2019 'LSST SC Chairs accelnet call 02 11 2019.gdoc'
# -rw------- 1 root root       151 Feb 12  2019 'SCiMMA Data management, communication, and collaboration meeting 1.gdoc'
# -rw------- 1 root root       151 Feb 12  2019 'Untitled presentation (4).gslides'
# -rw------- 1 root root   2911027 Feb 13  2019 'bg 2.png'
# -rw------- 1 root root       151 Feb 16  2019 'Copy of BaurJulienFBB.gdoc'
# -rw------- 1 root root       151 Feb 16  2019  BaurJulienFBB.gdoc
# -rw------- 1 root root     21684 Feb 20  2019  proposal_budget_v3.ods
# -rw------- 1 root root     24523 Feb 22  2019 'Budget  - NSF 19-501 - Bianco.xlsx'
# -rw------- 1 root root  40170678 Feb 23  2019  IMG_3406.MOV
# -rw------- 1 root root       151 Feb 25  2019 'Untitled presentation (2).gslides'
# -rw------- 1 root root     20932 Feb 25  2019  nsf-biosketch.docx
# -rw------- 1 root root       151 Feb 25  2019 'Untitled spreadsheet (16).gsheet'
# drwx------ 2 root root      4096 Feb 26  2019  LSSTBrokerWorkshop19/
# -rw------- 1 root root       151 Feb 26  2019 'Untitled document (52).gdoc'
# -rw------- 1 root root       151 Feb 28  2019 'LSST PST-SC meeting 02 27 19 notes.gdoc'
# -rw------- 1 root root       151 Mar  1  2019 'Review or resubmission.gdoc'
# -rw------- 1 root root       151 Mar  3  2019 'Untitled presentation (3).gslides'
# -rw------- 1 root root       151 Mar  4  2019 'Changes to PASP-100746 .gdoc'
# -rw------- 1 root root   2654688 Mar 13  2019  toms_and_brokers_lsst2018_fed.pdf
# -rw------- 1 root root       151 Mar 14  2019 'TVS task force proposal 2019.gform'
# -rw------- 1 root root       151 Mar 14  2019 'Untitled document (51).gdoc'
# -rw------- 1 root root       151 Mar 16  2019 'Untitled document (50).gdoc'
# -rw------- 1 root root       151 Mar 19  2019 'briefing on ODF - Steve Kahn - SC chairs.gdoc'
# -rw------- 1 root root 427576252 Mar 22  2019  udclass.key
# drwx------ 2 root root      4096 Mar 23  2019 'TED slides'/
# -rw------- 1 root root   3556610 Mar 23  2019  bg.jpg
# -rw------- 1 root root  25966618 Mar 23  2019  shutterstock_483529342.jpg
# -rw------- 1 root root       151 Mar 25  2019 'Untitled document (49).gdoc'
# -rw------- 1 root root 239431154 Mar 26  2019  fbbTedTalk_take1.mov
# -rw------- 1 root root  29918101 Mar 27  2019  CAA_LSSTSCs.pdf
# -rw------- 1 root root       151 Mar 27 21:36 'Live notes PST-SC chairs meeting 03 27.gdoc'
# -rw------- 1 root root 132844527 Mar 28 14:51  Q5_DE-AR0000886_NYUBianco.pdf
# -rw------- 1 root root       151 Mar 29 12:40 'Federica Bianco_PR Guide_TED2019 Fellows.gdoc'
# -rw------- 1 root root    113398 Mar 29 16:29 'Assessment of the impact of an LSST ODF from the Science Collaborations (1).pdf'
# -rw------- 1 root root    113398 Mar 29 17:25 'Assessment of the impact of an LSST ODF from the Science Collaborations.pdf'
# -rw------- 1 root root 150287408 Apr  4 15:15 'DarkUniverseNoSN (1).mp4'
# -rw------- 1 root root       151 Apr  5 19:10 'meeting mimutes template.gdoc'
# -rw------- 1 root root 150287408 Apr  6 17:54  DarkUniverseNoSN.mp4
# -rw------- 1 root root     23789 Apr  6 18:06 'Fact Check_Federica Bianco_v2.docx'
# -rw------- 1 root root       151 Apr  6 21:41 'Fact Check_Federica Bianco_v2 (1).gdoc'
# -rw------- 1 root root     22391 Apr  8 07:17  Atimeexchangemodel-thoughtsandscribblings.docx
# -rw------- 1 root root 667790373 Apr  8 18:23  DarkUniverseNoSN_slow.mov
# -rw------- 1 root root       151 Apr  9 19:15 'Letter to recommand dissolution of MB.gdoc'
# -rw------- 1 root root       151 Apr 14 21:48 'Fact Check_Federica Bianco_v2.gdoc'
# -rw------- 1 root root       151 Apr 14 23:17 'Federica Bianco II 2019 Talk prep  saved  .gdoc'
# -rw------- 1 root root       151 Apr 26 03:54 'NSF Career Grant proposal, F.gdoc'
# -rw------- 1 root root       151 Apr 30 22:48 'Untitled document (48).gdoc'
# drwx------ 2 root root      4096 May  1 12:01  LSST/
# -rw------- 1 root root       151 May  2 06:20 'Copy of Federica Bianco II 2019 Talk prep .gdoc'
# -rw------- 1 root root       151 May  2 21:33 'Untitled document (47).gdoc'
# -rw------- 1 root root     13210 May  3 18:14 'Female Undergrads in Physics for 2193.xlsx'
# -rw------- 1 root root   1910601 May  4 13:07  MVIMG_20190502_180146~2.jpg
# -rw------- 1 root root       151 May  7 00:24  Acquaviva.gdoc
# -rw------- 1 root root  27883444 May  7 13:13 'SierraLeone_urban_observatory (1).pdf'
# -rw------- 1 root root  27883444 May  7 13:14  SierraLeone_urban_observatory.pdf
# -rw------- 1 root root     23263 May  8 18:53 'Faculty and Staff Women in Physics.xlsx'
# -rw------- 1 root root       151 May  9 03:00 'research active WiPA-UD.gsheet'
# -rw------- 1 root root       151 May 12 20:16 'LSST SSSC chair nomination election.gform'
# -rw------- 1 root root       151 May 16 12:57 'TVS 2019 Task Force Sign up.gform'
# -rw------- 1 root root   1884736 May 18 06:41  tmp.key
# drwx------ 2 root root      4096 May 20 07:46  fights/
# -rw------- 1 root root       151 May 21 19:52 'TVS task force proposal 2019 (Responses).gsheet'
# -rw------- 1 root root       151 May 22 00:13 'TVS LSST@asia.gslides'
# drwx------ 2 root root      4096 May 22 18:11  photos/
# drwx------ 2 root root      4096 May 22 19:05  dads/
# -rw------- 1 root root   2727795 May 22 19:15  IMG_1819.JPG
# -rw------- 1 root root   1961768 May 22 19:15  IMG_1811.JPG
# -rw------- 1 root root   2202620 May 22 19:15  IMG_1810.JPG
# -rw------- 1 root root   2209121 May 22 19:15  IMG_1813.JPG
# -rw------- 1 root root   2359915 May 22 19:15  IMG_1812.JPG
# -rw------- 1 root root   2376989 May 22 19:15  IMG_1718.JPG
# -rw------- 1 root root   2570382 May 22 19:15  IMG_1814.JPG
# -rw------- 1 root root   2626336 May 22 19:16  IMG_1723.JPG
# -rw------- 1 root root   2913132 May 22 19:16  IMG_1719.JPG
# -rw------- 1 root root   3020886 May 22 19:16  IMG_1716.JPG
# -rw------- 1 root root   3072645 May 22 19:16  IMG_1818.JPG
# -rw------- 1 root root   3159030 May 22 19:16  IMG_1717.JPG
# -rw------- 1 root root   3233888 May 22 19:16  IMG_1720.JPG
# -rw------- 1 root root   3733596 May 22 19:16  IMG_1815.JPG
# -rw------- 1 root root   4050807 May 22 19:16  IMG_1722.JPG
# -rw------- 1 root root   4091945 May 22 19:16  IMG_1721.JPG
# -rw------- 1 root root   4224110 May 22 19:16  IMG_1816.JPG
# -rw------- 1 root root   4253500 May 22 19:16  IMG_1817.JPG
# -rw------- 1 root root   1792753 May 22 19:26  IMG_1890.JPG
# -rw------- 1 root root       151 May 23 02:30 'Untitled document (46).gdoc'
# -rw------- 2 root root       151 May 23 16:10 'LSST for-scientists webpages feedback.gform'
# -rw------- 1 root root       151 May 27 23:27 'needed for home.gsheet'
# -rw------- 1 root root       151 May 29 03:59 'UD-BNL Bianco Slosar  .gdoc'
# -rw------- 1 root root    159048 May 30 03:24 'Screen Shot 2019-05-02 at 11.39.54 PM.png'
# -rw------- 1 root root       151 May 30 21:12 'Untitled spreadsheet (15).gsheet'
# drwx------ 2 root root      4096 Jun  3 17:05 'LSSTC Executive Board SC committee'/
# -rw------- 1 root root       151 Jun  3 23:59 'Untitled document (45).gdoc'
# -rw------- 1 root root       151 Jun  4 00:51 'Untitled form (4).gform'
# -rw------- 1 root root    132086 Jun 12 14:35  LSST2020_rationale_v02.docx
# -rw------- 1 root root       151 Jun 15 16:03  NASPAA_LOI.gdoc
# drwx------ 2 root root      4096 Jun 18 16:37  tobacco/
# -rw------- 1 root root       151 Jun 19 04:13 'hackathon flowchart.gdraw'
# -rw------- 1 root root 146843498 Jun 21 21:46  presto-colorEWASS19.key
# -rw------- 1 root root       151 Jun 24 05:11 'Untitled document (29).gdoc'
# -rw------- 1 root root       151 Jun 29 19:35 'Copy of Vision for a Data Science curriculum for Public Service.gdoc'
# -rw------- 1 root root      1931 Jun 29 22:25 'Untitled Diagram.drawio'
# -rw------- 1 root root      6243 Jun 29 22:32 'Untitled Diagram (1).drawio'
# -rw------- 1 root root     53791 Jun 29 23:43 'DSPP curriculum logic model.svg'
# -rw------- 1 root root    341089 Jun 29 23:45 'DSPP curriculum logic model.png'
# -rw------- 1 root root    520894 Jun 30 14:18 'DSPP curriculum logic model.jpg'
# -rw------- 1 root root    521177 Jun 30 15:04 'DSPP curriculum logic model (1).jpg'
# -rw------- 1 root root    521177 Jun 30 15:07 'DSPP curriculum logic model (2).jpg'
# -rw------- 1 root root    521177 Jun 30 15:12 'DSPP curriculum logic model (3).jpg'
# -rw------- 1 root root    499934 Jun 30 15:13 'DSPP curriculum logic model (1).png'
# -rw------- 1 root root    500946 Jun 30 16:00 'DSPP curriculum logic model (2).png'
# -rw------- 1 root root       151 Jun 30 16:01 'Untitled drawing (1).gdraw'
# -rw------- 1 root root    500945 Jun 30 16:03 'DSPP curriculum logic model_final.png'
# -rw------- 1 root root    506032 Jun 30 16:20 'DSPP curriculum logic model_final2.png'
# -rw------- 1 root root      5515 Jun 30 16:47 'DSPP curriculum logic model.drawio'
# -rw------- 1 root root       151 Jun 30 22:16 'Untitled spreadsheet (13).gsheet'
# -rw------- 1 root root       151 Jul  1 16:16 'UD Fall hackathon 2019.gdoc'
# -rw------- 1 root root       151 Jul  1 16:44 'Untitled document (42).gdoc'
# -rw------- 1 root root       151 Jul  1 20:48 'TVS Subgroup Leads Telecon 2019 July 1st.gdoc'
# -rw------- 1 root root       151 Jul  2 00:06 'fig5 .gdraw'
# -rw------- 1 root root       151 Jul  2 19:18 'Vision for a Data Science curriculum for Public Service.gdoc'
# drwx------ 2 root root      4096 Jul  9 19:13  apiks/
# -rw------- 1 root root       151 Jul 10 17:20  Astro2020SCsF1.gdraw
# -rw------- 1 root root       151 Jul 12 02:16  tvssticker.gdraw
# -rw------- 1 root root       151 Jul 12 02:20  smwlvsticker.gdraw
# -rw------- 1 root root       151 Jul 12 02:26  descsticker.gdraw
# -rw------- 1 root root       151 Jul 12 03:57  ssscsticker.gdraw
# -rw------- 1 root root  53317774 Jul 12 17:36  bianco_S1_EWASS2019_LSST.pdf
# -rw------- 1 root root       151 Jul 14 22:58  AGNlogo.gdraw
# -rw------- 1 root root       151 Jul 15 00:12  SLSC.gdraw
# -rw------- 1 root root       151 Jul 15 00:22  GalSClogo.gdraw
# -rw------- 1 root root       151 Jul 16 19:12  TVSlogo.gdraw
# -rw------- 1 root root       151 Jul 16 19:19  TVSlogolabel.gdraw
# -rw------- 1 root root   3928132 Jul 19 17:08 'AC NSF ID -000747680 -Bianco Federica.docx'
# -rw------- 1 root root       151 Jul 22 20:25 'LSST SSSC chair election.gform'
# -rw------- 1 root root       151 Jul 30 02:01 'LSST Commissioning Input.gform'
# -rw------- 1 root root    259619 Jul 30 17:13  incubator_v3_ajc.docx
# -rw------- 1 root root       151 Jul 31 02:47 'Untitled spreadsheet (14).gsheet'
# -rw------- 1 root root       151 Jul 31 05:56 'SC speakers PCW 2019.gsheet'
# -rw------- 1 root root 167592148 Aug  7 21:34  VID_20190806_172853.mp4
# -rw------- 1 root root 345409413 Aug 11 14:08  CAA_LSSTSCs.key
# -rw------- 1 root root 345409413 Aug 11 14:11 'CAA_LSSTSCs (1).key'
# -rw------- 1 root root       151 Aug 11 14:15  Presentation1.gslides
# -rw------- 1 root root       151 Aug 11 14:18  CAA_LSSTSCs.gslides
# -rw------- 1 root root       151 Aug 11 14:19  Presentation2.gslides
# -rw------- 1 root root  56400286 Aug 12 12:28  sloth.mp4
# -rw------- 1 root root   4331719 Aug 12 12:28  IMG_20190810_081044_exported_stabilized_215728302638536747.mp4
# -rw------- 1 root root       151 Aug 12 12:59 'Untitled document (37).gdoc'
# -rw------- 1 root root       151 Aug 12 13:52 'WIPA-UD .gform'
# -rw------- 1 root root       151 Aug 13 07:38 'Galaxies plenary.gslides'
# -rw------- 1 root root       151 Aug 13 07:39 'Copy of LSST2019: LSST SCIENCE.gslides'
# -rw------- 1 root root       151 Aug 13 07:55 'LSST Science Collaborations Status Report - updates August 2019.gslides'
# -rw------- 1 root root       151 Aug 14 17:31 'LSST2019: Sci Collab Plenary Talks Wednesday.gslides'
# -rw------- 1 root root       151 Aug 14 18:39 'LSST2019: Sci Collab Plenary Talks Tuesday.gslides'
# -rw------- 1 root root       151 Aug 14 19:50 'Untitled document (35).gdoc'
# -rw------- 1 root root       151 Aug 15 18:18 'Untitled document (38).gdoc'
# -rw------- 1 root root       151 Aug 15 21:33 'July2019 LSSTC executive board  SCs Advisory committee meeting.gdoc'
# -rw------- 1 root root       151 Aug 16 18:13 'SETI LSST budget.gsheet'
# -rw------- 1 root root       151 Aug 17 00:27 'Untitled document (44).gdoc'
# -rw------- 1 root root       151 Aug 17 00:29 'Are we alone? Searching for Intelligent Life with LSST.gdoc'
# -rw------- 1 root root       151 Aug 17 14:47 'Summary Sci Collab activities and LSSTPCW2019 SC Plenary Talks.gslides'
# -rw------- 1 root root       151 Aug 17 15:39 'Endorsement of LSST Corporation Activities by the LSST Science Collaborations.gdoc'
# -rw------- 1 root root       151 Aug 18 23:44 'TVS metrics and survey cadence proposals.gslides'
# -rw------- 1 root root       151 Aug 19 18:06 'LSST science intro.gslides'
# -rw------- 1 root root       151 Aug 19 23:31 'Untitled document (43).gdoc'
# -rw------- 1 root root       151 Aug 20 00:00 'LSST science 101.gslides'
# drwx------ 2 root root      4096 Aug 23 20:53 'TED fellow space show'/
# -rw------- 1 root root     36578 Aug 24 05:06  LA.ipynb
# -rw------- 1 root root       151 Aug 24 21:56 'Untitled document (39).gdoc'
# drwx------ 2 root root      4096 Aug 26 02:53 'DE legislative reform'/
# -rw------- 1 root root       151 Aug 26 03:58  HOMLPython.gdoc
# -rw------- 1 root root       151 Aug 28 03:14 'Accelnet2019 reviews.gdoc'
# -rw------- 1 root root       151 Aug 28 20:22 'Untitled document (41).gdoc'
# -rw------- 1 root root       151 Aug 30 22:50 'SC Chairs meeting August 30th 2019.gdoc'
# -rw------- 1 root root       151 Aug 31 02:54 'Untitled document (34).gdoc'
# -rw------- 1 root root       151 Sep  9 17:35 'A Diversity and Inclusion Committee of the Department of Physics and Astronomy at the University of Delaware.gdoc'
# -rw------- 1 root root       151 Sep  9 21:34 'Untitled document (32).gdoc'
# -rw------- 1 root root       151 Sep 11 03:36  resume.gdoc
# drwx------ 2 root root      4096 Sep 13 13:16 'ARPAe docs'/
# -rw------- 1 root root       151 Sep 13 15:36 'Untitled document (53).gdoc'
# -rw------- 1 root root       151 Sep 15 01:46 'Untitled spreadsheet (12).gsheet'
# -rw------- 1 root root       151 Sep 17 05:57 'LSST IKCC.gdoc'
# -rw------- 1 root root       151 Sep 18 18:25 'Untitled document (30).gdoc'
# -rw------- 1 root root       151 Sep 20 01:27 'TVS-SMWLV meeting and hackathon 2019.gform'
# -rw------- 1 root root     71163 Sep 23 00:20 'DSPS 2019 quiz 6 - Google Docs-1.pdf'
# drwx------ 2 root root      4096 Sep 25 03:09  dsps/
# -rw------- 1 root root     67540 Sep 25 13:13  APIreadingJson.ipynb
# -rw------- 1 root root       598 Sep 25 13:32  NYCweatherAPI.py
# drwx------ 2 root root      4096 Sep 25 13:45  citibikes/
# drwx------ 2 root root      4096 Sep 25 16:39  dsps2019/
# -rw------- 1 root root       151 Sep 25 23:51 'TVS-SMWLV meeting and hackathon 2019 (Responses).gsheet'
# drwx------ 2 root root      4096 Sep 26 04:00  test_dir/

# %% [markdown]
# These unix commands can also be combined with some python syntax using the os module (let's make a directory called "data" in your colaboratory home directory):

# %% [markdown]
# download data from the web

# %% [markdown]
# to do that you can use wget, but that command is not "included" in the ```colab``` jupyter notebook. the are unix commands. you can use them if you start the command with ```!```

# %%
# !wget  https://www2.census.gov/programs-surveys/cbp/datasets/2016/zbp16totals.zip
# Out:
# --2019-09-26 04:03:44--  https://www2.census.gov/programs-surveys/cbp/datasets/2016/zbp16totals.zip
# Resolving www2.census.gov (www2.census.gov)... 23.44.160.119, 2600:1409:12:392::208c, 2600:1409:12:3a2::208c
# Connecting to www2.census.gov (www2.census.gov)|23.44.160.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘zbp16totals.zip’
#
# zbp16totals.zip         [ <=>                ] 750.30K  --.-KB/s    in 0.1s
#
# 2019-09-26 04:03:44 (6.65 MB/s) - ‘zbp16totals.zip’ saved [768303]

# %%
ls
# Out:
# drive/  sample_data/  zbp16totals.zip

# %% [markdown]
# same with ```unzip``` to expand a compressed zip file. the argument ```-d <path> ```expands into "path"

# %%
# !unzip  zbp16totals.zip -d "drive/My Drive/test_dir"
# Out:
# Archive:  zbp16totals.zip
#   inflating: drive/My Drive/test_dir/zbp16totals.txt

# %%
ls "drive/My Drive/test_dir"
# Out:
# zbp16totals.txt

# %% [markdown]
# Another way to access unix commands is to use the module ```os``` and specifically the function ```os.system()```.  This function performs operations and returns a success vs error state. So I cannot use it, for example, ro tun ```ls```

# %%
# -- import the os module for operating system interaction
import os
cmd = "ls drive/My\ Drive/test_dir"
os.system(cmd)
# Out:
# 0

# %% [markdown]
# 0 means no error: the command was executed without problem. Any other number will indicate an error (and you can google the meaning of the number.) But i do not see the output of the command. so use this if you want to know if the command worked, but you do not care to see its output.

# %%
ls "drive/My Drive/test_dir"
# Out:
# zbp16totals.txt

# %% [markdown]
# For example I can use it to remove files and directories: ```rm``` (```rm -r``` which means recursively, for a directory)

# %% [markdown]
# Note the syntax: you need to parse the space with a "\ " in front of it to be rendered correctly in the string when you use ```os.system()```

# %%
# -- create a string that contains the command you want
cmd = "rm -r drive/My\ Drive/test_dir"
# -- execute the command with os.system (notice the output)
os.system(cmd)
# Out:
# 0

# %% [markdown]
# The directory is no longer there

# %%
ls "drive/My Drive/test_dir"
# Out:
# ls: cannot access 'drive/My Drive/test_dir': No such file or directory

# %% [markdown]
# You can string unix commands together with the semicolon ; (cd stands for "change directory" and it moves you around)

# %%
ls; cd drive; pwd
# Out:
# drive/  sample_data/  zbp16totals.zip
# /content/drive

# %% [markdown]
# But again, <u>**these are not python commands and can't be used as such on their own**</u>:

# %% [markdown]
# We'll see how combining unix commands with python via os.system can be put to good use below.

# %% [markdown]
# ### The wget command
#
# When dealing with data on the web, the wget command can be very useful for quickly grabbing data that you want.  Let's get the zipcode business patterns for 2016 (note the exclamation point before the wget command):

# %%
# !wget https://www2.census.gov/programs-surveys/cbp/datasets/2016/zbp16detail.zip
# Out:
# --2019-09-26 04:11:35--  https://www2.census.gov/programs-surveys/cbp/datasets/2016/zbp16detail.zip
# Resolving www2.census.gov (www2.census.gov)... 23.44.160.119, 2600:1409:12:392::208c, 2600:1409:12:3a2::208c
# Connecting to www2.census.gov (www2.census.gov)|23.44.160.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘zbp16detail.zip’
#
# zbp16detail.zip         [   <=>              ]  27.51M  57.2MB/s    in 0.5s
#
# 2019-09-26 04:11:36 (57.2 MB/s) - ‘zbp16detail.zip’ saved [28843251]

# %% [markdown]
# Now we can see the utility of combining unix commands with python to make our lives much easier:

# %%
# -- define a command to make a sub-directory in data called zbp

# -- run that command

# -- check if the command worked

# %% [markdown]
# last package to discuss: ```glob``` looks at the content of a directory and returns it in a list. if the dir is empty the length of the string is...0!

# %%
import glob
if len(glob.glob("drive/My Drive/dsps2019")) == 0:
  os.system("mkdir drive/My\ Drive/dsps2019")

# %%
ls -ltr "drive/My Drive"
# Out:
# total 8567038
# -rw------- 1 root root       151 Dec  9  2009  FD-II.gdoc
# -rw------- 1 root root       151 Dec 20  2009 'PRANZO DEL 28.gdoc'
# -rw------- 1 root root       151 Dec 26  2009  Fragment.tex.gdoc
# -rw------- 1 root root       151 Jan  8  2010 'Sogno Berlino.gdoc'
# -rw------- 1 root root       151 Apr 19  2010  DDT_HD187091.gdoc
# -rw------- 1 root root       151 Nov  9  2010 'LIHSP todo.gdoc'
# -rw------- 1 root root    144675 Jun 24  2011  FTN_20110623_Pluto_halflight.ps
# -rw------- 1 root root    111975 Jun 24  2011  FTN_20110623_Charon_boxcar.ps
# -rw------- 1 root root       151 Jul 28  2011  nebulae.gsheet
# -rw------- 1 root root       151 Jul 28  2011 'nebulae (1).gsheet'
# -rw------- 1 root root       151 Oct  5  2011 'aas membership.gsheet'
# -rw------- 1 root root       151 Mar  1  2012 'federica bianco -- funding request contingent upon better understanding of USF support system.gsheet'
# -rw------- 1 root root       151 Mar  6  2012 'federica bianco - computer needs.gdoc'
# -rw------- 1 root root       151 Mar  7  2012 'federica bianco computer needs.gsheet'
# -rw------- 1 root root       151 Mar 18  2012  berlusconi_eng.doc.gdoc
# -rw------- 1 root root     49788 Aug 20  2012  Sedna_2013-01-10T05h09m02s.jpg
# -rw------- 1 root root     57468 Aug 20  2012  Sedna_2013-01-13T12h25m42s.jpg
# -rw------- 1 root root       151 Sep 12  2012 'moving expenses.gsheet'
# -rw------- 1 root root       151 Sep 17  2012 'nyu computers .gsheet'
# -rw------- 1 root root       151 Sep 30  2012 'new house.gsheet'
# -rw------- 1 root root     56660 Oct  1  2012 'Payment Confirmation.pdf'
# -rw------- 1 root root       151 Oct 18  2012 'OSSOS conf call.gdoc'
# -rw------- 1 root root     90180 Nov 13  2012 'AAS - EDU cheatsheet.pdf'
# -rw------- 1 root root       151 Nov 26  2012 ' Federica Job Applications 2012 for tim.gsheet'
# -rw------- 1 root root       151 Nov 26  2012 'Federica Job Applications 2012.gsheet'
# -rw------- 1 root root       151 Feb 13  2013 '11fe summary.gdoc'
# -rw------- 1 root root       151 Feb 13  2013  iraf.gdoc
# -rw------- 1 root root       151 Feb 13  2013  sn.gdoc
# -rw------- 1 root root     15788 Mar  2  2013  CfA.SNIbc.BIGINFO.list.txt
# -rw------- 1 root root       151 Mar 18  2013 'eta light echoes in colors.gsheet'
# -rw------- 1 root root       151 Apr  3  2013  eta07_eta09.gsheet
# -rw------- 1 root root       151 Apr  4  2013 'eta DECAM coordinates.gsheet'
# -rw------- 1 root root       151 Jun 19  2013 'NYU expenses 2013.gsheet'
# -rw------- 1 root root       151 Jul 10  2013  SN-syllabus.doc.gdoc
# -rw------- 1 root root       151 Aug 13  2013 'AAS check list.gsheet'
# drwx------ 2 root root      4096 Sep  5  2013 'Google Buzz'/
# -rw------- 1 root root       151 Sep 13  2013 'aas 2011 austin costs.gsheet'
# -rw------- 1 root root       151 Sep 22  2013 'amazing women.gdoc'
# drwx------ 2 root root      4096 Sep 22  2013 'obs log'/
# -rw------- 1 root root       151 Sep 22  2013 'NSF acknowledgement.gdoc'
# -rw------- 1 root root       151 Sep 22  2013 'monthly expenses.gsheet'
# drwx------ 2 root root      4096 Oct  8  2013 'slides and talks'/
# -rw------- 1 root root       151 Nov 12  2013 'well sampled SESN lightcurves.gsheet'
# -rw------- 1 root root       151 Nov 25  2013 'NSF acknowledgement 2.gdoc'
# -rw------- 1 root root       151 Nov 25  2013  nebulae.gdoc
# -rw------- 1 root root      2288 Dec  2  2013  2013Jul15_obslog_0327.log
# drwx------ 2 root root      4096 Dec  2  2013 'obs astro fall 2013 '/
# -rw------- 1 root root     38463 Dec  4  2013  how_to_do_nonlinearWCS
# -rw------- 1 root root       151 Dec  9  2013  Hubbleconstant.gdoc
# -rw------- 1 root root       151 Dec  9  2013 'preclass 12.gdoc'
# -rw------- 1 root root      5520 Dec 13  2013  sn2005eo_flux.dat
# -rw------- 1 root root       151 Dec 16  2013 'LIHSP 2m observing.gdoc'
# -rw------- 1 root root       151 Dec 16  2013 'final 2013.gdoc'
# -rw------- 1 root root       151 Dec 16  2013 'Untitled spreadsheet (32).gsheet'
# -rw------- 1 root root    189742 Dec 17  2013 'AAS Poster Quaoar.jpg'
# -rw------- 1 root root       151 Dec 20  2013  CfA.SNIbc.BIGINFO_notused.gsheet
# -rw------- 1 root root       151 Jan  8  2014 'Copy of Occultation Key Project .gdoc'
# -rw------- 1 root root    982824 Jan 10  2014  occkey2014_annotated.pdf
# -rw------- 1 root root       151 Jan 13  2014 'Untitled spreadsheet (31).gsheet'
# -rw------- 1 root root     98288 Jan 17  2014 'itg2014 (1)-1.pdf'
# -rw------- 1 root root       151 Jan 21  2014 'Untitled spreadsheet (30).gsheet'
# -rw------- 1 root root   2858676 Feb  6  2014  total_Ib_3_4_2_dh.ps
# drwx------ 2 root root      4096 Feb 20  2014  KOI42/
# drwx------ 2 root root      4096 Feb 20  2014  LE_proposal2014A/
# -rw------- 1 root root    753113 Feb 23  2014  IMG_20140222_214817.jpg
# -rw------- 1 root root    865962 Feb 23  2014  IMG_20140220_192020.jpg
# -rw------- 1 root root   1147904 Feb 23  2014  IMG_20140222_171540.jpg
# -rw------- 1 root root    771921 Feb 23  2014  IMG_20140222_151214.jpg
# -rw------- 1 root root    647573 Feb 23  2014  IMG_20140222_172145.jpg
# -rw------- 1 root root    972078 Feb 23  2014  IMG_20140222_172142.jpg
# -rw------- 1 root root   1153614 Feb 23  2014  IMG_20140221_091155.jpg
# -rw------- 1 root root    790585 Feb 23  2014  IMG_20140223_081628.jpg
# -rw------- 1 root root   1026917 Feb 23  2014  IMG_20140222_173948.jpg
# -rw------- 1 root root    836213 Feb 23  2014  IMG_20140222_172211.jpg
# -rw------- 1 root root    614266 Feb 23  2014  IMG_20140222_151309.jpg
# -rw------- 1 root root   1090962 Feb 23  2014  IMG_20140222_173957.jpg
# -rw------- 1 root root     48977 Feb 23  2014  IMG_20140222_151424.jpg
# -rw------- 1 root root   1015513 Feb 23  2014  IMG_20140222_173916.jpg
# -rw------- 1 root root    894015 Feb 23  2014  IMG_20140222_171543.jpg
# -rw------- 1 root root     45235 Feb 23  2014  IMG_20140222_151416.jpg
# -rw------- 1 root root     96280 Feb 23  2014  IMG_20140218_180333.jpg
# -rw------- 1 root root    662471 Feb 23  2014  IMG_20140222_151307.jpg
# -rw------- 1 root root    872594 Feb 23  2014  IMG_20140223_081633.jpg
# -rw------- 1 root root    632032 Feb 23  2014  IMG_20140222_171556.jpg
# -rw------- 1 root root    954403 Feb 23  2014  IMG_20140222_171549.jpg
# -rw------- 1 root root    894592 Feb 23  2014  IMG_20140222_172202.jpg
# -rw------- 1 root root    884380 Feb 23  2014  IMG_20140222_173641.jpg
# -rw------- 1 root root    951802 Feb 23  2014  IMG_20140222_173935.jpg
# -rw------- 1 root root    983846 Feb 23  2014  IMG_20140222_171617.jpg
# -rw------- 1 root root    613815 Feb 23  2014  IMG_20140222_151310.jpg
# -rw------- 1 root root   1029796 Feb 23  2014  IMG_20140222_214814.jpg
# -rw------- 1 root root    960219 Feb 23  2014  IMG_20140222_171541.jpg
# -rw------- 1 root root    877602 Feb 23  2014  IMG_20140222_172207.jpg
# -rw------- 1 root root    788155 Feb 23  2014  IMG_20140222_172001.jpg
# -rw------- 1 root root    670857 Feb 23  2014  IMG_20140222_151316.jpg
# -rw------- 1 root root    995305 Feb 23  2014  IMG_20140222_214808.jpg
# -rw------- 1 root root  13891242 Feb 23  2014  VID_20140222_151219.mp4
# -rw------- 1 root root    912825 Feb 23  2014  IMG_20140223_143529.jpg
# -rw------- 1 root root    901382 Feb 23  2014  IMG_20140223_140059.jpg
# -rw------- 1 root root   1010925 Feb 23  2014 'IMG_20140223_145213 (1).jpg'
# -rw------- 1 root root   1010925 Feb 25  2014  IMG_20140223_145213.jpg
# -rw------- 1 root root       151 Mar  2  2014  behavpp.gslides
# -rw------- 1 root root     95212 Mar  4  2014  HW5_s14.pdf
# -rw------- 1 root root   1424702 Mar 17  2014  Supernovae.zip
# -rw------- 1 root root    398494 Mar 21  2014 'ms (1).pdf'
# -rw------- 1 root root       151 Mar 25  2014 'Untitled document (89).gdoc'
# -rw------- 1 root root   2240533 Mar 26  2014  image.jpg
# -rw------- 1 root root    642804 Mar 29  2014  photo.JPG
# -rw------- 1 root root   3399234 Mar 30  2014  IMG_0008.MOV
# -rw------- 1 root root       151 Apr  4  2014 'Chotard+ 2011.gslides'
# -rw------- 1 root root       151 Apr  7  2014 'Untitled presentation (6).gslides'
# -rw------- 1 root root       151 May  7  2014  MS#ApJS94897.gdoc
# -rw------- 1 root root    132888 May 10  2014 'photo (1).JPG'
# -rw------- 1 root root       151 May 15  2014 'Probing the progenitors channels of stripped SN with the CfA SN sample..gdoc'
# -rw------- 1 root root       151 May 29  2014 'eta car echoes meeting 04 23.gdoc'
# -rw------- 1 root root    245579 Jun 10  2014  Stellar_Evolution_large.jpg
# -rw------- 1 root root    654426 Jun 11  2014  wessoccs.zip
# -rw------- 1 root root       151 Jun 17  2014 'bianco+2014 answers.gdoc'
# -rw------- 1 root root       151 Jun 18  2014 'lyman14 velocities.gsheet'
# -rw------- 1 root root    389742 Jun 23  2014 'Screen Shot 2014-06-23 at 3.53.47 PM.png'
# -rw------- 1 root root       151 Jun 25  2014 'Untitled spreadsheet (25).gsheet'
# -rw------- 1 root root       151 Jun 30  2014 'Untitled spreadsheet (27).gsheet'
# -rw------- 1 root root    177091 Jul 26  2014  IMG_2177.jpg
# -rw------- 1 root root    242442 Jul 26  2014  IMG_2178.jpg
# -rw------- 1 root root    240141 Jul 26  2014  IMG_2182.jpg
# -rw------- 1 root root    723341 Jul 26  2014  IMG_2192.jpg
# -rw------- 1 root root    723341 Jul 26  2014  IMG_2192-1.jpg
# -rw------- 1 root root   6264978 Aug  2  2014  Rhodes_SN.key
# -rw------- 1 root root       151 Aug  6  2014 'meteor showers in 30 sec.gdoc'
# -rw------- 1 root root   1941672 Aug 10  2014  IMG_0904.JPG
# -rw------- 1 root root    689657 Aug 10  2014  IMG_0867.JPG
# -rw------- 1 root root       151 Aug 11  2014 'Copy of CfA.SNIbc.BIGINFO.list.gsheet'
# -rw------- 1 root root       151 Aug 13  2014 'Untitled document (90).gdoc'
# -rw------- 1 root root       151 Aug 14  2014 ' eta car echoes  TARGET LIST.gdoc'
# -rw------- 1 root root       151 Aug 21  2014 'OANDA exchange rate Australian Dollar to USD.gsheet'
# -rw------- 1 root root       151 Aug 23  2014  d11_dom.gsheet
# -rw------- 1 root root     33762 Aug 23  2014 'Screen Shot 2014-08-23 at 5.40.18 PM.png'
# -rw------- 1 root root       151 Aug 26  2014 'Untitled document (78).gdoc'
# -rw------- 1 root root      8751 Aug 27  2014  SN07gr.photometry_derived.png
# -rw------- 1 root root    386503 Oct  2  2014  SNYUqrcode_fancy
# -rw------- 1 root root      3117 Oct  2  2014  SNYUqrcode.png
# -rw------- 1 root root   2034677 Oct  4  2014  GMT2014.pdf
# -rw------- 1 root root       151 Oct  8  2014  vphfe.gsheet
# -rw------- 1 root root       151 Oct  8  2014  fevel.gsheet
# -rw------- 1 root root       151 Oct  8  2014 'Untitled Spreadsheet (2).gsheet'
# -rw------- 1 root root      1675 Oct  8  2014  comp_Fe_old_new.csv
# -rw------- 1 root root       151 Oct  8  2014  comp_Fe_old_new.gsheet
# -rw------- 1 root root    625308 Oct 26  2014  building-comprehensive-complete.zip
# -rw------- 1 root root       151 Nov  5  2014 'Untitled document (82).gdoc'
# -rw------- 1 root root       151 Nov  7  2014 'Untitled spreadsheet (28).gsheet'
# -rw------- 1 root root     26069 Nov  7  2014  2003VS2.png
# -rw------- 1 root root    222756 Nov 13  2014  11img-179017.png
# -rw------- 1 root root     71455 Nov 15  2014 'Swift Cycle 11 NDA.pdf'
# -rw------- 1 root root       151 Nov 19  2014 'fed job apps 2014-5 HOGG.gsheet'
# -rw------- 1 root root       151 Dec  4  2014 'Untitled spreadsheet (20).gsheet'
# -rw------- 1 root root       151 Dec 13  2014  panel.gsheet
# -rw------- 1 root root       151 Dec 17  2014 'Untitled Spreadsheet (1).gsheet'
# -rw------- 1 root root       151 Dec 28  2014 'fed job apps 2014-5.gsheet'
# -rw------- 1 root root       151 Dec 30  2014 'fed job apps 2014-5 - Charles.gsheet'
# -rw------- 1 root root    234426 Jan  1  2015  Guide_to_Chambliss_Judging_final_Dec_2014.pdf
# -rw------- 1 root root       151 Jan  5  2015 'Untitled spreadsheet (24).gsheet'
# -rw------- 1 root root       151 Jan 13  2015 'Untitled document (79).gdoc'
# -rw------- 1 root root       151 Jan 16  2015 'L14 vs CfA.gsheet'
# -rw------- 1 root root    524798 Jan 19  2015 'science train.001.jpg'
# -rw------- 1 root root     58354 Feb  1  2015  Abundance_Maryam_29_Aug13.pro
# -rw------- 1 root root     32768 Feb  3  2015  Bianco--1-26-2015.doc
# -rw------- 1 root root       151 Feb  6  2015 'KBO occultations: historical perspective.gdoc'
# -rw------- 1 root root       151 Feb  6  2015 'Untitled document (63).gdoc'
# -rw------- 1 root root       151 Feb 17  2015 'Untitled spreadsheet (19).gsheet'
# -rw------- 1 root root       151 Feb 26  2015 'how to share google docs.gdoc'
# -rw------- 1 root root       151 Mar  2  2015 'lucia seminar participants.gsheet'
# -rw------- 1 root root       151 Mar  3  2015  fbbresume.gdoc
# -rw------- 1 root root    999471 Mar  3  2015  Label-327951343.pdf
# -rw------- 1 root root       151 Mar  3  2015 'Untitled document (64).gdoc'
# -rw------- 1 root root       151 Mar 10  2015 'fed job apps 2014-5 Andy.gsheet'
# -rw------- 1 root root       151 Mar 11  2015 'Untitled document (72).gdoc'
# -rw------- 1 root root    669434 Mar 19  2015 'UW (1).zip'
# -rw------- 1 root root       151 Mar 24  2015  Abundance_Maryam_29_Aug13.pro.gdoc
# -rw------- 1 root root    669434 Mar 27  2015  UW.zip
# -rw------- 1 root root       151 Apr  2  2015 'KD comb scales spreadsheet.gsheet'
# -rw------- 1 root root   2420580 Apr  6  2015  P1060076.jpg
# -rw------- 1 root root   2420580 Apr  6  2015 'P1060076 (1).jpg'
# -rw------- 1 root root         0 Apr  6  2015  IMG_0780.MOV
# -rw------- 1 root root         0 Apr  6  2015  IMG_0782.MOV
# -rw------- 1 root root         0 Apr  6  2015  IMG_0783.MOV
# -rw------- 1 root root       151 Apr  9  2015 'Abundance_Maryam_29_Aug13 (1).pro.gdoc'
# -rw------- 1 root root       151 Apr 16  2015 'Untitled document (58).gdoc'
# -rw------- 1 root root       151 Apr 22  2015 'Boxing Answers .gdoc'
# -rw------- 1 root root    306757 Apr 27  2015 'Screen Shot 2015-04-23 at 3.38.16 PM.png'
# -rw------- 1 root root    307695 Apr 27  2015 'Screen Shot 2015-04-23 at 3.37.05 PM.png'
# -rw------- 1 root root     29594 May  7  2015  sn1990B_Ic-norm_4_z_comp0001_snidflux.ps
# -rw------- 1 root root      2776 May  8  2015  bootplot4.py
# -rw------- 1 root root      4288 May  8  2015  residplot.py
# -rw------- 1 root root     98954 May 13  2015  otherAppsImage.jpg
# -rw------- 1 root root    356486 May 14  2015 'PAGINA 18.pdf'
# -rw------- 1 root root   1652482 May 18  2015  ms.pdf
# -rw------- 1 root root     50396 May 25  2015  5.25.pdf
# -rw------- 1 root root     36164 Jun  5  2015  ObjectIdentification_MinimalInfo.ods
# -rw------- 1 root root       151 Jun  5  2015  ObjectIdentification_MinimalInfo.ods.gsheet
# -rw------- 1 root root       119 Jun  6  2015 'vegan and veggy meals in philly.gmap'
# -rw------- 1 root root       119 Jun  6  2015 'philly hip bars.gmap'
# -rw------- 1 root root       119 Jun  6  2015 "Gleason's Gym.gmap"
# -rw------- 1 root root    323864 Jun  9  2015  11bov.pdf
# -rw------- 1 root root     76800 Jun 25  2015 'Hogg Bianco - NASA K2 Budget (1).xls'
# -rw------- 1 root root     76800 Jun 28  2015 'Hogg Bianco - NASA K2 Budget.xls'
# -rw------- 1 root root       151 Jun 29  2015  fbb_K2_biosketch.gdoc
# -rw------- 1 root root       151 Jun 29  2015 'Untitled document (60).gdoc'
# -rw------- 1 root root    425264 Jun 29  2015  rstreet_support_letter_signed.pdf
# -rw------- 1 root root     89871 Jun 29  2015  FBB_collab_letter.pdf
# -rw------- 1 root root       151 Jun 30  2015 'Untitled document (61).gdoc'
# -rw------- 1 root root       151 Jul  9  2015 'US curriculum meeting.gdoc'
# -rw------- 1 root root       151 Jul 13  2015 'Dear Editors of Astronomy&Computing,.gdoc'
# -rw------- 1 root root   2707858 Jul 17  2015  scan015.pdf
# -rw------- 1 root root       151 Jul 23  2015  macho-taos.gsheet
# -rw------- 1 root root       151 Jul 24  2015 'Untitled Spreadsheet.gsheet'
# -rw------- 1 root root     51306 Jul 25  2015  etaspec14A.fed.tex
# -rw------- 1 root root  13886349 Jul 31  2015  workspaceswDECAMeta03a3.mov
# -rw------- 1 root root   1011062 Aug 17  2015  IMG_6180.MOV
# -rw------- 1 root root       151 Aug 19  2015 'GETTING AND PROCESSING DECAM DATA.gdoc'
# -rw------- 1 root root       151 Aug 25  2015 'RF meeting.gdoc'
# -rw------- 1 root root       151 Sep  7  2015 'Untitled spreadsheet.gsheet'
# -rw------- 1 root root       151 Sep 16  2015  co_fed.gdoc
# -rw------- 1 root root       151 Sep 27  2015  CfA.SNIbc.BIGINFO.list.gsheet
# -rw------- 1 root root       151 Sep 29  2015 'PUI 2015 HW 3 M.gdoc'
# -rw------- 1 root root       151 Sep 29  2015 'PUI 2015 HW 3 W.gdoc'
# -rw------- 1 root root     53185 Sep 30  2015  NYUtemp-3long-BW.dotx
# -rw------- 1 root root       151 Sep 30  2015  NYUtemp-3long-BW.dotx.gdoc
# -rw------- 1 root root       151 Oct  9  2015 'PUI 2015 HW 4 W.gdoc'
# -rw------- 1 root root       151 Oct 15  2015 'PUI 2015 HW 5 M W.gdoc'
# -rw------- 1 root root       151 Oct 26  2015 'midterm hints.gdoc'
# -rw------- 1 root root       119 Oct 28  2015 'genova quick tour.gmap'
# -rw------- 1 root root       151 Nov  1  2015 'Untitled spreadsheet (2).gsheet'
# -rw------- 1 root root     36014 Nov  5  2015 'repush date.PNG'
# -rw------- 1 root root       151 Nov  7  2015 'LSST TVS chair position.gdoc'
# -rw------- 1 root root       151 Nov  9  2015  PUImidtermM2015.gsheet
# -rw------- 1 root root    139278 Nov 15  2015  fb_teaching.pdf
# -rw------- 1 root root       151 Nov 17  2015 'Untitled document (5).gdoc'
# -rw------- 1 root root     65481 Nov 19  2015  XHTDEE.pdf
# -rw------- 1 root root       151 Nov 20  2015 'transient chapter tables.gdoc'
# -rw------- 1 root root       151 Nov 20  2015 'Untitled document (54).gdoc'
# -rw------- 1 root root       151 Dec  1  2015 'application season 2015.gsheet'
# drwx------ 2 root root      4096 Dec  3  2015  __appdata__/
# -rw------- 1 root root       151 Dec  4  2015 'UO Hypertemporal photometry of City Lights.gdoc'
# -rw------- 1 root root      5159 Dec  4  2015 'application season 2015.xlsx'
# -rw------- 1 root root       151 Dec  7  2015 'pymcz referee report .gdoc'
# -rw------- 1 root root       151 Dec 16  2015 'Response to Anonymous reviewer #1:.gdoc'
# -rw------- 1 root root       151 Dec 16  2015 'Response to Anonymous reviewer #2.gdoc'
# -rw------- 1 root root       151 Jan  9  2016 'astro 101 2013 grades.gsheet'
# -rw------- 1 root root       151 Jan 14  2016 'Wsession HW1-5.gsheet'
# -rw------- 1 root root     23223 Jan 15  2016  velocity.pdf
# -rw------- 1 root root    966900 Jan 17  2016 'Screen Shot 2016-01-17 at 5.21.42 PM.png'
# -rw------- 1 root root       151 Jan 21  2016 'ResearchSummary blavatnikaward .gdoc'
# -rw------- 1 root root       151 Jan 28  2016 'Scott Hilberry reference.gdoc'
# -rw------- 1 root root       151 Feb  3  2016 'nyu letter head.gdoc'
# -rw------- 1 root root       151 Feb  3  2016 'shi recommendation.gdoc'
# -rw------- 1 root root       151 Feb  6  2016 'yuqian reference letter.gdoc'
# -rw------- 1 root root       151 Feb  6  2016 'PTF09q SN 2009bh.gdoc'
# -rw------- 1 root root       151 Feb  8  2016 'TVS Rodad Map March 2016 Schedule.gdoc'
# -rw------- 1 root root       151 Feb  9  2016 'TVS roadmap blur.gdoc'
# -rw------- 1 root root       151 Feb  9  2016 'spring hackaton.gdoc'
# -rw------- 1 root root    184192 Feb 10  2016  TVS_full_list.numbers
# -rw------- 1 root root    497337 Feb 10  2016  TVS_full_list.xlsx
# -rw------- 1 root root       151 Feb 10  2016  TVS_full_list.gsheet
# -rw------- 1 root root       151 Feb 10  2016 'TVS_full_list (1).gsheet'
# -rw------- 1 root root       151 Feb 10  2016 'LSST subgroups - Sheet1.gsheet'
# -rw------- 1 root root   5126096 Feb 10  2016 'Pages from ABB Book.pdf'
# -rw------- 1 root root       151 Feb 11  2016  AS4_TDA_Nov2015_20160119notes_ecb.docx.gdoc
# -rw------- 1 root root     31274 Feb 11  2016  AS4_TDA_20160211.docx
# -rw------- 1 root root   1533249 Feb 12  2016  GW.jpg
# -rw------- 1 root root       151 Feb 25  2016 'setting up my new mac mountainlion and ElCapitan.gdoc'
# -rw------- 1 root root       151 Feb 26  2016 'TVS roadmap subgroups.gsheet'
# -rw------- 1 root root       151 Feb 26  2016 'Ejecta mass Phot Analysis paper outline 2015-16.gdoc'
# -rw------- 1 root root       151 Feb 28  2016 'Vira comet.gdoc'
# -rw------- 1 root root     56820 Mar 10  2016  velocity_2.png
# -rw------- 1 root root     13798 Mar 14  2016  TVS_full_list_contact.csv
# -rw------- 1 root root       151 Mar 15  2016 'TVS_full_list_contact (2).csv.gsheet'
# -rw------- 1 root root     14088 Mar 15  2016 'TVS_full_list_contact (1).csv'
# -rw------- 1 root root       151 Mar 15  2016  TVS_full_list_contact.csv.gsheet
# -rw------- 1 root root     14480 Mar 15  2016 'TVS_full_list_contact (2).csv'
# -rw------- 1 root root      2208 Mar 15  2016  meetingsg.csv
# -rw------- 1 root root       151 Mar 17  2016 'stripped SN date of max from MC resampling.gdoc'
# -rw------- 1 root root       151 Mar 17  2016  SN_w_max_Fe_measured.gdoc
# -rw------- 1 root root     49250 Mar 20  2016  Modjaz-WomenNYUChallenge-Abstract.pdf
# -rw------- 1 root root    432229 Mar 20  2016  Modjaz-NYUWomenChallenge.pdf
# -rw------- 1 root root       151 Mar 24  2016 'subgroup presentations.gsheet'
# -rw------- 1 root root       151 Mar 25  2016 'Untitled document (11).gdoc'
# -rw------- 1 root root       151 Mar 25  2016 'TVS Roadmap Meeting Ride Share sign up.gsheet'
# -rw------- 1 root root       151 Mar 25  2016 'Non-Degenerate Eruptove Variables RoadMap.gdoc'
# -rw------- 1 root root       151 Mar 25  2016 'TVS_full_list_contact (1).csv.gsheet'
# -rw------- 1 root root       151 Mar 28  2016 'monday grades.gsheet'
# -rw------- 1 root root       151 Apr  3  2016  test_python_access.gsheet
# -rw------- 1 root root    269100 Apr  7  2016  transients_standalone.pdf
# -rw------- 1 root root       151 Apr  8  2016  Yuqian_appendicxA-D.gdoc
# -rw------- 1 root root       151 Apr 19  2016 'Untitled presentation.gslides'
# drwx------ 2 root root      4096 Apr 20  2016  filament/
# -rw------- 1 root root       151 Apr 25  2016 'Untitled document (14).gdoc'
# -rw------- 1 root root    501868 May 13  2016  ESB_119.75_camera4_50ms_1999_1706.GIF
# -rw------- 1 root root  71448184 Jun  3  2016 'LSST_TVS _template (2).key'
# -rw------- 1 root root   2314544 Jun  5  2016  IMG_0316.JPG
# -rw------- 1 root root  71445709 Jun  6  2016 'LSST_TVS _template (1).kth'
# -rw------- 1 root root  71545977 Jun  6  2016 'LSST_TVS _template (1).key'
# -rw------- 1 root root  73013352 Jun  7  2016 'LSST_TVS _template.kth'
# -rw------- 1 root root  73013773 Jun  7  2016 'LSST_TVS _template.key'
# -rw------- 1 root root       151 Jun 29  2016 'Untitled document (10).gdoc'
# dr-x------ 2 root root      4096 Jul  4  2016  Pbbfight/
# -rw------- 1 root root 647900664 Jul  4  2016 'Fed and Kim.mp4'
# -rw------- 1 root root 137243311 Jul  4  2016  00104.mov
# -rw------- 1 root root 124444801 Jul  4  2016  00103.mov
# -rw------- 1 root root 121389988 Jul  4  2016  00102.mov
# -rw------- 1 root root 121478075 Jul  4  2016  00101.mov
# -rw------- 1 root root       151 Jul 12  2016 'Untitled document (94).gdoc'
# -rw------- 1 root root       151 Jul 13  2016 'Untitled document (93).gdoc'
# -rw------- 1 root root     94902 Jul 17  2016 'Talking Guerilla Science.pdf'
# -rw------- 1 root root       151 Jul 18  2016  SCOPATONS:.gdoc
# -rw------- 1 root root       151 Jul 21  2016 'Untitled document (92).gdoc'
# -rw------- 1 root root       151 Jul 27  2016 'Untitled document (91).gdoc'
# -rw------- 1 root root       151 Aug  6  2016 'Wiki to HTML flow.gdoc'
# -rw------- 1 root root     72409 Aug 17  2016  PVZLDD.pdf
# -rw------- 1 root root       151 Aug 21  2016 'Untitled document (88).gdoc'
# -rw------- 1 root root       151 Aug 22  2016 'Untitled document (87).gdoc'
# -rw------- 1 root root       151 Aug 24  2016 'Untitled document (86).gdoc'
# -rw------- 1 root root       151 Aug 26  2016 'Untitled document (85).gdoc'
# -rw------- 1 root root       151 Sep  2  2016 'PUI syllabus Fall 2015.gdoc'
# -rw------- 1 root root       151 Sep  3  2016  LSST-TVS-communicationAugust2016.gdoc
# -rw------- 1 root root       151 Sep  4  2016  PEP8_short.gdoc
# -rw------- 1 root root    695388 Sep  7  2016  File_000.jpeg
# -rw------- 1 root root       151 Sep 10  2016 'preclass assessment.gsheet'
# -rw------- 1 root root       151 Sep 14  2016 'UO data acquisition.gsheet'
# -rw------- 1 root root       151 Sep 14  2016 'UO storage.gsheet'
# -rw------- 1 root root       151 Sep 15  2016 'Untitled spreadsheet (29).gsheet'
# -rw------- 1 root root       151 Sep 27  2016 'Untitled document (84).gdoc'
# -rw------- 1 root root       151 Oct  7  2016 'Camping graucery list.gdoc'
# -rw------- 1 root root       151 Oct 12  2016 'Untitled document (83).gdoc'
# -rw------- 1 root root       151 Oct 12  2016 'Untitled document (81).gdoc'
# -rw------- 1 root root     24104 Oct 13  2016 'Travel Expense Pre Authorization Form.docx'
# -rw------- 1 root root       151 Oct 18  2016  mariaFilippelliRecommandation.gdoc
# -rw------- 1 root root       151 Oct 20  2016 'Untitled spreadsheet (26).gsheet'
# -rw------- 1 root root       151 Oct 20  2016 'TVS LSST call 10 20.gdoc'
# -rw------- 1 root root  26803274 Oct 25  2016  LSST_TVS_intro.pdf
# -rw------- 1 root root       151 Oct 28  2016 'TVS LSST cadence proposals.gdoc'
# -rw------- 1 root root       151 Oct 28  2016 'Untitled document (80).gdoc'
# -rw------- 1 root root   1559873 Nov  1  2016  N0386.pdf
# -rw------- 1 root root     24601 Nov  1  2016  N0321_thesisa.pdf
# -rw------- 1 root root   1665573 Nov  1  2016  N0321.pdf
# -rw------- 1 root root    380309 Nov  1  2016  N0298.pdf
# -rw------- 1 root root    212168 Nov  1  2016  N0281.pdf
# -rw------- 1 root root   1271871 Nov  1  2016  N0151.pdf
# -rw------- 1 root root     26981 Nov  1  2016  N0139_thesisa.pdf
# -rw------- 1 root root   1315061 Nov  1  2016  N0139.pdf
# -rw------- 1 root root   5585865 Nov  1  2016  N0080.pdf
# -rw------- 1 root root 153735373 Nov  1  2016  N0061.pdf
# -rw------- 1 root root   1138286 Nov  1  2016  N0060.pdf
# -rw------- 1 root root       151 Nov  2  2016 'Untitled document (77).gdoc'
# -rw------- 1 root root       151 Nov  3  2016 'Untitled document (76).gdoc'
# -rw------- 1 root root     24158 Nov 18  2016 'PUI2016_Tue (1).xlsx'
# -rw------- 1 root root       151 Nov 19  2016 'Untitled spreadsheet (23).gsheet'
# -rw------- 1 root root       151 Nov 19  2016 'Untitled spreadsheet (22).gsheet'
# -rw------- 1 root root       151 Nov 25  2016 'Untitled spreadsheet (21).gsheet'
# -rw------- 1 root root       151 Nov 29  2016 'Untitled document (75).gdoc'
# -rw------- 1 root root       151 Nov 29  2016 'Untitled document (74).gdoc'
# -rw------- 1 root root       151 Dec  4  2016 'jobs 2016.gsheet'
# -rw------- 1 root root       151 Dec  6  2016 'Untitled document (73).gdoc'
# -rw------- 1 root root      9010 Dec  8  2016  carousel_image_fb084d49f0320057c720_DSC_0777.JPG
# -rw------- 1 root root       151 Dec  8  2016  PUI2016_quiz7.gdoc
# -rw------- 1 root root   1242329 Dec 12  2016  maximizing-potential-lsst.pdf
# -rw------- 1 root root       151 Dec 13  2016 'Untitled document (71).gdoc'
# -rw------- 1 root root       151 Dec 13  2016 'wednesday grades.gsheet'
# -rw------- 1 root root       151 Dec 17  2016 'census tracts geoid hint.gdoc'
# -rw------- 1 root root       151 Dec 17  2016 'Portions of the Slack conversations that may be useful.gdoc'
# -rw------- 1 root root     21817 Dec 22  2016  PUI2016_Tue.xlsx
# -rw------- 1 root root     15184 Dec 22  2016  rf.10813433.pdf
# -rw------- 1 root root       151 Dec 25  2016 'Untitled document (70).gdoc'
# -rw------- 1 root root       151 Dec 26  2016 'PUI2016 CLASS GRADES.gsheet'
# -rw------- 1 root root  26542080 Jan 18  2017  oct08_2013-10-25-175504-6092.raw
# -rw------- 1 root root       151 Feb 10  2017 'Untitled document (69).gdoc'
# -rw------- 1 root root    701147 Feb 12  2017 'sparring class.pages'
# -rw------- 1 root root    359720 Feb 12  2017 'sparring class.pdf'
# -rw------- 1 root root    869213 Feb 12  2017 'sparring class.docx'
# drwx------ 2 root root      4096 Feb 25  2017 'Shutter setup'/
# -rw------- 1 root root       151 Mar  4  2017 'Untitled document (68).gdoc'
# -rw------- 1 root root  32291366 Mar  4  2017 'NZReceipts (1).pdf'
# -rw------- 1 root root  32291366 Mar  4  2017  NZReceipts.pdf
# -rw------- 1 root root       151 Mar  4  2017 'Untitled document (67).gdoc'
# -rw------- 1 root root       151 Mar  4  2017 'Untitled document (66).gdoc'
# -rw------- 1 root root       151 Mar  6  2017 'Untitled document (65).gdoc'
# -rw------- 1 root root       151 Mar 13  2017 'DTU17 classification data challenge.gdoc'
# -rw------- 1 root root       151 Mar 17  2017 'NSF BIO_Bianco.docx.gdoc'
# -rw------- 1 root root     13383 Mar 21  2017 'NSF BIO_Bianco (1).docx'
# -rw------- 1 root root       151 Mar 25  2017 'Untitled document (62).gdoc'
# -rw------- 1 root root       151 Apr 13  2017 'Untitled presentation (5).gslides'
# -rw------- 1 root root    132731 Apr 13  2017  CSIAgenda4.12.17.pdf
# -rw------- 1 root root       151 Apr 14  2017 'Untitled form (5).gform'
# -rw------- 1 root root       151 Apr 17  2017 'Welcome message draft.gdoc'
# -rw------- 1 root root  85104199 May 11  2017 'File May 11, 12 35 26 PM.mov'
# -rw------- 1 root root     67873 Jun  9  2017  ItineraryReceipt_24704673402.pdf
# -rw------- 1 root root  64361458 Jul 14  2017  PLAsTiCCmetrics.key
# -rw------- 1 root root  27073632 Jul 29  2017 'SQUID-Bike, Street Quality IDentification for citywide Bike Lane infrastructure (2).pdf'
# -rw------- 1 root root       151 Sep 13  2017 'PUI 2015 HW 1 W.gdoc'
# drwx------ 3 root root      4096 Sep 13  2017 'Southern Poverty Law Center'/
# -rw------- 1 root root       151 Sep 21  2017 'Untitled document (59).gdoc'
# drwx------ 2 root root      4096 Sep 21  2017 'class quiz'/
# -rw------- 1 root root       151 Sep 26  2017 'SPL DATAKIND.gdoc'
# -rw------- 1 root root       151 Sep 30  2017 'SC coordinator FBB.gdoc'
# -rw------- 1 root root       151 Oct 11  2017 'PRE-CLASS QUIZ PUI2017  Wednesday 10 11 2017.gdoc'
# -rw------- 1 root root       151 Oct 13  2017 'Untitled document (57).gdoc'
# -rw------- 1 root root       151 Oct 16  2017 'PUI 2015 HW 1 M.gdoc'
# -rw------- 1 root root       151 Oct 18  2017 'PUI2017 quiz 5 Session 1 Wed 10 18 2071.gdoc'
# -rw------- 1 root root       151 Oct 18  2017 'Linear Regression and OLS notes.gdoc'
# -rw------- 1 root root       151 Oct 19  2017 'PUI2017 Session 1 Thu morning  10 18 2017.gdoc'
# -rw------- 1 root root       151 Oct 21  2017 'reading list.gdoc'
# -rw------- 1 root root       151 Oct 26  2017 'Untitled document (56).gdoc'
# -rw------- 1 root root       151 Oct 26  2017 'Untitled document (55).gdoc'
# -rw------- 1 root root       151 Oct 26  2017 'Untitled spreadsheet (18).gsheet'
# -rw------- 1 root root       151 Nov  2  2017 'Untitled spreadsheet (17).gsheet'
# drwx------ 2 root root      4096 Nov  2  2017  talks/
# -rw------- 1 root root   9941504 Nov  2  2017  LSSTSNRevolution2017.ppt
# -rw------- 1 root root  10425216 Nov  2  2017  LSSTSNRevolution2017.key
# -rw------- 1 root root       151 Nov  2  2017 'LSSTSNRevolution2017 (1).ppt.gslides'
# -rw------- 1 root root   3392818 Nov  3  2017 'Science Collaborations.pptx'
# -rw------- 1 root root       151 Nov  3  2017 'Science Collaborations.pptx.gslides'
# -rw------- 1 root root       151 Nov  3  2017  LSSTSNRevolution2017.ppt.gslides
# -rw------- 1 root root 197479472 Nov  3  2017  uo.pptx
# drwx------ 2 root root      4096 Nov  3  2017  Fed/
# drwx------ 2 root root      4096 Nov  3  2017  Fed2/
# -rw------- 1 root root 449918726 Nov  3  2017  LSST_intro_public.pptx
# drwx------ 2 root root      4096 Nov  4  2017  nbs/
# -rw------- 1 root root      7639 Nov  6  2017  PUI2017_Morning_HW_1-5_Quiz_Grades.xlsx
# -rw------- 1 root root       151 Nov  6  2017 'PUI2017_Morning_HW_1-5_Quiz_Grades (1).xlsx.gsheet'
# -rw------- 1 root root       151 Nov  6  2017  PUI2017_Morning_HW_1-5_Quiz_Grades.xlsx.gsheet
# -rw------- 1 root root       151 Nov  6  2017 'PUI Grading evening.xlsx.gsheet'
# -rw------- 1 root root       151 Nov 15  2017 'Untitled document.gdoc'
# -rw------- 1 root root    174751 Nov 26  2017  bookmarks_11_26_17.html
# -rw------- 1 root root       151 Nov 30  2017 'Untitled document (1).gdoc'
# -rw------- 1 root root       151 Nov 30  2017 'Pui2017 quiz 11 30 PM.gdoc'
# -rw------- 1 root root       151 Nov 30  2017 'PUI2017quiz Thursday,11 30 2017 PM.gdoc'
# -rw------- 1 root root     49639 Dec  2  2017 'BEST HACK (1).pdf'
# -rw------- 1 root root       151 Dec 14  2017 'Tips on clustering.gdoc'
# -rw------- 1 root root       151 Dec 15  2017 'PUI2017final hints.gdoc'
# -rw------- 1 root root       151 Dec 18  2017 'Untitled document (2).gdoc'
# -rw------- 1 root root       151 Dec 23  2017 'Untitled spreadsheet (1).gsheet'
# -rw------- 1 root root  53287493 Dec 24  2017  PUI2017final_zz1749.ipynb
# -rw------- 1 root root  53287493 Dec 24  2017 'PUI2017final_zz1749 (1).ipynb'
# -rw------- 1 root root       151 Jan  5  2018 'Untitled document (3).gdoc'
# -rw------- 1 root root       151 Jan  5  2018 'Untitled document (4).gdoc'
# drwx------ 2 root root      4096 Jan 23  2018  references/
# drwx------ 2 root root      4096 Jan 23  2018  PUI/
# drwx------ 2 root root      4096 Jan 24  2018  CUSP/
# -rw------- 1 root root       151 Jan 24  2018  FBBshortCV.gdoc
# -rw------- 1 root root    149248 Jan 28  2018 'Santa Fe Institute App.docx'
# -rw------- 1 root root       151 Jan 28  2018 'Santa Fe Institute App.docx.gdoc'
# -rw------- 1 root root    472988 Jan 29  2018 'Julien Baur 4.1.18.docx'
# -rw------- 1 root root       151 Feb  2  2018  fbb_UD.gdoc
# -rw------- 1 root root     21653 Feb  2  2018 'NSF BIO_Bianco.docx'
# -rw------- 1 root root       151 Feb  2  2018 'Untitled document (6).gdoc'
# -rw------- 1 root root       151 Feb  2  2018 'Untitled drawing.gdraw'
# -rw------- 1 root root       151 Feb  3  2018 'Urban Metabolism studies: detection and tracking of building generated pollutant plumes.gdoc'
# -rw------- 1 root root  65925849 Feb  4  2018  File_000.mov
# -rw------- 1 root root       151 Feb  6  2018  ranks.gsheet
# -rw------- 1 root root  23447367 Feb 12  2018  IMG_0229.TRIM.MOV
# -rw------- 1 root root       151 Feb 12  2018 'Untitled document (7).gdoc'
# -rw------- 1 root root       151 Feb 12  2018 'This project will work to assess the viability of social media, particularly twitter, as a meter to measure the response of the population to policy implementation in the prosecutorial justice sector.gdoc'
# -rw------- 1 root root 401030340 Feb 13  2018  DSC_0089.AVI
# -rw------- 1 root root       151 Feb 15  2018 'TVS subgroup proposal.gform'
# -rw------- 1 root root       151 Feb 19  2018 'Untitled document (8).gdoc'
# -rw------- 1 root root       151 Feb 23  2018 'Untitled spreadsheet (3).gsheet'
# -rw------- 1 root root   2196293 Feb 27  2018  photometry.pdf
# -rw------- 1 root root   2196293 Feb 27  2018  Lupton_LSST_PSTSAC_02272018_photometry.pdf
# -rw------- 1 root root     13985 Mar  2  2018 '2018 Capstone assignments FINAL.XLSX'
# -rw------- 1 root root       151 Mar  6  2018 'TVS call 03 05 2018.gdoc'
# -rw------- 2 root root       151 Mar  9  2018 'lsst.org feedback request .gdoc'
# -rw------- 1 root root       151 Mar  9  2018 'march 9th meeting notes.gdoc'
# -rw------- 1 root root     53392 Mar  9  2018 'Job Description-LSSTCSCC 2015-Dec 1.docx'
# drwx------ 2 root root      4096 Mar 15  2018 'Colab Notebooks'/
# -rw------- 1 root root     85186 Mar 15  2018 '2018 Capstone assignments - worksheets.xlsx'
# -rw------- 1 root root       151 Mar 20  2018 '2018 Capstone assignments - worksheets.xlsx.gsheet'
# -rw------- 1 root root       151 Mar 20  2018  CUSPstudents_netIDGithub.gsheet
# -rw------- 1 root root     40885 Mar 23  2018 'ZHANG Lingyi Resume.pdf'
# -rw------- 1 root root       151 Mar 24  2018 'Untitled document (9).gdoc'
# -rw------- 1 root root      3110 Mar 27  2018 'Untitled Diagram.html'
# -rw------- 1 root root      5224 Mar 27  2018 'Untitled Diagram (1).html'
# -rw------- 1 root root       151 Mar 28  2018 'PST Astrometric data products.gdoc'
# -rw------- 1 root root     62687 Apr  1  2018 'Xianbo Gao reference letter.pdf'
# -rw------- 1 root root      3160 Apr  3  2018 'Untitled Diagram (2).html'
# -rw------- 1 root root      3160 Apr  3  2018 'Untitled Diagram (3).html'
# -rw------- 1 root root       151 Apr 11  2018 "gabriella's thesis - copy.gdoc"
# -rw------- 1 root root       151 Apr 16  2018 'Untitled form.gform'
# -rw------- 1 root root   9346936 Apr 16  2018  Bianco_SC_F2F2018.pdf
# -rw------- 1 root root   9346936 Apr 16  2018 'Bianco_SC_F2F2018 (1).pdf'
# -rw------- 1 root root       151 Apr 23  2018 'Untitled form (1).gform'
# -rw------- 1 root root 963544022 Apr 24  2018  yana_fdnyshow2018.mov
# -rw------- 1 root root   2362151 May  7  2018  IMG_8059.JPG
# -rw------- 1 root root   2160549 May  7  2018  IMG_8056.JPG
# -rw------- 1 root root   1970276 May  7  2018  IMG_8058.JPG
# -rw------- 1 root root   2115846 May  7  2018  IMG_8061.JPG
# -rw------- 1 root root   2061151 May  7  2018  IMG_8057.JPG
# -rw------- 1 root root   2157539 May  7  2018  IMG_8060.JPG
# -rw------- 1 root root   2120814 May  7  2018  IMG_8055.JPG
# -rw------- 1 root root   2157539 May  7  2018 'IMG_8060 (1).JPG'
# -rw------- 1 root root       151 May 22  2018 'Untitled document (12).gdoc'
# -rw------- 1 root root       151 May 22  2018 'Untitled document (13).gdoc'
# -rw------- 1 root root       151 May 26  2018 'ranking startup.gdoc'
# drwx------ 2 root root      4096 May 27  2018 'LSST TVS'/
# -rw------- 1 root root 579828857 May 29  2018  Q1_DE-AR0000886_NYUBianco.key
# -rw------- 1 root root       151 Jun  3  2018  house.gsheet
# -rw------- 1 root root       151 Jun  6  2018 'UD startup flexibility.gsheet'
# -rw------- 1 root root     97966 Jun  9  2018 'Screen Shot 2018-06-08 at 11.44.56 PM.png'
# -rw------- 1 root root       151 Jun 11  2018 'added coauthors.gsheet'
# -rw------- 1 root root     21434 Jun 18  2018  Budget_justification_NSF_UWM_Bianco.docx
# -rw------- 1 root root       151 Jun 18  2018 'Untitled spreadsheet (4).gsheet'
# -rw------- 1 root root     21893 Jun 18  2018 'NSF BIO_Bianco2018.docx'
# -rw------- 1 root root     19925 Jun 21  2018  startupsUD.ipynb
# -rw------- 1 root root      4470 Jun 21  2018 'Untitled Diagram (4).html'
# -rw------- 1 root root     39472 Jun 26  2018  box_whisker_pca.png
# -rw------- 1 root root       151 Jun 27  2018 'TVS publication report.gform'
# -rw------- 1 root root    399030 Jun 28  2018 'Proposal Award Notification-Information Letter 2018-01 Bianco-Street.pdf'
# -rw------- 1 root root    119331 Jun 28  2018 '4 Form W-9.pdf'
# -rw------- 1 root root     13459 Jun 28  2018 '3 2017 Financial Report Template.xlsx'
# -rw------- 1 root root   2138042 Jun 28  2018 '2 2017 Final Report and Financial Attestation Forms.pdf'
# -rw------- 1 root root    897915 Jun 28  2018 '1 2017 Proposal Award Information Form & Guidelines.pdf'
# -rw------- 1 root root       151 Jul  1  2018 'Untitled form (2).gform'
# -rw------- 1 root root       151 Jul  3  2018 'pubpolicy survey.gdoc'
# -rw------- 1 root root    330719 Jul  8  2018  seamlesslyPoor.ipynb
# -rw------- 1 root root       151 Jul  9  2018 'Untitled form (3).gform'
# -rw------- 1 root root   5981648 Jul 17  2018  2018-07-17_SC.pdf
# -rw------- 1 root root       151 Jul 17  2018 'PJ tweets presentation at Marron.gdoc'
# drwx------ 2 root root      4096 Jul 19  2018  LSSTCCAHackathon/
# -rw------- 1 root root       151 Jul 25  2018 'MHealth slides.gdoc'
# -rw------- 1 root root       151 Jul 26  2018 'Plumes slides.gdoc'
# -rw------- 1 root root       151 Jul 26  2018 'Untitled document (15).gdoc'
# -rw------- 1 root root       151 Jul 31  2018 'Hypertemporal visible imaging of an urban lightscape can reveal the phase of the electrical grid granular to individual housing units.gdoc'
# -rw------- 1 root root       151 Aug  8  2018 'LSST TVS subgroup proposal.gform'
# -rw------- 1 root root       151 Aug  8  2018 'Untitled document (16).gdoc'
# -rw------- 1 root root       151 Aug  8  2018 'Untitled spreadsheet (5).gsheet'
# -rw------- 1 root root       151 Aug  8  2018 'TAs 2018.gsheet'
# -rw------- 1 root root   2235526 Aug  8  2018  IMG_0120.JPG
# -rw------- 1 root root   1844382 Aug  8  2018  IMG_0118.JPG
# -rw------- 1 root root   2606914 Aug  8  2018  IMG_0117.JPG
# -rw------- 1 root root       151 Aug 14  2018 'Transients & Variable Stars SC - Blending impacts & metrics.gslides'
# -rw------- 1 root root       151 Aug 17  2018 'Untitled spreadsheet (6).gsheet'
# -rw------- 1 root root       151 Aug 17  2018 'Untitled spreadsheet (7).gsheet'
# -rw------- 1 root root     11617 Aug 17  2018  movies.csv
# -rw------- 1 root root       151 Aug 17  2018  movies.gsheet
# -rw------- 1 root root       151 Aug 17  2018 'movies (1).gsheet'
# -rw------- 1 root root       151 Aug 17  2018 'movies (2).gsheet'
# -rw------- 1 root root     16223 Aug 17  2018  alienmovies.tsv
# -rw------- 1 root root       151 Aug 17  2018  alienmovies.gsheet
# -rw------- 1 root root       151 Aug 22  2018 'Untitled document (17).gdoc'
# -rw------- 1 root root       151 Aug 22  2018 'Copy of all_music_gear.gsheet'
# -rw------- 1 root root     43367 Aug 23  2018  A1DBA84B-27E0-4B23-A409-135AA52FB3FD.png
# -rw------- 1 root root       151 Aug 23  2018 'Untitled document (18).gdoc'
# -rw------- 1 root root     40795 Aug 26  2018 'BIA02-01 Modified Provisional Application - with GA_s changes-c SEK.docx'
# -rw------- 1 root root       151 Aug 28  2018 'BIA02-01 Modified Provisional Application - with GA_s changes-c SEK.gdoc'
# -rw------- 1 root root       151 Aug 28  2018 'Copy of BIA02-01 Modified Provisional Application - with GA_s changes-c SEK - sek.gdoc'
# -rw------- 1 root root       151 Aug 28  2018 'Key numbers final.gdoc'
# -rw------- 1 root root       151 Aug 29  2018 'LSST organization.gslides'
# -rw------- 1 root root     14300 Aug 30  2018 'Questionnaire (R).docx'
# -rw------- 1 root root       151 Sep  5  2018 'Done for house.gsheet'
# -rw------- 2 root root       151 Sep  5  2018 'SC content.gdoc'
# -rw------- 1 root root       151 Sep  9  2018 'Untitled document (19).gdoc'
# -rw------- 1 root root       151 Sep  9  2018 'Untitled document (20).gdoc'
# -rw------- 1 root root       151 Sep 10  2018 'PUI non CUSP students .gdoc'
# -rw------- 1 root root     36382 Sep 12  2018 'Untitled Diagram (5).html'
# -rw------- 1 root root    199141 Sep 12  2018  HTIdrawings.png
# -rw------- 1 root root       151 Sep 15  2018 'AAS12948 referee report.gdoc'
# -rw------- 1 root root       151 Sep 16  2018 'Untitled spreadsheet (8).gsheet'
# -rw------- 1 root root       151 Sep 16  2018 'F.B.Bianso SC Coordinator worksheet.gsheet'
# -rw------- 1 root root       151 Sep 17  2018 'local info flatiron.gdoc'
# -rw------- 1 root root       151 Sep 20  2018 'Untitled document (21).gdoc'
# -rw------- 1 root root       151 Sep 24  2018 'Science Collaboration  White Paper Responses Federica Bianco Science Collaborations Coordinator  and the Science Collaboration Reps.gslides'
# -rw------- 1 root root       151 Sep 24  2018 'Untitled document (22).gdoc'
# -rw------- 1 root root       151 Sep 24  2018 'Fast Transients.gslides'
# -rw------- 1 root root       151 Sep 26  2018 'LSST PST and Science Collaboration Chairs Telecon, Wednesday September 26, 2018.gdoc'
# drwx------ 2 root root      4096 Sep 28  2018  August/
# -rw------- 1 root root       151 Oct  2  2018 'Untitled document (23).gdoc'
# -rw------- 1 root root  23154058 Oct  3  2018  UI4_PUI2018.key
# -rw------- 1 root root       151 Oct  7  2018 'Science Collaboration  White Paper Responses .gslides'
# -rw------- 1 root root       151 Oct  8  2018 'LSST Cadence Hacks CCA, Flatiron Institute.gslides'
# -rw------- 1 root root       151 Oct 12  2018 'Pui2017 quiz 6 evening.gdoc'
# -rw------- 1 root root       151 Oct 18  2018 'Electromagnetic Follow Up of MMA triggers.gdoc'
# -rw------- 1 root root       151 Oct 19  2018 'Untitled document (24).gdoc'
# -rw------- 1 root root   1184867 Oct 20  2018  _system_appendPDF_proof_hi.pdf
# -rw------- 1 root root       151 Oct 24  2018 'MMA Cyberinfrastructure LSST call.gdoc'
# -rw------- 1 root root       151 Oct 24  2018 'Untitled document (25).gdoc'
# -rw------- 1 root root       151 Oct 24  2018 'LSST 2018 TSO session.gdoc'
# -rw------- 1 root root       151 Nov  1  2018 'Copy of 6. Aggregation task.gdoc'
# drwx------ 2 root root      4096 Nov  7  2018 'PUI midterm 2018'/
# -rw------- 1 root root       151 Nov 13  2018 'Untitled presentation (1).gslides'
# -rw------- 1 root root 214190212 Nov 13  2018  Q3_DE-AR0000886_NYUBianco.key.zip
# -rw------- 1 root root       151 Nov 13  2018 'Fast Transients cadence proposal call 11 12.gdoc'
# -rw------- 1 root root       151 Nov 13  2018 'Untitled spreadsheet (9).gsheet'
# -rw------- 1 root root       151 Nov 13  2018 'Nsf career academy.gdoc'
# -rw------- 1 root root       151 Nov 14  2018  manTrees.gsheet
# -rw------- 1 root root       151 Nov 14  2018 'TVS White Paper Submissions.gsheet'
# -rw------- 1 root root 256669346 Nov 14  2018 "Tiffany Patafio's Personal Meeting Room-20181029 1702-1.arf"
# -rw------- 1 root root     18304 Nov 15  2018  HalfSemestergradesMorning.png
# -rw------- 1 root root       151 Nov 18  2018 'Untitled spreadsheet (10).gsheet'
# -rw------- 1 root root       151 Nov 19  2018 'Untitled document (26).gdoc'
# -rw------- 1 root root      3089 Nov 21  2018  sky_separation.py
# -rw------- 1 root root       151 Nov 22  2018 'Target  of  Opportunity  Observations  ofGravitational  Wave  Events  with  LSST Margutti.gdoc'
# -rw------- 1 root root       151 Nov 22  2018 'An Extreme Rolling Cadence (for TDEs) Gezari.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Mapping the Periphery and Variability of the Magellanic Clouds Olsen .gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Unique  Science  from  a  Coordinated  LSST-WFIRSTSurvey  of  the  Galactic  Bulge Street.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'The  Diverse  Science  Return  from  a  Wide-AreaSurvey  of  the  Galactic  Plane  - Street.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'A  Higher  Cadence  Subsurvey  Located  in  the Galactic  Plane Lund.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Gaia-LSST Synergy and Constraints to Pulsation Theory using LSST: Observations of variable stars in Local Group stellar systems.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Searching for white dwarf transits with LSST  - Silvotti.gdoc'
# -rw------- 1 root root       151 Nov 24  2018 'Continuous  Cadence  Acquisition  of  the  LSSTDeep  Drilling  Fields Bell.gdoc'
# -rw------- 1 root root       151 Nov 25  2018 'A  Cadence  to  Reduce  Aliasing  in  LSST Bell.gdoc'
# -rw------- 1 root root       151 Nov 25  2018 'TVS WP submissions.gsheet'
# -rw------- 1 root root       151 Nov 27  2018 'Explosive  Physics  and  Fast  Transients  White  PaperCadence Bianco.gdoc'
# -rw------- 1 root root       151 Nov 28  2018 'Blazars  (and  FRBs)  with  LSST Raiteri.gdoc'
# -rw------- 1 root root     53696 Nov 28  2018  Bianco.pdf
# -rw------- 1 root root       151 Nov 29  2018 'unVEil  the  darknesS  of  The  gAlactic  buLgE  (VESTALE) Bono   DallOra.gdoc'
# -rw------- 1 root root       151 Nov 29  2018 'Untitled document (31).gdoc'
# -rw------- 1 root root       151 Nov 29  2018 'Bianco UDel Phsyica&Astronomy   DSI  postdoc PDR.gdoc'
# -rw------- 1 root root       151 Nov 29  2018 'TDEs  with  LSST Bricman.gdoc'
# -rw------- 1 root root       151 Dec  2  2018 'PUI2018 Extra Credit Project Proposal.gdoc'
# -rw------- 1 root root       151 Dec  6  2018 'Pui quiz 11 am.gdoc'
# -rw------- 1 root root    336231 Dec  6  2018 'Committees guidelines from Executive Board Handbook_Final_R2_21Mar2018.pdf'
# -rw------- 1 root root       151 Dec  8  2018 'December 7th CUSP HackDay.gdoc'
# -rw------- 1 root root  94342945 Dec  9  2018  Somayeh_Khakpash.mov
# -rw------- 1 root root       151 Dec 10  2018 'December 10 LSST SC chairs call.gdoc'
# -rw------- 1 root root       151 Dec 14  2018 'Untitled document (40).gdoc'
# drwx------ 2 root root      4096 Dec 15  2018 'PUI Final2018 hints'/
# -rw------- 1 root root       151 Dec 18  2018 'PUI2018 Extra Credit Project Template.gdoc'
# -rw------- 1 root root       151 Dec 18  2018 'December 6 LSST SC chairs call.gdoc'
# -rw------- 1 root root       151 Dec 21  2018 'Untitled document (33).gdoc'
# -rw------- 1 root root      1050 Dec 26  2018  graded.csv
# -rw------- 1 root root   6229203 Jan  1  2019  Bianco_Federica-2018-03.jpg
# -rw------- 1 root root   9479331 Jan  1  2019 'FedericaBianco[FinalJPEGs]-270.jpg'
# -rw------- 1 root root  15117523 Jan  1  2019 'FedericaBianco[FinalJPEGs]-257.jpg'
# -rw------- 1 root root       151 Jan  4  2019 'Copy of Carreer Grant Proposal 01 03 2019.gdoc'
# -rw------- 1 root root       151 Jan  5  2019 'Carreer Grant Proposal 01 03 2019.gdoc'
# -rw------- 1 root root       151 Jan  5  2019 'Untitled spreadsheet (11).gsheet'
# -rw------- 1 root root  35469816 Jan  5  2019 'BiancoAAS233TownHallPPT 3.key'
# -rw------- 1 root root  35032358 Jan  5  2019 'BiancoAAS233TownHallPPT 3 (1).key'
# -rw------- 1 root root       151 Jan 11  2019 'LSST Cadence Hackathon at the Flatiron Institute.gdoc'
# -rw------- 1 root root       151 Jan 13  2019 'Untitled document (27).gdoc'
# -rw------- 1 root root       151 Jan 13  2019 'Untitled document (28).gdoc'
# -rw------- 1 root root       151 Jan 13  2019 'Untitled document (36).gdoc'
# -rw------- 1 root root       151 Jan 15  2019  PUI2017grades.gsheet
# -rw------- 1 root root       151 Jan 16  2019  draft.gdoc
# -rw------- 1 root root       151 Jan 25  2019 'TVS conf call 01 23 2019.gdoc'
# -rw------- 2 root root       151 Feb  1  2019 'GBS Committee Report and Notes.gdoc'
# -rw------- 1 root root       151 Feb  7  2019 'LOI AccelNet LSST SCs.gdoc'
# -rw------- 1 root root       151 Feb 11  2019 'LSST SC Accelnet prep form.gform'
# -rw------- 1 root root       151 Feb 12  2019 'LSST SC Chairs accelnet call 02 11 2019.gdoc'
# -rw------- 1 root root       151 Feb 12  2019 'SCiMMA Data management, communication, and collaboration meeting 1.gdoc'
# -rw------- 1 root root       151 Feb 12  2019 'Untitled presentation (4).gslides'
# -rw------- 1 root root   2911027 Feb 13  2019 'bg 2.png'
# -rw------- 1 root root       151 Feb 16  2019 'Copy of BaurJulienFBB.gdoc'
# -rw------- 1 root root       151 Feb 16  2019  BaurJulienFBB.gdoc
# -rw------- 1 root root     21684 Feb 20  2019  proposal_budget_v3.ods
# -rw------- 1 root root     24523 Feb 22  2019 'Budget  - NSF 19-501 - Bianco.xlsx'
# -rw------- 1 root root  40170678 Feb 23  2019  IMG_3406.MOV
# -rw------- 1 root root       151 Feb 25  2019 'Untitled presentation (2).gslides'
# -rw------- 1 root root     20932 Feb 25  2019  nsf-biosketch.docx
# -rw------- 1 root root       151 Feb 25  2019 'Untitled spreadsheet (16).gsheet'
# drwx------ 2 root root      4096 Feb 26  2019  LSSTBrokerWorkshop19/
# -rw------- 1 root root       151 Feb 26  2019 'Untitled document (52).gdoc'
# -rw------- 1 root root       151 Feb 28  2019 'LSST PST-SC meeting 02 27 19 notes.gdoc'
# -rw------- 1 root root       151 Mar  1  2019 'Review or resubmission.gdoc'
# -rw------- 1 root root       151 Mar  3  2019 'Untitled presentation (3).gslides'
# -rw------- 1 root root       151 Mar  4  2019 'Changes to PASP-100746 .gdoc'
# -rw------- 1 root root   2654688 Mar 13  2019  toms_and_brokers_lsst2018_fed.pdf
# -rw------- 1 root root       151 Mar 14  2019 'TVS task force proposal 2019.gform'
# -rw------- 1 root root       151 Mar 14  2019 'Untitled document (51).gdoc'
# -rw------- 1 root root       151 Mar 16  2019 'Untitled document (50).gdoc'
# -rw------- 1 root root       151 Mar 19  2019 'briefing on ODF - Steve Kahn - SC chairs.gdoc'
# -rw------- 1 root root 427576252 Mar 22  2019  udclass.key
# drwx------ 2 root root      4096 Mar 23  2019 'TED slides'/
# -rw------- 1 root root   3556610 Mar 23  2019  bg.jpg
# -rw------- 1 root root  25966618 Mar 23  2019  shutterstock_483529342.jpg
# -rw------- 1 root root       151 Mar 25  2019 'Untitled document (49).gdoc'
# -rw------- 1 root root 239431154 Mar 26  2019  fbbTedTalk_take1.mov
# -rw------- 1 root root  29918101 Mar 27  2019  CAA_LSSTSCs.pdf
# -rw------- 1 root root       151 Mar 27 21:36 'Live notes PST-SC chairs meeting 03 27.gdoc'
# -rw------- 1 root root 132844527 Mar 28 14:51  Q5_DE-AR0000886_NYUBianco.pdf
# -rw------- 1 root root       151 Mar 29 12:40 'Federica Bianco_PR Guide_TED2019 Fellows.gdoc'
# -rw------- 1 root root    113398 Mar 29 16:29 'Assessment of the impact of an LSST ODF from the Science Collaborations (1).pdf'
# -rw------- 1 root root    113398 Mar 29 17:25 'Assessment of the impact of an LSST ODF from the Science Collaborations.pdf'
# -rw------- 1 root root 150287408 Apr  4 15:15 'DarkUniverseNoSN (1).mp4'
# -rw------- 1 root root       151 Apr  5 19:10 'meeting mimutes template.gdoc'
# -rw------- 1 root root 150287408 Apr  6 17:54  DarkUniverseNoSN.mp4
# -rw------- 1 root root     23789 Apr  6 18:06 'Fact Check_Federica Bianco_v2.docx'
# -rw------- 1 root root       151 Apr  6 21:41 'Fact Check_Federica Bianco_v2 (1).gdoc'
# -rw------- 1 root root     22391 Apr  8 07:17  Atimeexchangemodel-thoughtsandscribblings.docx
# -rw------- 1 root root 667790373 Apr  8 18:23  DarkUniverseNoSN_slow.mov
# -rw------- 1 root root       151 Apr  9 19:15 'Letter to recommand dissolution of MB.gdoc'
# -rw------- 1 root root       151 Apr 14 21:48 'Fact Check_Federica Bianco_v2.gdoc'
# -rw------- 1 root root       151 Apr 14 23:17 'Federica Bianco II 2019 Talk prep  saved  .gdoc'
# -rw------- 1 root root       151 Apr 26 03:54 'NSF Career Grant proposal, F.gdoc'
# -rw------- 1 root root       151 Apr 30 22:48 'Untitled document (48).gdoc'
# drwx------ 2 root root      4096 May  1 12:01  LSST/
# -rw------- 1 root root       151 May  2 06:20 'Copy of Federica Bianco II 2019 Talk prep .gdoc'
# -rw------- 1 root root       151 May  2 21:33 'Untitled document (47).gdoc'
# -rw------- 1 root root     13210 May  3 18:14 'Female Undergrads in Physics for 2193.xlsx'
# -rw------- 1 root root   1910601 May  4 13:07  MVIMG_20190502_180146~2.jpg
# -rw------- 1 root root       151 May  7 00:24  Acquaviva.gdoc
# -rw------- 1 root root  27883444 May  7 13:13 'SierraLeone_urban_observatory (1).pdf'
# -rw------- 1 root root  27883444 May  7 13:14  SierraLeone_urban_observatory.pdf
# -rw------- 1 root root     23263 May  8 18:53 'Faculty and Staff Women in Physics.xlsx'
# -rw------- 1 root root       151 May  9 03:00 'research active WiPA-UD.gsheet'
# -rw------- 1 root root       151 May 12 20:16 'LSST SSSC chair nomination election.gform'
# -rw------- 1 root root       151 May 16 12:57 'TVS 2019 Task Force Sign up.gform'
# -rw------- 1 root root   1884736 May 18 06:41  tmp.key
# drwx------ 2 root root      4096 May 20 07:46  fights/
# -rw------- 1 root root       151 May 21 19:52 'TVS task force proposal 2019 (Responses).gsheet'
# -rw------- 1 root root       151 May 22 00:13 'TVS LSST@asia.gslides'
# drwx------ 2 root root      4096 May 22 18:11  photos/
# drwx------ 2 root root      4096 May 22 19:05  dads/
# -rw------- 1 root root   2727795 May 22 19:15  IMG_1819.JPG
# -rw------- 1 root root   1961768 May 22 19:15  IMG_1811.JPG
# -rw------- 1 root root   2202620 May 22 19:15  IMG_1810.JPG
# -rw------- 1 root root   2209121 May 22 19:15  IMG_1813.JPG
# -rw------- 1 root root   2359915 May 22 19:15  IMG_1812.JPG
# -rw------- 1 root root   2376989 May 22 19:15  IMG_1718.JPG
# -rw------- 1 root root   2570382 May 22 19:15  IMG_1814.JPG
# -rw------- 1 root root   2626336 May 22 19:16  IMG_1723.JPG
# -rw------- 1 root root   2913132 May 22 19:16  IMG_1719.JPG
# -rw------- 1 root root   3020886 May 22 19:16  IMG_1716.JPG
# -rw------- 1 root root   3072645 May 22 19:16  IMG_1818.JPG
# -rw------- 1 root root   3159030 May 22 19:16  IMG_1717.JPG
# -rw------- 1 root root   3233888 May 22 19:16  IMG_1720.JPG
# -rw------- 1 root root   3733596 May 22 19:16  IMG_1815.JPG
# -rw------- 1 root root   4050807 May 22 19:16  IMG_1722.JPG
# -rw------- 1 root root   4091945 May 22 19:16  IMG_1721.JPG
# -rw------- 1 root root   4224110 May 22 19:16  IMG_1816.JPG
# -rw------- 1 root root   4253500 May 22 19:16  IMG_1817.JPG
# -rw------- 1 root root   1792753 May 22 19:26  IMG_1890.JPG
# -rw------- 1 root root       151 May 23 02:30 'Untitled document (46).gdoc'
# -rw------- 2 root root       151 May 23 16:10 'LSST for-scientists webpages feedback.gform'
# -rw------- 1 root root       151 May 27 23:27 'needed for home.gsheet'
# -rw------- 1 root root       151 May 29 03:59 'UD-BNL Bianco Slosar  .gdoc'
# -rw------- 1 root root    159048 May 30 03:24 'Screen Shot 2019-05-02 at 11.39.54 PM.png'
# -rw------- 1 root root       151 May 30 21:12 'Untitled spreadsheet (15).gsheet'
# drwx------ 2 root root      4096 Jun  3 17:05 'LSSTC Executive Board SC committee'/
# -rw------- 1 root root       151 Jun  3 23:59 'Untitled document (45).gdoc'
# -rw------- 1 root root       151 Jun  4 00:51 'Untitled form (4).gform'
# -rw------- 1 root root    132086 Jun 12 14:35  LSST2020_rationale_v02.docx
# -rw------- 1 root root       151 Jun 15 16:03  NASPAA_LOI.gdoc
# drwx------ 2 root root      4096 Jun 18 16:37  tobacco/
# -rw------- 1 root root       151 Jun 19 04:13 'hackathon flowchart.gdraw'
# -rw------- 1 root root 146843498 Jun 21 21:46  presto-colorEWASS19.key
# -rw------- 1 root root       151 Jun 24 05:11 'Untitled document (29).gdoc'
# -rw------- 1 root root       151 Jun 29 19:35 'Copy of Vision for a Data Science curriculum for Public Service.gdoc'
# -rw------- 1 root root      1931 Jun 29 22:25 'Untitled Diagram.drawio'
# -rw------- 1 root root      6243 Jun 29 22:32 'Untitled Diagram (1).drawio'
# -rw------- 1 root root     53791 Jun 29 23:43 'DSPP curriculum logic model.svg'
# -rw------- 1 root root    341089 Jun 29 23:45 'DSPP curriculum logic model.png'
# -rw------- 1 root root    520894 Jun 30 14:18 'DSPP curriculum logic model.jpg'
# -rw------- 1 root root    521177 Jun 30 15:04 'DSPP curriculum logic model (1).jpg'
# -rw------- 1 root root    521177 Jun 30 15:07 'DSPP curriculum logic model (2).jpg'
# -rw------- 1 root root    521177 Jun 30 15:12 'DSPP curriculum logic model (3).jpg'
# -rw------- 1 root root    499934 Jun 30 15:13 'DSPP curriculum logic model (1).png'
# -rw------- 1 root root    500946 Jun 30 16:00 'DSPP curriculum logic model (2).png'
# -rw------- 1 root root       151 Jun 30 16:01 'Untitled drawing (1).gdraw'
# -rw------- 1 root root    500945 Jun 30 16:03 'DSPP curriculum logic model_final.png'
# -rw------- 1 root root    506032 Jun 30 16:20 'DSPP curriculum logic model_final2.png'
# -rw------- 1 root root      5515 Jun 30 16:47 'DSPP curriculum logic model.drawio'
# -rw------- 1 root root       151 Jun 30 22:16 'Untitled spreadsheet (13).gsheet'
# -rw------- 1 root root       151 Jul  1 16:16 'UD Fall hackathon 2019.gdoc'
# -rw------- 1 root root       151 Jul  1 16:44 'Untitled document (42).gdoc'
# -rw------- 1 root root       151 Jul  1 20:48 'TVS Subgroup Leads Telecon 2019 July 1st.gdoc'
# -rw------- 1 root root       151 Jul  2 00:06 'fig5 .gdraw'
# -rw------- 1 root root       151 Jul  2 19:18 'Vision for a Data Science curriculum for Public Service.gdoc'
# drwx------ 2 root root      4096 Jul  9 19:13  apiks/
# -rw------- 1 root root       151 Jul 10 17:20  Astro2020SCsF1.gdraw
# -rw------- 1 root root       151 Jul 12 02:16  tvssticker.gdraw
# -rw------- 1 root root       151 Jul 12 02:20  smwlvsticker.gdraw
# -rw------- 1 root root       151 Jul 12 02:26  descsticker.gdraw
# -rw------- 1 root root       151 Jul 12 03:57  ssscsticker.gdraw
# -rw------- 1 root root  53317774 Jul 12 17:36  bianco_S1_EWASS2019_LSST.pdf
# -rw------- 1 root root       151 Jul 14 22:58  AGNlogo.gdraw
# -rw------- 1 root root       151 Jul 15 00:12  SLSC.gdraw
# -rw------- 1 root root       151 Jul 15 00:22  GalSClogo.gdraw
# -rw------- 1 root root       151 Jul 16 19:12  TVSlogo.gdraw
# -rw------- 1 root root       151 Jul 16 19:19  TVSlogolabel.gdraw
# -rw------- 1 root root   3928132 Jul 19 17:08 'AC NSF ID -000747680 -Bianco Federica.docx'
# -rw------- 1 root root       151 Jul 22 20:25 'LSST SSSC chair election.gform'
# -rw------- 1 root root       151 Jul 30 02:01 'LSST Commissioning Input.gform'
# -rw------- 1 root root    259619 Jul 30 17:13  incubator_v3_ajc.docx
# -rw------- 1 root root       151 Jul 31 02:47 'Untitled spreadsheet (14).gsheet'
# -rw------- 1 root root       151 Jul 31 05:56 'SC speakers PCW 2019.gsheet'
# -rw------- 1 root root 167592148 Aug  7 21:34  VID_20190806_172853.mp4
# -rw------- 1 root root 345409413 Aug 11 14:08  CAA_LSSTSCs.key
# -rw------- 1 root root 345409413 Aug 11 14:11 'CAA_LSSTSCs (1).key'
# -rw------- 1 root root       151 Aug 11 14:15  Presentation1.gslides
# -rw------- 1 root root       151 Aug 11 14:18  CAA_LSSTSCs.gslides
# -rw------- 1 root root       151 Aug 11 14:19  Presentation2.gslides
# -rw------- 1 root root  56400286 Aug 12 12:28  sloth.mp4
# -rw------- 1 root root   4331719 Aug 12 12:28  IMG_20190810_081044_exported_stabilized_215728302638536747.mp4
# -rw------- 1 root root       151 Aug 12 12:59 'Untitled document (37).gdoc'
# -rw------- 1 root root       151 Aug 12 13:52 'WIPA-UD .gform'
# -rw------- 1 root root       151 Aug 13 07:38 'Galaxies plenary.gslides'
# -rw------- 1 root root       151 Aug 13 07:39 'Copy of LSST2019: LSST SCIENCE.gslides'
# -rw------- 1 root root       151 Aug 13 07:55 'LSST Science Collaborations Status Report - updates August 2019.gslides'
# -rw------- 1 root root       151 Aug 14 17:31 'LSST2019: Sci Collab Plenary Talks Wednesday.gslides'
# -rw------- 1 root root       151 Aug 14 18:39 'LSST2019: Sci Collab Plenary Talks Tuesday.gslides'
# -rw------- 1 root root       151 Aug 14 19:50 'Untitled document (35).gdoc'
# -rw------- 1 root root       151 Aug 15 18:18 'Untitled document (38).gdoc'
# -rw------- 1 root root       151 Aug 15 21:33 'July2019 LSSTC executive board  SCs Advisory committee meeting.gdoc'
# -rw------- 1 root root       151 Aug 16 18:13 'SETI LSST budget.gsheet'
# -rw------- 1 root root       151 Aug 17 00:27 'Untitled document (44).gdoc'
# -rw------- 1 root root       151 Aug 17 00:29 'Are we alone? Searching for Intelligent Life with LSST.gdoc'
# -rw------- 1 root root       151 Aug 17 14:47 'Summary Sci Collab activities and LSSTPCW2019 SC Plenary Talks.gslides'
# -rw------- 1 root root       151 Aug 17 15:39 'Endorsement of LSST Corporation Activities by the LSST Science Collaborations.gdoc'
# -rw------- 1 root root       151 Aug 18 23:44 'TVS metrics and survey cadence proposals.gslides'
# -rw------- 1 root root       151 Aug 19 18:06 'LSST science intro.gslides'
# -rw------- 1 root root       151 Aug 19 23:31 'Untitled document (43).gdoc'
# -rw------- 1 root root       151 Aug 20 00:00 'LSST science 101.gslides'
# drwx------ 2 root root      4096 Aug 23 20:53 'TED fellow space show'/
# -rw------- 1 root root     36578 Aug 24 05:06  LA.ipynb
# -rw------- 1 root root       151 Aug 24 21:56 'Untitled document (39).gdoc'
# drwx------ 2 root root      4096 Aug 26 02:53 'DE legislative reform'/
# -rw------- 1 root root       151 Aug 26 03:58  HOMLPython.gdoc
# -rw------- 1 root root       151 Aug 28 03:14 'Accelnet2019 reviews.gdoc'
# -rw------- 1 root root       151 Aug 28 20:22 'Untitled document (41).gdoc'
# -rw------- 1 root root       151 Aug 30 22:50 'SC Chairs meeting August 30th 2019.gdoc'
# -rw------- 1 root root       151 Aug 31 02:54 'Untitled document (34).gdoc'
# -rw------- 1 root root       151 Sep  9 17:35 'A Diversity and Inclusion Committee of the Department of Physics and Astronomy at the University of Delaware.gdoc'
# -rw------- 1 root root       151 Sep  9 21:34 'Untitled document (32).gdoc'
# -rw------- 1 root root       151 Sep 11 03:36  resume.gdoc
# drwx------ 2 root root      4096 Sep 13 13:16 'ARPAe docs'/
# -rw------- 1 root root       151 Sep 13 15:36 'Untitled document (53).gdoc'
# -rw------- 1 root root       151 Sep 15 01:46 'Untitled spreadsheet (12).gsheet'
# -rw------- 1 root root       151 Sep 17 05:57 'LSST IKCC.gdoc'
# -rw------- 1 root root       151 Sep 18 18:25 'Untitled document (30).gdoc'
# -rw------- 1 root root       151 Sep 20 01:27 'TVS-SMWLV meeting and hackathon 2019.gform'
# -rw------- 1 root root     71163 Sep 23 00:20 'DSPS 2019 quiz 6 - Google Docs-1.pdf'
# -rw------- 1 root root     67540 Sep 25 13:13  APIreadingJson.ipynb
# -rw------- 1 root root       598 Sep 25 13:32  NYCweatherAPI.py
# drwx------ 2 root root      4096 Sep 25 13:45  citibikes/
# drwx------ 2 root root      4096 Sep 25 16:39  dsps2019/
# -rw------- 1 root root       151 Sep 25 23:51 'TVS-SMWLV meeting and hackathon 2019 (Responses).gsheet'
# drwx------ 2 root root      4096 Sep 26 04:14  test_dir/
# drwx------ 2 root root      4096 Sep 26 04:15  dsps/

# %% [markdown]
# ## TASK
# Create a for loop that reads in the ZIPCODE data zbp[year]detail.zip where [year] goes from 2010 through 2014 included.
# The for look should use the ```os``` module to:
#   - download the zipped file
#   - unzip the file in dsps2019 dir (create it if necessary)
#   - clean up after itself by removing the downloaded zip files
#   - print at every step of the loop which year the loop is working on and at each command which command is running.
#   - notify the user if an error occurs and where

# %%
path = ...

# create the directory as above. 
# Use glob.glob to see if it is there and capture the output of os.system to see if you have an error
[...]

# -- loop through the years for which we want the zbp data
for ii in [...]: 
  
  # -- convert year to string
  snum = str(ii)

  # -- build the wget command
  cmd_wget = [...]

  # -- build the unzip command
  cmd_unzip = [...]

    # -- build the remove command
  cmd_rm = [...]
  
  # -- alert on progress
  print("downloading year 20{}".format(snum))
  
  # -- execute the wget command and check
  res = os.system(...]
  if res != 0:
    print("error ", res, "with downloading", ii)
  
  # -- alert on progress
  print("moving file...")
  
  res = [...]
  
  # -- alert on progress
  print(...)
  
  res = [...]

# %%
ls  "drive/My Drive/dsps2019"
# Out:
# zbp10detail.txt  zbp12detail.txt  zbp14detail.txt
# zbp11detail.txt  zbp13detail.txt
